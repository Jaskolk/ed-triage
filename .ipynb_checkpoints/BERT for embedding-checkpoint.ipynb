# %% [markdown]
# ## Install and Import

# %%
import tensorflow as tf

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install pytorch-pretrained-bert pytorch-nlp
# Out:
# Requirement already satisfied: pytorch-pretrained-bert in /usr/local/lib/python3.6/site-packages (0.6.2)
# Requirement already satisfied: pytorch-nlp in /usr/local/lib/python3.6/site-packages (0.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/site-packages (from pytorch-pretrained-bert) (2.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/site-packages (from pytorch-pretrained-bert) (4.31.1)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.6/site-packages (from pytorch-pretrained-bert) (1.0.1.post2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/site-packages (from pytorch-pretrained-bert) (1.9.253)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/site-packages (from pytorch-pretrained-bert) (1.15.4)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/site-packages (from pytorch-pretrained-bert) (2019.8.19)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/site-packages (from pytorch-nlp) (0.23.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/site-packages (from requests->pytorch-pretrained-bert) (2019.3.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests->pytorch-pretrained-bert) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests->pytorch-pretrained-bert) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests->pytorch-pretrained-bert) (3.0.4)
# Requirement already satisfied: botocore<1.13.0,>=1.12.253 in /usr/local/lib/python3.6/site-packages (from boto3->pytorch-pretrained-bert) (1.12.253)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python3.6/site-packages (from boto3->pytorch-pretrained-bert) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/site-packages (from boto3->pytorch-pretrained-bert) (0.9.4)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/site-packages (from pandas->pytorch-nlp) (2018.7)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/site-packages (from pandas->pytorch-nlp) (2.7.5)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/site-packages (from botocore<1.13.0,>=1.12.253->boto3->pytorch-pretrained-bert) (0.15.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->pytorch-nlp) (1.12.0)
# menpo 0.8.1 has requirement matplotlib<2.0,>=1.4, but you'll have matplotlib 3.0.2 which is incompatible.
# menpo 0.8.1 has requirement pillow<5.0,>=3.0, but you'll have pillow 5.4.0 which is incompatible.
# menpo 0.8.1 has requirement scipy<1.0,>=0.16, but you'll have scipy 1.2.0 which is incompatible.
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from pytorch_pretrained_bert import BertTokenizer, BertConfig
from pytorch_pretrained_bert import BertAdam, BertForSequenceClassification
from tqdm import tqdm, trange
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
#% matplotlib inline

# %% [markdown]
# In order for torch to use the GPU, we need to identify and specify the GPU as the device. Later, in our training loop, we will load data onto the device.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla K80'

# %%
#use this cell when working online
path = '/floyd/home/ed-triage'
data_path = '/floyd/home/data/egh'

# %% [markdown]
# ## second pass
# now going to figure out how to run this on the whole dataset

# %%
def create_dummy_column(s):
  if str(s) == 'nan':
    return 'empty cell'
  else:
    return s

# %%
data = pd.read_csv(data_path + '/subj_data.csv', index_col = 0)
data.shape
# Out:
# (63474, 2)

# %%
data.head()
# Out:
#                                   CleanSubjectiveNotes  \
# 511  complains of central chest tightness since yes...
# 754  pt says noted blood in stool yesterday and mor...
# 755    rt flank pain since morning,on her periods now.
# 757            abdo pain  onset monday,not seen by fd.
# 758  fell last monday landed on ground, " dizzy" at...
#
#                                              pmhx
# 511            childhood heart murmur, drug abuse
# 754                                       seizure
# 755  no significant medical history, ovarian cyst
# 757                no significant medical history
# 758       high cholesterol, 2 stents 2014, low bp

# %%
data['for embedding'] = data.CleanSubjectiveNotes.map(create_dummy_column)

# %%
sentences = data['for embedding'].values

# We need to add special tokens at the beginning and end of each sentence for BERT to work properly
sentences = ["[CLS] " + sentence + " [SEP]" for sentence in sentences]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]
print ("Tokenize the first sentence:")
print (tokenized_texts[0])
# Out:
# Tokenize the first sentence:
# ['[CLS]', 'complain', '##s', 'of', 'central', 'chest', 'tight', '##ness', 'since', 'yesterday', 'morning', '.', 'worse', 'with', 'pal', '##pati', '##on', '.', 'relieved', 'with', 'movement', 'and', 'deep', 'breathing', '.', 'denies', 'nausea', 'and', '/', 'or', 'vomiting', '.', 'complain', '##s', 'of', 'feeling', 'cold', 'and', '"', 'tired', '"', '.', 'says', 'took', 'nearly', 'mel', '##aton', '##in', '100', '##mg', ',', 'cocaine', ',', 'and', 'et', '##oh', 'on', 'sunday', '.', '[SEP]']

# %%
print ('show a few other tokenized sentences')
print (tokenized_texts[10])
print (tokenized_texts[100])
print (tokenized_texts[1000])
print (tokenized_texts[10000])
# Out:
# show a few other tokenized sentences
# ['[CLS]', 'presently', 'feels', 'like', 'heart', 'is', 'going', 'fast', '.', 'intermittent', 'lt', 'sided', ',', 'non', '-', 'radiating', '.', 'no', 'cp', 'now', '.', 'says', 'he', 'has', 'thoughts', 'of', 'harm', '##ing', 'self', 'and', 'others', 'at', 'tri', '##age', 'but', 'says', 'plan', 'is', '"', 'to', 'get', 'help', '"', '.', 'says', 'takes', 'hiv', '/', 'aids', 'med', '##s', 'when', 'he', 'remembers', '.', 'cannot', 'remember', 'the', 'names', 'of', 'med', '##s', '.', '[SEP]']
# ['[CLS]', 'vomit', '##ed', 'x', '5', ',', 'headache', ',', 'di', '##zziness', ',', 'not', 'able', 'to', 'tolerate', 'food', 'or', 'fluids', 'since', '113', '##0', 'hours', '[SEP]']
# ['[CLS]', 'pt', 'complain', '##s', 'of', 'short', '##ness', 'of', 'breath', 'that', 'started', '1', 'week', 'ago', ',', 'denies', 'cp', '.', 'pt', 'has', 'swelling', 'to', 'feet', '.', 'report', 'feeling', 'weak', '.', 'wife', 'stated', 'pt', 'has', 'blood', 'in', 'stool', '.', '[SEP]']
# ['[CLS]', 'pt', 'reported', 'that', 'he', 'needs', 'help', 'for', 'alcohol', 'withdrawal', '.', 'having', 'pal', '##pit', '##ations', ',', 'anxiety', 'attacks', 'and', 'tremor', '##s', '.', '[SEP]']

# %%
data['tokenized_subj_notes'] = sentences

# %%
sent_lens = [len(x) for x in tokenized_texts]
print ('mean sentence length', np.mean(sent_lens))
print ('max sentence length', np.max(sent_lens))
# Out:
# mean sentence length 40.27126067366166
# max sentence length 216

# %%
# Set the maximum sequence length. The longest sequence in our training set is 47, but we'll leave room on the end anyway. 
# In the original paper, the authors used a length of 512.
MAX_LEN = np.max(sent_lens)

# %%
# Use the BERT tokenizer to convert the tokens to their index numbers in the BERT vocabulary
input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]

# %%
# Pad our input tokens
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")

# %%
# Create attention masks
attention_masks = []

# Create a mask of 1s for each token followed by 0s for padding
for seq in input_ids:
  seq_mask = [float(i>0) for i in seq]
  attention_masks.append(seq_mask)

# %%
# Convert all of our data into torch tensors, the required datatype for our model

train_inputs = torch.tensor(input_ids)
train_masks = torch.tensor(attention_masks)

# %%
# Select a batch size for training. For fine-tuning BERT on a specific task, the authors recommend a batch size of 16 or 32
batch_size = 16

# Create an iterator of our data with torch DataLoader. This helps save on memory during training because, unlike a for loop, 
# with an iterator the entire dataset does not need to be loaded into memory

train_data = TensorDataset(train_inputs, train_masks)
train_dataloader = DataLoader(train_data, batch_size=batch_size)

# %%
#we are going to download the model and transfer it to cuda
from pytorch_pretrained_bert import BertModel
model = BertModel.from_pretrained('bert-base-uncased')
model.cuda();

# %% [markdown]
# ## sentence embedding below

# %%
#gonna redo, but this time only keep the sentences
model.eval()
embedded_notes = []
for i, x in enumerate(train_dataloader):
  
    inpseq = x[0].to(device)
    inpmask = x[1].to(device)
    embeds,_ = model(inpseq, attention_mask = inpmask)
    sentence_vec = torch.mean(embeds[11],1)  #this is supposedly where the sentences are
    embedded_notes.append(sentence_vec.cpu().detach().numpy())
    if i%500 == 0:
        print ('batch #:', i+1)
        print ('results stored...')
# Out:
# batch #: 1
# results stored...
# batch #: 501
# results stored...
# batch #: 1001
# results stored...
# batch #: 1501
# results stored...
# batch #: 2001
# results stored...
# batch #: 2501
# results stored...
# batch #: 3001
# results stored...
# batch #: 3501
# results stored...

# %%
len(embedded_notes)
# Out:
# 3968

# %%
flat_sentences = [item for sublist in embedded_notes for item in sublist]

# %%
data['embedded_subjnotes'] = flat_sentences

# %%
data.head()
# Out:
#                                   CleanSubjectiveNotes  \
# 511  complains of central chest tightness since yes...
# 754  pt says noted blood in stool yesterday and mor...
# 755    rt flank pain since morning,on her periods now.
# 757            abdo pain  onset monday,not seen by fd.
# 758  fell last monday landed on ground, " dizzy" at...
#
#                                              pmhx  \
# 511            childhood heart murmur, drug abuse
# 754                                       seizure
# 755  no significant medical history, ovarian cyst
# 757                no significant medical history
# 758       high cholesterol, 2 stents 2014, low bp
#
#                                          for embedding  \
# 511  complains of central chest tightness since yes...
# 754  pt says noted blood in stool yesterday and mor...
# 755    rt flank pain since morning,on her periods now.
# 757            abdo pain  onset monday,not seen by fd.
# 758  fell last monday landed on ground, " dizzy" at...
#
#                                   tokenized_subj_notes  \
# 511  [CLS] complains of central chest tightness sin...
# 754  [CLS] pt says noted blood in stool yesterday a...
# 755  [CLS] rt flank pain since morning,on her perio...
# 757  [CLS] abdo pain  onset monday,not seen by fd. ...
# 758  [CLS] fell last monday landed on ground, " diz...
#
#                                     embedded_subjnotes
# 511  [-0.2552049, 0.060189128, 0.2712358, -0.307374...
# 754  [0.23464553, -0.18784478, 0.47729325, -0.02351...
# 755  [-0.26586953, -0.1800395, 0.37560245, -0.34440...
# 757  [-0.20064865, -0.20033248, 0.32697883, -0.2581...
# 758  [-0.09094222, -0.15834723, 0.48943293, 0.03535...

# %%
data['embedded_subjnotes'].to_csv(data_path + '/subjnote_embeds.csv')

# %% [markdown]
# ## now gonna sentence embed medical history

# %%
#need an way to handle empty cells so i can still embed the whole dataset and plug it back into the dataframe
data['for embedding'] = data['pmhx'].map(create_dummy_column)

# %%
sentences = data['for embedding'].values

# We need to add special tokens at the beginning and end of each sentence for BERT to work properly
sentences = ["[CLS] " + sentence + " [SEP]" for sentence in sentences]

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

tokenized_texts = [tokenizer.tokenize(sent) for sent in sentences]
print ("Tokenize the first sentence:")
print (tokenized_texts[0])
# Out:
# Tokenize the first sentence:
# ['[CLS]', 'childhood', 'heart', 'murmur', ',', 'drug', 'abuse', '[SEP]']

# %%
print ('show a few other tokenized sentences')
print (tokenized_texts[10])
print (tokenized_texts[100])
print (tokenized_texts[1000])
print (tokenized_texts[10000])
# Out:
# show a few other tokenized sentences
# ['[CLS]', 'hiv', '[SEP]']
# ['[CLS]', 'no', 'significant', 'medical', 'history', '[SEP]']
# ['[CLS]', 'hyper', '##tension', ',', 'high', 'cho', '##les', '##terol', '[SEP]']
# ['[CLS]', 'ge', '##rd', '[SEP]']

# %%
data['tokenized_medhx'] = sentences

# %%
sent_lens = [len(x) for x in tokenized_texts]
print ('mean sentence length:', np.mean(sent_lens))
print ('max sentence length:', np.max(sent_lens))
# Out:
# mean sentence length: 7.990295238995494
# max sentence length: 101

# %%
# Set the maximum sequence length. The longest sequence in our training set is 47, but we'll leave room on the end anyway. 
# In the original paper, the authors used a length of 512.
MAX_LEN = np.max(sent_lens)

# %%
# Use the BERT tokenizer to convert the tokens to their index numbers in the BERT vocabulary
input_ids = [tokenizer.convert_tokens_to_ids(x) for x in tokenized_texts]

# %%
# Pad our input tokens
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", truncating="post", padding="post")

# %% [markdown]
# Create the attention masks

# %%
# Create attention masks
attention_masks = []

# Create a mask of 1s for each token followed by 0s for padding
for seq in input_ids:
  seq_mask = [float(i>0) for i in seq]
  attention_masks.append(seq_mask)

# %%
# Convert all of our data into torch tensors, the required datatype for our model

train_inputs = torch.tensor(input_ids)
train_masks = torch.tensor(attention_masks)

# %%
# Select a batch size for training. For fine-tuning BERT on a specific task, the authors recommend a batch size of 16 or 32
batch_size = 16

# Create an iterator of our data with torch DataLoader. This helps save on memory during training because, unlike a for loop, 
# with an iterator the entire dataset does not need to be loaded into memory

train_data = TensorDataset(train_inputs, train_masks)
train_dataloader = DataLoader(train_data, batch_size=batch_size)

# %%
#we are going to download the model and transfer it to cuda
from pytorch_pretrained_bert import BertModel
model = BertModel.from_pretrained('bert-base-uncased')
model.cuda();

# %%
#gonna redo, but this time only keep the sentences
model.eval()
embedded_notes = []
for i, x in enumerate(train_dataloader):
  
    inpseq = x[0].to(device)
    inpmask = x[1].to(device)
    embeds,_ = model(inpseq, attention_mask = inpmask)
    sentence_vec = torch.mean(embeds[11],1)  #this is supposedly where the sentences are
    embedded_notes.append(sentence_vec.cpu().detach().numpy())
    if i%500 == 0:
        print ('batch #:', i+1)
        print ('results stored...')
# Out:
# batch #: 1
# results stored...
# batch #: 501
# results stored...
# batch #: 1001
# results stored...
# batch #: 1501
# results stored...
# batch #: 2001
# results stored...
# batch #: 2501
# results stored...
# batch #: 3001
# results stored...
# batch #: 3501
# results stored...

# %%
len(embedded_notes)
# Out:
# 3968

# %%
flat_sentences = [item for sublist in embedded_notes for item in sublist]

# %%
data['embedded_pmhx'] = flat_sentences

# %%
data['embedded_pmhx'].to_csv(data_path + 'pmhx_embeds.csv')

# %% [markdown]
# ## below here, I'm just learning to import the data and merge it.  works well

# %%
new_data = pd.read_csv(data_path + '/pmhx_embeds.csv', header = None, index_col = 0)

# %%
new_data.head()
# Out:
#                                                      1
# 0
# 511  [-5.62175699e-02 -1.55288264e-01 -3.55031192e-...
# 754  [-2.32482120e-01 -3.98706704e-01  5.75849652e-...
# 755  [ 7.09933490e-02 -1.90701023e-01 -3.40518981e-...
# 757  [-6.41224608e-02  1.80907622e-02 -2.60267198e-...
# 758  [-3.08350593e-01 -8.54802653e-02  3.15538704e-...

# %%
new_data.columns
# Out:
# Int64Index([1], dtype='int64')

# %%
del new_data.index.name

# %%
new_data.index
# Out:
# Int64Index([  511,   754,   755,   757,   758,   761,   762,   764,   765,
#               767,
#             ...
#             85142, 85143, 85144, 85146, 85147, 85148, 85149, 85150, 85152,
#             85153],
#            dtype='int64', length=63474)

# %%
target_df = pd.read_csv(data_path + '/targets.csv', index_col = 0)

# %%
target_df.shape, new_data.shape
# Out:
# ((63474, 10), (63474, 1))

# %%
balanced_data = pd.read_csv(data_path + '/balanced_4cls_nlp_data.csv', index_col = 0)

# %%
balanced_data.head()
# Out:
#         ID ChartNumber EncounterNumber  TriageLevel  AgeNumber  AgeInYrs  \
# 2036  2037    E8513381     EE002038/18          2.0         29      29.0
# 2426  2427    E6203160     EE002429/18          2.0         80      80.0
# 3688  3689    E8576697     EE003692/18          2.0         48      48.0
# 4174  4175    E8569017     EE004180/18          2.0         68      68.0
# 4387  4388    E8577015     EE004393/18          2.0         50      50.0
#
#      GenderDesc   Triage Date & Time      Reg Date & Time  \
# 2036       Male  2018-04-10 05:01:00  2018-04-10 05:00:00
# 2426     Female  2018-04-11 21:43:00  2018-04-11 21:49:00
# 3688       Male  2018-04-17 21:12:00  2018-04-17 21:19:00
# 4174     Female  2018-04-20 05:24:00  2018-04-20 05:26:00
# 4387       Male  2018-04-21 00:30:00  2018-04-21 00:35:00
#
#           PIA Date & Time                        ...                          \
# 2036  2018-04-10 05:27:00                        ...
# 2426  2018-04-11 21:50:00                        ...
# 3688  2018-04-17 21:30:00                        ...
# 4174  2018-04-20 05:30:00                        ...
# 4387  2018-04-21 01:00:00                        ...
#
#      target  service target2 discharge  target3   dispo target4  \
# 2036      2      ICU       4     admit        0  madmit     1.0
# 2426      4      ICU       4     admit        0     ICU     3.0
# 3688      2      ICU       4     admit        0  madmit     1.0
# 4174      2      ICU       4     admit        0  madmit     1.0
# 4387      2      ICU       4     admit        0  madmit     1.0
#
#                ICUvsother target5  \
# 2036  INTENSIVE CARE UNIT       1
# 2426  INTENSIVE CARE UNIT       1
# 3688  INTENSIVE CARE UNIT       1
# 4174  INTENSIVE CARE UNIT       1
# 4387  INTENSIVE CARE UNIT       1
#
#                                                    pmhx
# 2036                                    type 1 diabetes
# 2426  pea, chf, pulmonary htn, mi, angina, sleep apn...
# 3688  anemia, thyroid, iddm, hypertension, gerd, cir...
# 4174  copd, chronic bronchitis, home o2 3l np prn, d...
# 4387                     no significant medical history
#
# [5 rows x 46 columns]

# %%
balanced_data.join(new_data, how = "inner")
# Out:
#           ID ChartNumber EncounterNumber  TriageLevel  AgeNumber  AgeInYrs  \
# 2036    2037    E8513381     EE002038/18          2.0         29      29.0
# 2426    2427    E6203160     EE002429/18          2.0         80      80.0
# 3688    3689    E8576697     EE003692/18          2.0         48      48.0
# 4174    4175    E8569017     EE004180/18          2.0         68      68.0
# 4387    4388    E8577015     EE004393/18          2.0         50      50.0
# 4456    4457    E8342684     EE004462/18          2.0         81      81.0
# 6211    6212    E8577721     EE006221/18          2.0         68      68.0
# 6215    6216    e7359433     EE006225/18          2.0         32      32.0
# 6484    6485    E8383907     EE006495/18          2.0         77      77.0
# 7930    7931    E8476439     EE007948/18          3.0         77      77.0
# 8322    8323    E7975683     EE008339/18          2.0         18      18.0
# 9762    9763    E7406762     EE009779/18          3.0         86      86.0
# 9979    9980    E8463520     EE009996/18          2.0         75      75.0
# 10930  10931    E8032445     EE010948/18          2.0         81      81.0
# 11348  11349    E8579918     EE011367/18          2.0         71      71.0
# 13749  13750    E8209143     EE013772/18          3.0         75      75.0
# 14347  14348    E8360706     EE014370/18          3.0         44      44.0
# 15101  15102    E6348734     EE015125/18          2.0         76      76.0
# 15255  15256    E8251710     EE015279/18          2.0         61      61.0
# 16639  16640    E8572515     EE016666/18          3.0         17      17.0
# 17797  17798    E8107999     EE017829/18          2.0         85      85.0
# 19327  19328    E7653322     EE019363/18          2.0         57      57.0
# 19881  19882    E7319239     EE019919/18          3.0         90      90.0
# 21472  21473    E8547191     EE021511/18          3.0         86      86.0
# 22368  22369    E3286960     EE022410/18          2.0         42      42.0
# 22431  22432    E8569865     EE022473/18          2.0         70      70.0
# 23777  23778    E8181571     EE023818/18          2.0         72      72.0
# 24849  24850    E8522566     EE024893/18          2.0         52      52.0
# 26832  26833    E8390402     EE026878/18          3.0         56      56.0
# 26985  26986    E8387995     EE027033/18          2.0         85      85.0
# ...      ...         ...             ...          ...        ...       ...
# 46069  46070    E8594785     EE046145/18          3.0         70      70.0
# 31391  31392    E8421234     EE031446/18          2.0         50      50.0
# 48379  48380    E6438089     EE048458/18          3.0         27      27.0
# 5594    5595    E8240693     EE005601/18          2.0         37      37.0
# 16778  16779    E4543872     EE016805/18          3.0         66      66.0
# 48956  48957    E8086770     EE049037/18          3.0         85      85.0
# 6013    6014    E5990296     EE006023/18          3.0         64      64.0
# 63832  63833    E8602991     EE063933/18          2.0         34      34.0
# 45956  45957    E8137047     EE046033/18          2.0         24      24.0
# 16664  16665    E8582054     EE016691/18          2.0         43      43.0
# 83681  83682    E8170066     EE083814/18          2.0         58      58.0
# 75527  75528    E8607978     EE075646/18          4.0         53      53.0
# 40719  40720    E8585443     EE040784/18          2.0         55      55.0
# 40873  40874    E8585120     EE040939/18          3.0         30      30.0
# 74306  74307    E8607536     EE074425/18          2.0         23      23.0
# 65653  65654    E8603652     EE065759/18          3.0         42      42.0
# 46316  46317    E8566419     EE046393/18          3.0          2       2.0
# 26832  2018-07-25 03:35:00                        ...
# 26985  2018-07-25 19:00:00                        ...
# ...                    ...                        ...
# 46069  2018-10-17 15:40:00                        ...
# 31391  2018-08-14 08:47:00                        ...
# 48379  2018-10-27 19:25:00                        ...
# 5594   2018-04-26 14:00:00                        ...
# 16778  2018-06-12 16:30:00                        ...
# 48956  2018-10-30 13:00:00                        ...
# 6013   2018-04-28 11:25:00                        ...
# 63832  2019-01-02 00:40:00                        ...
# 45956  2018-10-16 22:24:00                        ...
# 16664  2018-06-12 05:45:00                        ...
# 83681  2019-03-25 21:37:00                        ...
# 75527  2019-02-20 10:50:00                        ...
# 40719  2018-09-24 12:30:00                        ...
# 40873  2018-09-24 22:33:00                        ...
# 74306  2019-02-15 12:50:00                        ...
# 65653  2019-01-08 21:30:00                        ...
# 46316  2018-10-18 18:40:00                        ...
# 37954  2018-09-12 18:57:00                        ...
# 33792  2018-08-24 20:00:00                        ...
# 78686  2019-03-05 06:26:00                        ...
# 40987  2018-09-25 13:48:00                        ...
# 76369  2019-02-23 15:55:00                        ...
# 47148  2018-10-22 12:45:00                        ...
# 6208   2018-04-29 02:58:00                        ...
# 79792  2019-03-09 21:35:00                        ...
# 84026  2019-03-27 12:10:00                        ...
# 58166  2018-12-10 15:23:00                        ...
# 80178  2019-03-11 12:40:00                        ...
# 5529   2018-04-26 07:59:00                        ...
# 33558  2018-08-23 19:53:00                        ...
#
#          service  target2  discharge target3   dispo target4  \
# 2036         ICU        4      admit       0  madmit     1.0
# 2426         ICU        4      admit       0     ICU     3.0
# 3688         ICU        4      admit       0  madmit     1.0
# 4174         ICU        4      admit       0  madmit     1.0
# 4387         ICU        4      admit       0  madmit     1.0
# 4456         ICU        4      admit       0     ICU     3.0
# 6211         ICU        4      admit       0  madmit     1.0
# 6215         ICU        4      admit       0  madmit     1.0
# 6484         ICU        4      admit       0  madmit     1.0
# 7930         ICU        4      admit       0  sadmit     2.0
# 8322         ICU        4      admit       0     ICU     3.0
# 9762         ICU        4      admit       0  sadmit     2.0
# 9979         ICU        4      admit       0     ICU     3.0
# 10930        ICU        4      admit       0  madmit     1.0
# 11348        ICU        4      admit       0     ICU     3.0
# 13749        ICU        4      admit       0  madmit     1.0
# 14347        ICU        4      admit       0     ICU     3.0
# 15101        ICU        4      admit       0  madmit     1.0
# 15255        ICU        4      admit       0  madmit     1.0
# 16639        ICU        4      admit       0     ICU     3.0
# 17797        ICU        4      admit       0     ICU     3.0
# 19327        ICU        4      admit       0     ICU     3.0
# 19881        ICU        4      admit       0  madmit     1.0
# 21472        ICU        4      admit       0  sadmit     2.0
# 22368        ICU        4      admit       0  madmit     1.0
# 22431        ICU        4      admit       0     ICU     3.0
# 23777        ICU        4      admit       0     ICU     3.0
# 24849        ICU        4      admit       0  madmit     1.0
# 26832        ICU        4      admit       0     ICU     3.0
# 26985        ICU        4      admit       0     ICU     3.0
# ...          ...      ...        ...     ...     ...     ...
# 46069  discharge        1  discharge       1     NaN     NaN
# 31391  discharge        1  discharge       1     NaN     NaN
# 48379  discharge        1  discharge       1     NaN     NaN
# 5594   discharge        1  discharge       1     NaN     NaN
# 16778  discharge        1  discharge       1     NaN     NaN
# 48956  discharge        1  discharge       1     NaN     NaN
# 6013   discharge        1  discharge       1     NaN     NaN
# 63832  discharge        1  discharge       1     NaN     NaN
# 45956  discharge        1  discharge       1     NaN     NaN
# 16664  discharge        1  discharge       1     NaN     NaN
# 83681  discharge        1  discharge       1     NaN     NaN
# 75527  discharge        1  discharge       1     NaN     NaN
# 40719  discharge        1  discharge       1     NaN     NaN
# 40873  discharge        1  discharge       1     NaN     NaN
# 74306  discharge        1  discharge       1     NaN     NaN
# 65653  discharge        1  discharge       1     NaN     NaN
# 46316  discharge        1  discharge       1     NaN     NaN
# 37954  discharge        1  discharge       1     NaN     NaN
# 33792  discharge        1  discharge       1     NaN     NaN
# 78686  discharge        1  discharge       1     NaN     NaN
# 40987  discharge        1  discharge       1     NaN     NaN
# 76369  discharge        1  discharge       1     NaN     NaN
# 47148  discharge        1  discharge       1     NaN     NaN
# 6208   discharge        1  discharge       1     NaN     NaN
# 79792  discharge        1  discharge       1     NaN     NaN
# 84026  discharge        1  discharge       1     NaN     NaN
# 58166  discharge        1  discharge       1     NaN     NaN
# 80178  discharge        1  discharge       1     NaN     NaN
# 5529   discharge        1  discharge       1     NaN     NaN
# 33558  discharge        1  discharge       1     NaN     NaN
#
#                 ICUvsother target5  \
# 2036   INTENSIVE CARE UNIT       1
# 2426   INTENSIVE CARE UNIT       1
# 3688   INTENSIVE CARE UNIT       1
# 4174   INTENSIVE CARE UNIT       1
# 4387   INTENSIVE CARE UNIT       1
# 4456   INTENSIVE CARE UNIT       1
# 6211   INTENSIVE CARE UNIT       1
# 6215   INTENSIVE CARE UNIT       1
# 6484   INTENSIVE CARE UNIT       1
# 7930   INTENSIVE CARE UNIT       1
# 8322   INTENSIVE CARE UNIT       1
# 9762   INTENSIVE CARE UNIT       1
# 9979   INTENSIVE CARE UNIT       1
# 10930  INTENSIVE CARE UNIT       1
# 11348  INTENSIVE CARE UNIT       1
# 13749  INTENSIVE CARE UNIT       1
# 14347  INTENSIVE CARE UNIT       1
# 15101  INTENSIVE CARE UNIT       1
# 15255  INTENSIVE CARE UNIT       1
# 16639  INTENSIVE CARE UNIT       1
# 17797  INTENSIVE CARE UNIT       1
# 19327  INTENSIVE CARE UNIT       1
# 19881  INTENSIVE CARE UNIT       1
# 21472  INTENSIVE CARE UNIT       1
# 22368  INTENSIVE CARE UNIT       1
# 22431  INTENSIVE CARE UNIT       1
# 23777  INTENSIVE CARE UNIT       1
# 24849  INTENSIVE CARE UNIT       1
# 26832  INTENSIVE CARE UNIT       1
# 26985  INTENSIVE CARE UNIT       1
# ...                    ...     ...
# 46069                  NaN       0
# 31391                  NaN       0
# 48379                  NaN       0
# 5594                   NaN       0
# 16778                  NaN       0
# 48956                  NaN       0
# 6013                   NaN       0
# 63832                  NaN       0
# 45956                  NaN       0
# 16664                  NaN       0
# 83681                  NaN       0
# 75527                  NaN       0
# 40719                  NaN       0
# 40873                  NaN       0
# 74306                  NaN       0
# 65653                  NaN       0
# 46316                  NaN       0
# 37954                  NaN       0
# 33792                  NaN       0
# 78686                  NaN       0
# 40987                  NaN       0
# 76369                  NaN       0
# 47148                  NaN       0
# 6208                   NaN       0
# 79792                  NaN       0
# 84026                  NaN       0
# 58166                  NaN       0
# 80178                  NaN       0
# 5529                   NaN       0
# 33558                  NaN       0
#
#                                                     pmhx  \
# 2036                                     type 1 diabetes
# 2426   pea, chf, pulmonary htn, mi, angina, sleep apn...
# 3688   anemia, thyroid, iddm, hypertension, gerd, cir...
# 4174   copd, chronic bronchitis, home o2 3l np prn, d...
# 4387                      no significant medical history
# 4456                      no significant medical history
# 6211    mi, asthma, high cholesterol, hypertension, copd
# 6215                                             unknown
# 6484   chf, high cholesterol, mi 2012 with triple byp...
# 7930             iron deficiency, gerd, htn, hep b, etoh
# 8322                                              asthma
# 9762                                          niddm, htn
# 9979   renal failure, high cholesterol, bipass, niddm...
# 10930                     hypertension, high cholesterol
# 11348          mi, double bypass, hitn, high cholesterol
# 13749  cva, mi, iddm, hypertension, high cholesterol,...
# 14347                                hypothyroid, anemia
# 15101  quaddrupal bipass three years ago, iddm, hyper...
# 15255              high cholesterol, hypertension, niddm
# 16639                      suicidal admission march 2018
# 17797  pneumonia, heart problem, hypertension, high c...
# 19327               brain cancer, iddm, high cholesterol
# 19881                                  dementia, thyroid
# 21472  vasculitis 2016, diverticulitis, colostomy mar...
# 22368                                                dmi
# 22431                            lymphoma, high bp, gerd
# 23777  hypertension, high cholesterol, chf, mi, asthm...
# 24849                          iddm, htn, kidney problem
# 26832                                       liver cancer
# 26985                     hypertension, high cholesterol
# ...                                                  ...
# 46069                     no significant medical history
# 31391                                                htn
# 48379                     no significant medical history
# 5594                      no significant medical history
# 16778                            niddm, htn, cholesterol
# 48956                          high cholesterol, high bp
# 6013                      no significant medical history
# 63832                     no significant medical history
# 45956                                     abortion april
# 16664                     no significant medical history
# 83681                                        hypothyroid
# 75527                     no significant medical history
# 40719  gout, depression, hypertension, kidney and bla...
# 40873                                         alcoholism
# 74306                                depression, anxiety
# 65653                     no significant medical history
# 46316                     no significant medical history
# 37954                                       hypertension
# 33792                          highcholesterol, seizures
# 78686                     no significant medical history
# 40987                                       hypertension
# 76369                     no significant medical history
# 47148                                        hypothyroid
# 6208                      no significant medical history
# 79792                     no significant medical history
# 84026                              htn, high cholesterol
# 58166                                              niddm
# 80178                   high bp, high cholesterol, niddm
# 5529   atrial fibrillation, anxiety, enlarged prostat...
# 33558                                       constipation
#
#                                                        1
# 2036   [-3.93756658e-01 -3.28373522e-01 -4.02532220e-...
# 2426   [-2.32611611e-01  1.10164401e-03  1.30712651e-...
# 3688   [-1.75886527e-01 -1.08718732e-02 -1.85199138e-...
# 4174   [-2.86045134e-01 -5.87921310e-03  1.62716746e-...
# 4387   [-6.41224608e-02  1.80907622e-02 -2.60267198e-...
# 4456   [-6.41224608e-02  1.80907622e-02 -2.60267198e-...
#
balanced_data.index
# Out:
# Int64Index([ 2036,  2426,  3688,  4174,  4387,  4456,  6211,  6215,  6484,
#              7930,
#             ...
#             40987, 76369, 47148,  6208, 79792, 84026, 58166, 80178,  5529,
#             33558],
#            dtype='int64', length=400)

# %%
overlap = [x for x in  new_data.index if x in balanced_data.index]

# %%
len(overlap)
# Out:
# 400

# %%
sorted(overlap) == sorted(list(balanced_data.index))
# Out:
# True

# %%
ltd_data = new_data.loc[overlap]

# %%
len(ltd_data)
# Out:
# 400

# %%
pd.concat([balanced_data, ltd_data], axis = 1)
# Out:
#           ID ChartNumber EncounterNumber  TriageLevel  AgeNumber  AgeInYrs  \
# 1184    1185    E8443276     EE001185/18          2.0         73     73.00
# 1620    1621    E3111507     EE001622/18          5.0         82     82.00
# 1713    1714    E8216415     EE001716/18          2.0         49     49.00
# 1836    1837    E8152804     EE001838/18          2.0         57     57.00
# 1837    1838    E8181432     EE001839/18          2.0         75     75.00
# 2036    2037    E8513381     EE002038/18          2.0         29     29.00
# 2287    2288    E8526246     EE002289/18          4.0         43     43.00
# 2340    2341    E8557165     EE002343/18          3.0         24     24.00
# 2426    2427    E6203160     EE002429/18          2.0         80     80.00
# 2453    2454    E8576123     EE002455/18          3.0         45     45.00
# 2571    2572    E8576221     EE002574/18          2.0         53     53.00
# 3688    3689    E8576697     EE003692/18          2.0         48     48.00
# 3702    3703    E4062261     EE003706/18          4.0         53     53.00
# 3813    3814    E7514094     EE003820/18          2.0         51     51.00
# 3885    3886    E8576804     EE003892/18          2.0          2      2.00
# 3907    3908    E5203898     EE003914/18          3.0         78     78.00
# 4174    4175    E8569017     EE004180/18          2.0         68     68.00
# 4370    4371    E5146824     EE004376/18          2.0         69     69.00
# 4387    4388    E8577015     EE004393/18          2.0         50     50.00
# 4456    4457    E8342684     EE004462/18          2.0         81     81.00
# 4552    4553    E8577053     EE004558/18          2.0         79     79.00
# 4666    4667    E8245753     EE004673/18          4.0         16     16.00
# 4801    4802    E8297590     EE004808/18          2.0         33     33.00
# 4910    4911    E8073059     EE004917/18          2.0         50     50.00
# 5013    5014    E4817722     EE005020/18          2.0         72     72.00
# 5529    5530    E8465783     EE005536/18          3.0         98     98.00
# 5539    5540    E8459873     EE005546/18          3.0         37     37.00
# 5550    5551    E8577000     EE005557/18          3.0         81     81.00
# 5594    5595    E8240693     EE005601/18          2.0         37     37.00
# 5655    5656    E8559373     EE005662/18          2.0         16      1.33
# ...      ...         ...             ...          ...        ...       ...
# 79780  79781    E8401927     EE079907/18          2.0         64     64.00
# 79792  79793    E8609793     EE079919/18          4.0         57     57.00
# 79973  79974    E8609852     EE080100/18          2.0         82     82.00
# 80178  80179    E7154370     EE080304/18          3.0         59     59.00
# 80603  80604    E8610120     EE080729/18          1.0         60     60.00
# 80755  80756    E8607528     EE080883/18          3.0         60     60.00
# 81078  81079    E6982524     EE081205/18          2.0         56     56.00
# 81125  81126    E7243256     EE081252/18          2.0         56     56.00
# 81221  81222    E8401512     EE081348/18          2.0         24     24.00
# 81321  81322    E8589235     EE081448/18          2.0         67     67.00
# 5529   discharge        1  discharge       1     NaN     NaN
# 5539   discharge        1  discharge       1     NaN     NaN
# 5550      madmit        2      admit       0  madmit     1.0
# 5594   discharge        1  discharge       1     NaN     NaN
# 5655      madmit        2      admit       0  madmit     1.0
# ...          ...      ...        ...     ...     ...     ...
# 79780     madmit        2      admit       0  madmit     1.0
# 79792  discharge        1  discharge       1     NaN     NaN
# 79973        ICU        4      admit       0     ICU     3.0
# 80178  discharge        1  discharge       1     NaN     NaN
# 80603        ICU        4      admit       0  madmit     1.0
# 80755     madmit        2      admit       0  madmit     1.0
# 81078        ICU        4      admit       0  madmit     1.0
# 81125  discharge        1  discharge       1     NaN     NaN
# 81221  discharge        1  discharge       1     NaN     NaN
# 81321     sadmit        3      admit       0  sadmit     2.0
# 81474     madmit        2      admit       0  madmit     1.0
# 82075     madmit        2      admit       0  madmit     1.0
# 82382     madmit        2      admit       0  madmit     1.0
# 82760        ICU        4      admit       0  madmit     1.0
# 83085     madmit        2      admit       0  madmit     1.0
# 83248        ICU        4      admit       0  madmit     1.0
# 83271     sadmit        3      admit       0  sadmit     2.0
# 83555        ICU        4      admit       0  madmit     1.0
# 83681  discharge        1  discharge       1     NaN     NaN
# 83727     sadmit        3      admit       0  sadmit     2.0
# 83875     sadmit        3      admit       0  sadmit     2.0
# 83929        ICU        4      admit       0     ICU     3.0
# 84026  discharge        1  discharge       1     NaN     NaN
# 84135     madmit        2      admit       0  madmit     1.0
# 84367        ICU        4      admit       0  madmit     1.0
# 84415     madmit        2      admit       0  madmit     1.0
# 84478        ICU        4      admit       0     ICU     3.0
# 84509        ICU        4      admit       0  madmit     1.0
# 84577        ICU        4      admit       0     ICU     3.0
# 84818        ICU        4      admit       0     ICU     3.0
#
#                 ICUvsother target5  \
# 1184                   NaN       0
# 1620                   NaN       0
# 1713                   NaN       0
# 1836                   NaN       0
# 1837                   NaN       0
# 2036   INTENSIVE CARE UNIT       1
# 2287                   NaN       0
# 2340                   NaN       0
# 2426   INTENSIVE CARE UNIT       1
# 2453                   NaN       0
# 2571                   NaN       0
# 3688   INTENSIVE CARE UNIT       1
# 3702                   NaN       0
# 3813                   NaN       0
# 3885                   NaN       0
# 3907                   NaN       0
# 4174   INTENSIVE CARE UNIT       1
# 4370                   NaN       0
# 4387   INTENSIVE CARE UNIT       1
# 4456   INTENSIVE CARE UNIT       1
# 4552                   NaN       0
# 4666                   NaN       0
# 4801                   NaN       0
# 4910                   NaN       0
# 5013                   NaN       0
# 5529                   NaN       0
# 5539                   NaN       0
# 5550                   NaN       0
# 5594                   NaN       0
# 5655                   NaN       0
# ...                    ...     ...
# 79780                  NaN       0
# 79792                  NaN       0
# 79973  INTENSIVE CARE UNIT       1
# 80178                  NaN       0
# 80603  INTENSIVE CARE UNIT       1
# 80755                  NaN       0
# 81078  INTENSIVE CARE UNIT       1
# 81125                  NaN       0
# 81221                  NaN       0
# 81321                  NaN       0
# 81474                  NaN       0
# 82075                  NaN       0
# 82382                  NaN       0
# 82760  INTENSIVE CARE UNIT       1
# 83085                  NaN       0
# 83248  INTENSIVE CARE UNIT       1
# 83271                  NaN       0
# 83555  INTENSIVE CARE UNIT       1
# 83681                  NaN       0
# 83727                  NaN       0
# 83875                  NaN       0
# 83929  INTENSIVE CARE UNIT       1
# 84026                  NaN       0
# 84135                  NaN       0
# 84367  INTENSIVE CARE UNIT       1
# 84415                  NaN       0
# 84478  INTENSIVE CARE UNIT       1
# 84509  INTENSIVE CARE UNIT       1
# 84577  INTENSIVE CARE UNIT       1
# 84818  INTENSIVE CARE UNIT       1
#
#                                                     pmhx  \
# 1184    bowel obstruction d/t bowel adhesions, htn, afib
# 1620   diverticulitis, high bp, high cholesterol, thy...
# 1713                            liver and kidney failure
# 1836   htn, diabetic, thyroid, rt total nephrectomy, ...
# 1837                      no significant medical history
# 2036                                     type 1 diabetes
# 2287                                                  pe
# 2340         kidneystones, urethral junction obstruction
# 2426   pea, chf, pulmonary htn, mi, angina, sleep apn...
# 2453                                                gerd
# 2571                      no significant medical history
# 3688   anemia, thyroid, iddm, hypertension, gerd, cir...
# 3702                                             high bp
# 3813   heart problem, was recently diagnosed with hol...
# 3885                      no significant medical history
# 3907   high cholesterol, two stents in kidney every t...
# 4174   copd, chronic bronchitis, home o2 3l np prn, d...
# 4370            altace, breast cancer, uti, hypertension
# 4387                      no significant medical history
# 4456                      no significant medical history
# 4552                 iddm, hypertension, hip replacement
# 4666                      no significant medical history
# 4801                                        htn, anxiety
# 4910                                 hypertension, niddm
# 5013           knee replacement, high cholesterol, niddm
# 5529   atrial fibrillation, anxiety, enlarged prostat...
# 5539                                              anemia
# 5550                                             unknown
# 5594                      no significant medical history
# 5655                      no significant medical history
# ...                                                  ...
# 79780          niddm, high cholesterol, high cholesterol
# 79792                     no significant medical history
# 79973  hypertension, high cholesterol, possible heart...
# 80178                   high bp, high cholesterol, niddm
# 80603                     no significant medical history
# 80755                                  b/p, stent, niddm
# 81078          lap band surgery - removed, kidney stones
# 81125                                  high bp, diabetes
# 81221                     no significant medical history
# 81321                                              niddm
# 81474  niddm, gerd, high bp, stroke, high cholesterol...
# 82075        high chol, niddm, chf, htn, synthetic valve
# 82382                     no significant medical history
# 82760                                         copd, afib
# 83085                 copd, cholesterol, htn, depression
# 83248                     no significant medical history
# 83271                                    htn, cva, osteo
# 83555                                      htn, lymphoma
# 83681                                        hypothyroid
# 83727                     no significant medical history
# 83875                          cabg, hypertension, niddm
# 83929  gerd, hypothyroid, high cholesterol, paralyzed...
# 84026                              htn, high cholesterol
# 84135  gerd, iddm, htn, mi x 7 or 8 times with stents...
# 84367  mental and behavioral problems with communicat...
# 84415                       substance misuse, depression
# 84478               hypertension, high cholesterol, copd
# 84509                                              niddm
# 84577                     no significant medical history
# 84818                     no significant medical history
#
#                                                        1
# 1184   [-1.18588388e-01 -3.62613685e-02  1.71774179e-...
# 1620   [-1.94503769e-01 -8.38923976e-02  5.67541644e-...
# 1713   [-6.44557178e-02  2.12498493e-02 -4.99889851e-...
# 1836   [-1.45752514e-02 -3.72009605e-01  2.15191156e-...
# 1837   [-6.41224608e-02  1.80907622e-02 -2.60267198e-...
#