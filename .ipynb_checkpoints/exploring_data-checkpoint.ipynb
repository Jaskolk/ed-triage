# %% [markdown]
# In this notebook, I'm going to do some experimentation with xgboost on only the real clinical data

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl (103kB)
#     100% |████████████████████████████████| 112kB 3.9MB/s
# menpo 0.8.1 has requirement matplotlib<2.0,>=1.4, but you'll have matplotlib 3.0.2 which is incompatible.
# menpo 0.8.1 has requirement pillow<5.0,>=3.0, but you'll have pillow 5.4.0 which is incompatible.
# menpo 0.8.1 has requirement scipy<1.0,>=0.16, but you'll have scipy 1.2.0 which is incompatible.
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0
# You are using pip version 10.0.1, however version 19.2.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
import sklearn.metrics

# %%
import os
import re
from collections import Counter
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/Users/jjaskolkambp/Desktop/machine learning/my_projects/ed-triage'

# %%
#use this cell when working online
path = '/floyd/home/notebooks'
data_path = '/floyd/home/data'

# %%
os.listdir('/Users/jjaskolkambp/Desktop/machine learning/my_projects/data/ED triage project')
# Out:
# ['bch_data_breakdown.xlsx',
#  '.DS_Store',
#  'first_model.pth',
#  '500_cleaned.csv',
#  'BCH ED visits FY1819_with additions.xlsx',
#  'sample_cleaned.xlsx',
#  'models',
#  'EGH ED visits FY1819_with additions.xlsx',
#  'BERT',
#  '.gitattributes',
#  '.ipynb_checkpoints',
#  '.git',
#  'data',
#  'ed_databunch',
#  'jj_modified_bch_data.xlsx',
#  'clean_sentiment_columns.csv',
#  'bert-temp']

# %%
#use this cell when working from home
path = '/Users/jjaskolkambp/Desktop/machine learning/my_projects/ed-triage'
data_path = '/Users/jjaskolkambp/Desktop/machine learning/my_projects/data/ED triage project'

# %%
clin = pd.read_excel(data_path + '/jj_modified_bch_data.xlsx')

# %%
len(clin)
# Out:
# 136993

# %%
clin.columns
# Out:
# Index(['ID', 'ChartNumber', 'EncounterNumber', 'TriageLevel', 'AgeNumber',
#        'AgeInYrs', 'GenderDesc', 'Triage Date & Time', 'Reg Date & Time',
#        'PIA Date & Time', 'Disposition Date & Time', 'DischargeDisposition',
#        'DischargeDispositionDesc', 'Left ED Date & Time',
#        'PresentingComplaint', 'PresentingComplaintDesc', 'MainDiagnosisCode',
#        'MainDiagnosisCodeDesc', 'AdmitLocation', 'PatientService',
#        'SubjectiveNotes', 'InfectionControlScreening', 'MedicalHistory',
#        'BloodPressure_LastEDReading', 'O2Saturation_LastEDReading',
#        'Pulse_LastEDReading', 'Temperature_LastEDReading',
#        'Are you feeling feverish or have had shakes or chills in the last 24 hours?',
#        'Have you ever been isolated/required isolation for an infectious disease when receiving care in a healthcare setting?',
#        'Do you have a new Rash?',
#        'Do you have a new onset of Vomiting/Diarrhea in the last 24 hours?',
#        'Have you travelled outside of Canada/USA in the last 3 weeks?',
#        'Have you had contact with a sick person who has travelled outside of Canada/USA in the last 3 weeks?',
#        'Have you received Health Care in another country in the last 2 years?',
#        'Do you have a new/worse cough or shortness of breath?',
#        'If so, select all countries that apply',
#        'If so, select all infectious diseases that apply'],
#       dtype='object')

# %%
discharge_count = Counter(clin['DischargeDisposition']); discharge_count
# Out:
# Counter({17: 112819,
#          62: 398,
#          7: 15740,
#          16: 628,
#          63: 2165,
#          6: 1173,
#          13: 1731,
#          72: 191,
#          8: 286,
#          30: 573,
#          90: 42,
#          40: 486,
#          61: 88,
#          64: 547,
#          12: 91,
#          14: 27,
#          9: 6,
#          71: 2})

# %%
discharge_count2 = Counter(clin['DischargeDispositionDesc']); discharge_count2
# Out:
# Counter({'Discharge to private home, condo, apt without support service/referral': 112819,
#          'Left at his/her own risk post-initial treatment': 398,
#          'Admit to reporting facility as inpatient to another unit from amb care': 15740,
#          'Discharge to private home, condo, apt with support service/referral': 628,
#          'Left After Triage': 2165,
#          'Admit to reporting facility as inpatient to SCU or OR from amb care': 1173,
#          'Intra-facility transfer to ED': 1731,
#          'Died in Facility': 191,
#          'Transfer to another acute care facility directly from amb care': 286,
#          'Transfer to Residential care': 573,
#          'Transfer to correctional facility': 42,
#          'Transfer to Group/supportive living': 486,
#          'Left at his/her own risk following registration': 88,
#          'Left After Initial Assessment': 547,
#          'Intra-facility transfer to day surgery': 91,
#          'Intra-facility transfer to clinic': 27,
#          'Transfer to another non-acute care facility directly from amb care': 6,
#          'Dead on arrival': 2})

# %%
triage_count = Counter(clin['TriageLevel'])
triage_count
# Out:
# Counter({3.0: 73424,
#          2.0: 43936,
#          4.0: 14091,
#          1.0: 1472,
#          5.0: 3980,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1})

# %%
comp_count = Counter(clin['PatientService']); comp_count
# Out:
# Counter({nan: 120106,
#          'General Surgery': 1452,
#          'Respirology': 895,
#          'General Medicine': 6091,
#          'INTENSIVE CARE UNIT': 454,
#          'Cardiology': 2678,
#          'Oncology': 491,
#          'Palliative': 170,
#          'AD PALLIATIVE': 48,
#          'Genitourinary': 688,
#          'Paediatrics': 1248,
#          'Mental Health': 596,
#          'Orthopaedics': 352,
#          'MH Child & Adolescent': 390,
#          'AD Oncology': 9,
#          'Neurology': 583,
#          'ALC General Medicine': 211,
#          'ALC General Surgery': 35,
#          'Acute Care for Elders': 62,
#          'ALC Neurology': 93,
#          'ALC Cardiology': 86,
#          'ALC Respirology': 29,
#          'ALC Orthopaedics': 145,
#          'Neonatal Retro Transfers': 4,
#          'Newborn': 4,
#          'Obstetrics': 32,
#          'ALC Oncology': 9,
#          'AD General Medicine': 6,
#          'AD Acute Care for Elders': 3,
#          'AD Respirology': 2,
#          'ALC ACUTE CARE FOR EDLERS': 5,
#          'AD Cardiology': 2,
#          'AD Neurology': 3,
#          'ALC Palliative': 10,
#          'AD General Surgery': 1})

# %%
clin['service'] = clin['PatientService'].astype('str').map(
    {'nan': 'discharge',
         'General Surgery': 'sadmit',
         'Respirology': 'madmit',
         'General Medicine': 'madmit',
         'INTENSIVE CARE UNIT': 'ICU',
         'Cardiology': 'madmit',
         'Oncology': 'madmit',
         'Palliative': 'madmit',
         'AD PALLIATIVE': 'madmit',
         'Genitourinary': 'sadmit',
         'Paediatrics': 'madmit',
         'Mental Health': 'madmit',
         'Orthopaedics': 'sadmit',
         'MH Child & Adolescent': 'madmit',
         'AD Oncology': 'madmit',
         'Neurology': 'madmit',
         'ALC General Medicine': 'madmit',
         'ALC General Surgery': 'sadmit',
         'Acute Care for Elders': 'madmit',
         'ALC Neurology': 'madmit',
         'ALC Cardiology': 'madmit',
         'ALC Respirology': 'madmit',
         'ALC Orthopaedics': 'madmit',
         'Neonatal Retro Transfers': 'madmit',
         'Newborn': 'madmit',
         'Obstetrics': 'madmit',
         'ALC Oncology': 'madmit',
         'AD General Medicine': 'madmit',
         'AD Acute Care for Elders': 'madmit',
         'AD Respirology': 'madmit',
         'ALC ACUTE CARE FOR EDLERS': 'madmit',
         'AD Cardiology': 'madmit',
         'AD Neurology': 'madmit',
         'ALC Palliative': 'madmit',
         'AD General Surgery': 'sadmit'})

# %%
service_count = Counter(clin['service'])
service_count
# Out:
# Counter({'discharge': 120106, 'sadmit': 2528, 'madmit': 13905, 'ICU': 454})

# %%
clin['target2'] = clin['service'].map({'discharge': 1, 'madmit': 2, 'sadmit': 3, 'ICU': 4})

# %%
o2sat = [item if item[-1] != '%' else item[:-1] for item in clin['O2Saturation_LastEDReading'].astype('str')]
o2sat = [np.nan if item == 'nan' else float(item) for item in o2sat] 
clin['o2sat'] = o2sat

# %%
pulse = clin['Pulse_LastEDReading']
pulse = [re.sub("[^0-9]", "", str(item)) for item in pulse]
pulse = [np.nan if item == '' else float(item) for item in pulse] 
#set(pulse)
clin['pulse'] = pulse

# %%
temp = clin['Temperature_LastEDReading']
temp = [re.sub("[^0-9]", "", str(item)) for item in temp]
temp = [np.nan if item == '' else float(item) for item in temp] 
temp = [item/10 if item > 100 else item for item in temp]
temp = [np.nan if item > 40  else item for item in temp]
#set(temp)
clin['temp'] = temp

# %% [markdown]
# **bptrans** parses the blood pressure column into systolic and diastolic, **fixencode** does some preprocessing on text

# %%
def bptrans(bp):
    if pd.isnull(bp):
        return [np.nan, np.nan]
    res = []
    for x in bp.split('/'):
        try:
            float(x)
            res =  [float(x) for x in bp.split('/')]
        except: 
            res =  [np.nan, np.nan]
        return res

def fixencode(s):
    if pd.isnull(s):
        s = "None"
    s=s.replace('<LT><LF>',',')
    s=s.replace('Pt.', 'patient')
    s=s.replace('Pt', 'patient')
    s= s.replace('pt.', 'patient')
    s=s.replace('pt', 'patient')
    s = s.replace('y/o', 'year old')
    s = s.replace('c/o', 'complains of')
    s = s.replace('C/o', 'complains of')
    return s

# %%
clin['BP'] = clin.BloodPressure_LastEDReading.map(bptrans)
clin[['systolic', 'diastolic']] = pd.DataFrame(clin.BP.tolist(), index= clin.index)
clin["Gender"] = clin.GenderDesc.map(lambda x: 1 if x == "Male" else 0)

# %%
inf_screen_df = clin[[
    'Are you feeling feverish or have had shakes or chills in the last 24 hours?',
       'Have you ever been isolated/required isolation for an infectious disease when receiving care in a healthcare setting?',
       'Do you have a new Rash?',
       'Do you have a new onset of Vomiting/Diarrhea in the last 24 hours?',
       'Have you travelled outside of Canada/USA in the last 3 weeks?',
       'Have you had contact with a sick person who has travelled outside of Canada/USA in the last 3 weeks?',
       'Have you received Health Care in another country in the last 2 years?',
       'Do you have a new/worse cough or shortness of breath?',
       'If so, select all countries that apply',
       'If so, select all infectious diseases that apply']]

# %%
subj_df = clin[['MedicalHistory','SubjectiveNotes']]

# %%
tab_df = clin[['ID', 'TriageLevel',
       'AgeInYrs', 'GenderDesc', 'DischargeDisposition',
       'PresentingComplaint', 'PresentingComplaintDesc', 'AdmitLocation', 'PatientService',
       'BloodPressure_LastEDReading','systolic', 'diastolic','temp','pulse','o2sat']]
        #'O2Saturation_LastEDReading', 'Pulse_LastEDReading', 'Temperature_LastEDReading']]

# %%
admit_count= Counter(clin['AdmitLocation']); admit_count
# Out:
# Counter({nan: 120106,
#          'N.SUR GEN': 1024,
#          'N.MED CARD': 1738,
#          'N.ER IN': 1186,
#          'N.MED SIX': 604,
#          'N.CC ICU': 455,
#          'N.CC CCU': 584,
#          'N.MED ONC': 1024,
#          'N.MAU': 2365,
#          'N.SIMCU': 301,
#          'N.MED CPU': 329,
#          'N.MED GER': 1070,
#          'N.MED CT': 144,
#          'N.WC PAED': 1291,
#          'N.ERMH IN': 29,
#          'N.MED SIM': 450,
#          'N.SUR ORTH': 661,
#          'N.MH CHADI': 152,
#          'N.MH GER': 68,
#          'N.MH GENB': 217,
#          'N.MH INTEN': 234,
#          'N.MED RESP': 944,
#          'N.MED NEUR': 921,
#          'N.SUR SS': 582,
#          'N.MH CHAD': 210,
#          'N.WC POST': 119,
#          'N.MH GENC': 47,
#          'N.MED DIAL': 48,
#          'N.CC NICU': 5,
#          'N.WC LD': 2,
#          'N.WC LDN': 1,
#          'N.MAIN OR': 1,
#          'N.MED STTU': 1,
#          'N.MED FLEX': 10,
#          'N.MED DSU': 69,
#          'N.SUR DSU': 1})

# %%
clin['outcome'] = clin['AdmitLocation'].astype('str').map(
{'N.CC CCU': 'ICU',
 'N.CC ICU': 'ICU',
 'N.ER IN' : 'madmit',
 'N.ERMH IN': 'madmit',
 'N.MAU': 'madmit',
 'N.MED CARD': 'madmit',
 'N.MED CPU': 'madmit',
 'N.MED CT': 'madmit',
 'N.MED GER': 'madmit',
 'N.MED DIAL': 'madmit',
 'N.MED NEUR': 'madmit',
 'N.MED ONC': 'madmit',
 'N.MED RESP': 'madmit',
 'N.MED SIM': 'madmit',
 'N.MED SIX': 'madmit',
 'N.MH CHAD': 'madmit',
 'N.MH CHADI': 'madmit',
 'N.MH GENB': 'madmit',
 'N.MH GER': 'madmit',
 'N.MH INTEN': 'madmit',
 'N.SIMCU': 'ICU',
 'N.SUR GEN': 'sadmit',
 'N.SUR ORTH': 'sadmit',
 'N.SUR SS': 'sadmit',
 'N.WC PAED': 'madmit',
 'N.WC POST': 'madmit',
 'N.MH GENC': 'madmit',
 'N.CC NICU': 'ICU',
 'N.WC LD': 'sadmit',
  'N.WC LDN': 'sadmit',
  'N.MAIN OR': 'sadmit',
  'N.MED STTU': 'madmit',
  'N.MED FLEX': 'madmit',
    'N.MED DSU': 'madmit',
    'N.SUR DSU': 'sadmit',
 'nan': 'discharge'})

# %%
clin['target'] = clin['outcome'].map({'discharge': 1, 'madmit': 2, 'sadmit': 3, 'ICU': 4})

# %%
outcome_count = Counter(clin['outcome']); outcome_count
# Out:
# Counter({'discharge': 120106, 'sadmit': 2272, 'madmit': 13270, 'ICU': 1345})

# %%
target_count = Counter(clin['target']); target_count
# Out:
# Counter({1: 120106, 3: 2272, 2: 13270, 4: 1345})

# %%
target2_count = Counter(clin['target2']); target2_count
# Out:
# Counter({1: 120106, 3: 2528, 2: 13905, 4: 454})

# %%
out_dict = {'discharge': 1, 'madmit': 2, 'sadmit': 3, 'ICU': 4}
out_dict = {v:k for k,v in out_dict.items()}
out_dict
# Out:
# {1: 'discharge', 2: 'madmit', 3: 'sadmit', 4: 'ICU'}

# %%
clin['discharge'] = clin['outcome'].map({'discharge': 1, 'madmit': 0, 'sadmit': 0, 'ICU': 0})

# %%
clin['dispo']= clin['outcome'].map({'discharge': np.nan, 'madmit': 1, 'sadmit': 2, 'ICU': 3})

# %% [markdown]
# Now we are going to split stuff up into features and train some models

# %%
features_ltd = clin[['systolic', 'diastolic', 'pulse', 'o2sat', 'temp', 'AgeInYrs', 'Gender']]
features = clin[['systolic', 'diastolic', 'pulse', 'o2sat', 'temp', 'AgeInYrs', 'Gender', 'PresentingComplaint', 'TriageLevel']]

# %%
target2 = clin['target2']
target1 = clin['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target1) #, random_state=1)
xgc = xgb.XGBClassifier()
xgc.fit(X_train, y_train)
preds = xgc.predict(X_test)
conf = confusion_matrix(y_test, preds); conf
# Out:
# array([[29754,   310,     0,     2],
#        [ 2593,   690,     0,     4],
#        [  504,    59,     0,     0],
#        [  232,    96,     0,     5]])

# %%
f1_w = sklearn.metrics.f1_score(y_test, preds, average='weighted')
f1 = sklearn.metrics.f1_score(y_test, preds, average=None)
acc = sklearn.metrics.accuracy_score(y_test, preds)
prec = sklearn.metrics.precision_score(y_test,preds, average = None)
rec = sklearn.metrics.recall_score(y_test,preds, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.8573485764818736
# f1:           [0.94234271 0.31067087 0.         0.02906977]
# accuracy:     0.8890478554118368
# precision:    [0.8993743  0.5974026  0.         0.45454545]
# recall:       [0.98962283 0.20991786 0.         0.01501502]
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
target_dict = {'discharge': 1, 'madmit': 2, 'sadmit': 3, 'ICU': 4}

# %%
LABELS = target_dict.keys()  #['admit', 'discharge'] #lab_count.keys()

plt.figure(figsize=(5, 5))
sns.heatmap(conf, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %% [markdown]
# So, now we are going to try the same but with different method for determining target

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target2) #, random_state=1)
xgc = xgb.XGBClassifier()
xgc.fit(X_train, y_train)
preds = xgc.predict(X_test)
conf = confusion_matrix(y_test, preds); conf
# Out:
# array([[29627,   372,     0,     0],
#        [ 2642,   806,     0,     0],
#        [  631,    57,     0,     0],
#        [   77,    37,     0,     0]])

# %%
f1_w = sklearn.metrics.f1_score(y_test, preds, average='weighted')
f1 = sklearn.metrics.f1_score(y_test, preds, average=None)
acc = sklearn.metrics.accuracy_score(y_test, preds)
prec = sklearn.metrics.precision_score(y_test,preds, average = None)
rec = sklearn.metrics.recall_score(y_test,preds, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.8585238214388159
# f1:           [0.94089812 0.34152542 0.         0.        ]
# accuracy:     0.8885806884872551
# precision:    [0.89841405 0.6336478  0.         0.        ]
# recall:       [0.98759959 0.2337587  0.         0.        ]

# %%
LABELS = target_dict.keys()  #['admit', 'discharge'] #lab_count.keys()

plt.figure(figsize=(5, 5))
sns.heatmap(conf, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %%
#check for overfitting
preds = xgc.predict(X_train)
conf = confusion_matrix(y_train, preds); conf
# Out:
# array([[89174,   971,     0,     0],
#        [ 7854,  2512,     0,     0],
#        [ 1691,   193,     0,     0],
#        [  243,   106,     0,     0]])

# %% [markdown]
# What follows is going to be some work on hyperparameter selection and tuning as the model is underfitting

# %%
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import cross_validate, GridSearchCV   #Additional scklearn functions
#from sklearn.grid_search import GridSearchCV 
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4

# %%
clin.columns
# Out:
# Index(['ID', 'ChartNumber', 'EncounterNumber', 'TriageLevel', 'AgeNumber',
#        'AgeInYrs', 'GenderDesc', 'Triage Date & Time', 'Reg Date & Time',
#        'PIA Date & Time', 'Disposition Date & Time', 'DischargeDisposition',
#        'DischargeDispositionDesc', 'Left ED Date & Time',
#        'PresentingComplaint', 'PresentingComplaintDesc', 'MainDiagnosisCode',
#        'MainDiagnosisCodeDesc', 'AdmitLocation', 'PatientService',
#        'SubjectiveNotes', 'InfectionControlScreening', 'MedicalHistory',
#        'BloodPressure_LastEDReading', 'O2Saturation_LastEDReading',
#        'Pulse_LastEDReading', 'Temperature_LastEDReading',
#        'Are you feeling feverish or have had shakes or chills in the last 24 hours?',
#        'Have you ever been isolated/required isolation for an infectious disease when receiving care in a healthcare setting?',
#        'Do you have a new Rash?',
#        'Do you have a new onset of Vomiting/Diarrhea in the last 24 hours?',
#        'Have you travelled outside of Canada/USA in the last 3 weeks?',
#        'Have you had contact with a sick person who has travelled outside of Canada/USA in the last 3 weeks?',
#        'Have you received Health Care in another country in the last 2 years?',
#        'Do you have a new/worse cough or shortness of breath?',
#        'If so, select all countries that apply',
#        'If so, select all infectious diseases that apply', 'service',
#        'target2', 'target', 'o2sat', 'pulse', 'temp', 'BP', 'systolic',
#        'diastolic', 'Gender', 'outcome', 'discharge', 'dispo'],
#       dtype='object')

# %%
target_df = clin[['service','target2', 'target', 'outcome', 'discharge', 'dispo']]

# %%
target_df.to_csv(data_path  + '/targets.csv')

# %%
inf_screen_df.to_csv(data_path + '/inf_control_data.csv')

# %%
subj_df.to_csv(data_path + '/subj_data.csv')

# %%
tab_df.to_csv(data_path + '/tabular_data.csv')

# %%
med_hx = subj_df['MedicalHistory']

# %%
histories = Counter(clin['MedicalHistory']); histories
# Out:
# Counter({nan: 14782,
#          '^c^^^^ctasMEHPL=No Significant Medical History': 46276,
#          '^c^^^^ctasMEHPL=Substance Misuse': 397,
#          '^c^^^^ctasMEHPL=ACS (Acute Coronary Syndrome)<LT>LF>MI (Myocardial Infarction)<LT>LF>triple a repair<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>bronchiectasis': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)': 2813,
#          '^c^^^^ctasMEHPL=Seizure<LT>LF>Asthma<LT>LF>palpitations<LT>LF>leaky hrt valve': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Gerd<LT>LF>Chronic Back Pain': 1,
#          '^c^^^^ctasMEHPL=Dialysis Haemo/PD<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>CRF (Chronic Renal Failure)<LT>LF>heart problem<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Fibromyalgia': 48,
#          '^c^^^^ctasMEHPL=enlarged liver': 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>Autistic<LT>LF>ADHD (Attention Deficit Hyperactivity Disorder)<LT>LF>Depression<LT>LF>Asthma<LT>LF>Celiac': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)': 359,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>TIA (Transient Ischemic Attack)<LT>LF>Arthritis<LT>LF>Glaucoma<LT>LF>Dementia<LT>LF>CVA (Cerebral vascular Accident)': 1,
#          '^c^^^^ctasMEHPL=Bladder Cancer<LT>LF>Hypertension (HTN)<LT>LF>MI (Myocardial Infarction)<LT>LF>stents,borderline dm': 1,
#          '^c^^^^ctasMEHPL=ca colon with bowel resection<LT>LF>Received Chemotherapy within 4 weeks': 1,
#          '^c^^^^ctasMEHPL=Hypothyroid': 724,
#          '^c^^^^ctasMEHPL=tb carrier, hep c<LT>LF>Substance Misuse': 1,
#          '^c^^^^ctasMEHPL=Anxiety': 708,
#          '^c^^^^ctasMEHPL=Neuropathy': 6,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Schizophrenia<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Gerd<LT>LF>KNEE SURGERY': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol': 866,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>SBO/LBO (Small/Large Bowel Obstruction)': 1,
#          '^c^^^^ctasMEHPL=Arthritis<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)': 4,
#          '^c^^^^ctasMEHPL=ITP, Wiscott-Aldridge Syndrome <LT>LF>Eczema': 1,
#          '^c^^^^ctasMEHPL=Suicidal attempts <LT>LF>Depression': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>CABG<LT>LF>L knee surgery 15 years ago': 1,
#          '^c^^^^ctasMEHPL=sepsis<LT>LF>UTI<LT>LF>Ca lungs <LT>LF>ca bronchus<LT>LF>Hypothyroid<LT>LF>Glaucoma Cataract/Cataract Repair<LT>LF>kidney disease<LT>LF>Anemia': 1,
#          '^c^^^^ctasMEHPL=Alcoholism': 128,
#          '^c^^^^ctasMEHPL=Eczema': 189,
#          '^c^^^^ctasMEHPL=Gerd<LT>LF>High Cholesterol': 6,
#          '^c^^^^ctasMEHPL=mental Health': 1,
#          '^c^^^^ctasMEHPL=hypertension, TIA, Osteoporosis, diverticulitis, high cholesterol, anxiety, depression<LT>LF>Aortic Stenosis': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>arrythmia?<LT>LF>Anxiety': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>tooth infection': 2,
#          '^c^^^^ctasMEHPL=MI (Myocardial Infarction)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>CVA (Cerebral vascular Accident)<LT>LF>angioplasty<LT>LF>recent UTI<LT>LF>fused c3,4 6,7 due to accident 2016': 1,
#          '^c^^^^ctasMEHPL=Chronic Back Pain<LT>LF>High Cholesterol': 5,
#          '^c^^^^ctasMEHPL=CHF (Congestive Heart Failure)<LT>LF>Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 2,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 186,
#          '^c^^^^ctasMEHPL=Asthma': 2000,
#          '^c^^^^ctasMEHPL=Paraplegia<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>anxiety': 3,
#          '^c^^^^ctasMEHPL=OTC': 1,
#          '^c^^^^ctasMEHPL=unknown': 109,
#          '^c^^^^ctasMEHPL=COPD, Depression, Hypertension': 1,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>Dementia<LT>LF>Hypertension (HTN)<LT>LF>frequent UTI<LT>LF>Gerd': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Hypothyroid<LT>LF>Osteoporosis<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hysterectomy': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>Glaucoma': 1,
#          '^c^^^^ctasMEHPL=Benign Prostatic Hypertension<LT>LF>Asthma<LT>LF>hx of lung CA': 1,
#          '^c^^^^ctasMEHPL=unkown': 2,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 258,
#          '^c^^^^ctasMEHPL=polymyocitis <LT>LF>Arthritis<LT>LF>Fibromyalgia<LT>LF>blood clots': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>prolapse rectum': 1,
#          '^c^^^^ctasMEHPL=kidney infection<LT>LF>fatty liver<LT>LF>Paraplegia': 1,
#          '^c^^^^ctasMEHPL=CAD (Coronary Artery Disease)<LT>LF>Hypertension (HTN)<LT>LF>Hypothyroid<LT>LF>CVA (Cerebral vascular Accident)<LT>LF>Depression<LT>LF>Glaucoma<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>UTI<LT>LF>Anemia': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Diabetes': 38,
#          "^c^^^^ctasMEHPL=Arthritis<LT>LF>Benign Prostatic Hypertension<LT>LF>Osteoporosis<LT>LF>Parkinson's<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>CAD (Coronary Artery Disease)<LT>LF>CVA (Cerebral vascular Accident)": 1,
#          '^c^^^^ctasMEHPL=Seizure<LT>LF>Hypothyroid<LT>LF>Hippocampus removal': 1,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Respiratory Issues': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>Diabetes': 1,
#          "^c^^^^ctasMEHPL=Asthma<LT>LF>Hypertension (HTN)<LT>LF>Parkinson's": 1,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Anemia': 7,
#          '^c^^^^ctasMEHPL=HTN, HIGH CHOL': 3,
#          '^c^^^^ctasMEHPL=Pacemaker/Cardioverter/Defib<LT>LF>Hypertension (HTN)<LT>LF>Arthritis<LT>LF>Atrial Fibrillation (A Fib)<LT>LF>CRF (Chronic Renal Failure)': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>hepatomegaly': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Dementia<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>Pacemaker/Cardioverter/Defib': 1,
#          '^c^^^^ctasMEHPL=stent<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Benign Prostatic Hypertension': 1,
#          '^c^^^^ctasMEHPL=Substance Misuse<LT>LF>Depression<LT>LF>Anxiety<LT>LF>suicide attempts': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 845,
#          '^c^^^^ctasMEHPL=MS (Multiple Sclerosis)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Seizure<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=CRF (Chronic Renal Failure)<LT>LF>Dialysis Haemo/PD<LT>LF>colon ca <LT>LF>Diabetes<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 79,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Depression': 13,
#          '^c^^^^ctasMEHPL=Acid Reflux': 308,
#          '^c^^^^ctasMEHPL=Rheumatoid Arthritis<LT>LF>Depression': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol<LT>LF>Diabetes<LT>LF>Gerd': 1,
#          '^c^^^^ctasMEHPL=ASTHMA<LT>LF>THRYROID<LT>LF>GERD<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=SKIN INFECTION': 1,
#          '^c^^^^ctasMEHPL=Chronic Back Pain': 138,
#          '^c^^^^ctasMEHPL=heart problem<LT>LF>Acid Reflux<LT>LF>CHF (Congestive Heart Failure)<LT>LF>Glaucoma<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=PARTIAL COLON REMOVAL<LT>LF>Ulcerative Colitis': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Gout': 26,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 46,
#          '^c^^^^ctasMEHPL=Prostate Cancer<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 3,
#          '^c^^^^ctasMEHPL=Seizure<LT>LF>ETOH Abuse<LT>LF>Smoker<LT>LF>Diabetes<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>High BP<LT>LF>High Cholesterol<LT>LF>Enlarged Prostate<LT>LF>LT KIDNEY REMOVED<LT>LF>KIDNEY CANCER<LT>LF>STENT X 2': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High BP': 6,
#          '^c^^^^ctasMEHPL=SEIZURE<LT>LF>Hepatitis C': 1,
#          '^c^^^^ctasMEHPL=Depression': 984,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Hypertension (HTN)<LT>LF>prostate issues': 1,
#          '^c^^^^ctasMEHPL=LOW IRON': 16,
#          '^c^^^^ctasMEHPL=colon cancer<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>MS (Multiple Sclerosis)': 1,
#          '^c^^^^ctasMEHPL=kiney stone': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol': 269,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Anxiety<LT>LF>Asthma': 7,
#          '^c^^^^ctasMEHPL=Dialysis Haemo/PD<LT>LF>Diabetes<LT>LF>Hypertension (HTN)<LT>LF>Depression<LT>LF>High Cholesterol<LT>LF>CRF (Chronic Renal Failure)<LT>LF>gastrities<LT>LF>Sarcoidosis': 1,
#          '^c^^^^ctasMEHPL=TIA (Transient Ischemic Attack)': 16,
#          '^c^^^^ctasMEHPL=High Cholesterol': 919,
#          '^c^^^^ctasMEHPL=STENTS<LT>LF>Thyroid': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Thyroid': 2,
#          '^c^^^^ctasMEHPL=bronchitis when younger': 1,
#          '^c^^^^ctasMEHPL=bp, acid reflux,': 1,
#          '^c^^^^ctasMEHPL=ANXIETY,DEPRESSION,SLEEP APNEA': 1,
#          '^c^^^^ctasMEHPL=HTN,HYPERLIPIDEMIA,CATARACT,HYPOTHYROIDISM': 1,
#          '^c^^^^ctasMEHPL=Glaucoma Cataract/Cataract Repair<LT>LF>Osteoporosis<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Anxiety': 289,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>Gerd<LT>LF>Constipation<LT>LF>STENT X 1<LT>LF>MI (Myocardial Infarction)': 1,
#          '^c^^^^ctasMEHPL=Osteoporosis<LT>LF>Dementia<LT>LF>Aortic Stenosis<LT>LF>Hypertension (HTN)<LT>LF>CVA (Cerebral vascular Accident)<LT>LF>Glaucoma Cataract/Cataract Repair<LT>LF>Hearing Impaired': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>High Cholesterol<LT>LF>High BP<LT>LF>CVA (Cerebral vascular Accident)<LT>LF>VISION LOSS TO LT EYE': 1,
#          '^c^^^^ctasMEHPL=ACNE': 2,
#          '^c^^^^ctasMEHPL=Diabetes': 328,
#          '^c^^^^ctasMEHPL=none': 4,
#          '^c^^^^ctasMEHPL=DVT (Deep Vein Thrombosis)<LT>LF>Hypothyroid<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Chronic Pain': 1,
#          '^c^^^^ctasMEHPL=Anemia': 344,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>DIET CONTROLLED DIABETETS': 1,
#          '^c^^^^ctasMEHPL=strep throat': 9,
#          '^c^^^^ctasMEHPL=htn,high cholesterol,anemia,arthritis,cardiac,anxiety': 1,
#          '^c^^^^ctasMEHPL=kidney disease<LT>LF>CHF (Congestive Heart Failure)<LT>LF>Pacemaker/Cardioverter/Defib<LT>LF>diet control diabetic<LT>LF>skin cancer<LT>LF>Hypertension (HTN)<LT>LF>Gout<LT>LF>Glaucoma<LT>LF>Asthma<LT>LF>low platelets<LT>LF>low blood cells<LT>LF>Depression<LT>LF>Sleep Apnea': 1,
#          '^c^^^^ctasMEHPL=myo facial pain syndrome,fibromyalgia,scoliosis,arthritis neck/spine,bulging disc, depression/anxiety,chronic pain': 1,
#          '^c^^^^ctasMEHPL=CHRONIC PAIN POST MVC': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>No Significant Medical History': 290,
#          '^c^^^^ctasMEHPL=Bypass Surgery<LT>LF>Enlarged Prostate<LT>LF>High BP<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Aortic Stenosis<LT>LF>no more aota': 1,
#          '^c^^^^ctasMEHPL=substance abuse': 8,
#          '^c^^^^ctasMEHPL=memory loss, anuerysm,high cholesterol,htn,iddm': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Diabetes<LT>LF>High Cholesterol': 39,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>cyst kidney <LT>LF>CABG': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Hypertension (HTN)<LT>LF>Thyroid<LT>LF>Depression': 1,
#          '^c^^^^ctasMEHPL=SKIN CANCER WITH METS<LT>LF>High BP<LT>LF>Hearing Impaired': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol<LT>LF>Diabetes<LT>LF>STENT X1 2009<LT>LF>MI (Myocardial Infarction)': 1,
#          '^c^^^^ctasMEHPL=STENTS<LT>LF>BORDERLINE DIABETES<LT>LF>Hypertension (HTN)<LT>LF>Chronic Back Pain': 1,
#          '^c^^^^ctasMEHPL=CHEMO MDS<LT>LF>High Cholesterol<LT>LF>LOW PLATLETS': 1,
#          '^c^^^^ctasMEHPL=IRON PILLS': 1,
#          '^c^^^^ctasMEHPL=kidney problem<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=GERD <LT>LF>PTSD (Post Traumatic Stress Disorder)<LT>LF>BULIMA': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Dementia': 1,
#          '^c^^^^ctasMEHPL=heart problems with valves?<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Thyroid': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Diabetes<LT>LF>High Cholesterol<LT>LF>ANGIOPLASTY': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>VALVE REPLACEMENT': 1,
#          '^c^^^^ctasMEHPL=LOW BP': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Hypertension (HTN)': 81,
#          '^c^^^^ctasMEHPL=neontal jaudice <LT>LF>low  sugar': 1,
#          '^c^^^^ctasMEHPL=Bi-Polar<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 3,
#          '^c^^^^ctasMEHPL=WOLF HIRSCHORN SYNDROME': 1,
#          '^c^^^^ctasMEHPL=Diverticulitis<LT>LF>ABLASION 2014<LT>LF>PSORISIS': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol<LT>LF>CAD (Coronary Artery Disease)<LT>LF>STENT X 4': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 2,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Metformin': 1,
#          '^c^^^^ctasMEHPL=TYPE 2 DIABETES<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=High BP': 856,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>PROSTRATE CA': 1,
#          '^c^^^^ctasMEHPL=bp, depression': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)': 62,
#          '^c^^^^ctasMEHPL=dialysis,htn,high cholesterol,diabetes,anemia,arthritis': 1,
#          '^c^^^^ctasMEHPL=Peptic Ulcer': 13,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Lymphoma<LT>LF>LOW BONE DESNITY<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=iron dificiency': 1,
#          '^c^^^^ctasMEHPL=asthma': 157,
#          '^c^^^^ctasMEHPL=Arthritis': 198,
#          '^c^^^^ctasMEHPL=DVT (Deep Vein Thrombosis)<LT>LF>Diabetes<LT>LF>Hypertension (HTN)<LT>LF>gallstone': 1,
#          '^c^^^^ctasMEHPL=SHERMAN KYPHOSIS': 1,
#          '^c^^^^ctasMEHPL=Hypothyroid<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)': 2,
#          '^c^^^^ctasMEHPL=Hypothyroid<LT>LF>Depression': 13,
#          '^c^^^^ctasMEHPL=ADHD (Attention Deficit Hyperactivity Disorder)<LT>LF>FETAL ALCOHOL SYNDROME': 1,
#          '^c^^^^ctasMEHPL=G4P2<LT>LF>4 DAYS POST PARTUM': 1,
#          '^c^^^^ctasMEHPL=CRF (Chronic Renal Failure)<LT>LF>Hypothyroid<LT>LF>Hypertension (HTN)<LT>LF>Anemia<LT>LF>Atrial Fibrillation (A Fib)<LT>LF>Colitis<LT>LF>CHF (Congestive Heart Failure)': 1,
#          '^c^^^^ctasMEHPL=Dementia<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol': 2,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Thyroid': 13,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>CHF (Congestive Heart Failure)<LT>LF>?cardiac arrythmia<LT>LF>Dementia': 1,
#          "^c^^^^ctasMEHPL=Hypothyroid<LT>LF>Bartholin's cyst": 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Thyroid': 75,
#          '^c^^^^ctasMEHPL=Bypass Surgery<LT>LF>Hypertension (HTN)<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Thyroid<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Rheumatoid Arthritis<LT>LF>angioplasty<LT>LF>MI (Myocardial Infarction)<LT>LF>Vertigo<LT>LF>Anxiety<LT>LF>Gout<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>Dementia': 3,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol': 152,
#          '^c^^^^ctasMEHPL=bilateral leg amputee<LT>LF>Hypertension (HTN)<LT>LF>Gout<LT>LF>High Cholesterol<LT>LF>Atrial Fibrillation (A Fib)<LT>LF>renal dialysis<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>CHF (Congestive Heart Failure)<LT>LF>atherosclerotic heart disease': 1,
#          '^c^^^^ctasMEHPL=Schizophrenia<LT>LF>Hypothyroid<LT>LF>Sleep Apnea': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Smoker<LT>LF>MI (Myocardial Infarction)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=deaf<LT>LF>kidney disease<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol': 1,
#          "^c^^^^ctasMEHPL=Alzheimer's": 22,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Hypertension (HTN)<LT>LF>uterine polyps<LT>LF>Anemia': 1,
#          '^c^^^^ctasMEHPL=# rt rib': 1,
#          '^c^^^^ctasMEHPL=angioplasty': 2,
#          "^c^^^^ctasMEHPL=chronn's disease": 1,
#          '^c^^^^ctasMEHPL=GERD (Gastroesophageal Reflux Disease)': 112,
#          '^c^^^^ctasMEHPL=Acid Reflux<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>MI (Myocardial Infarction)<LT>LF>Gerd<LT>LF>chest infection': 1,
#          '^c^^^^ctasMEHPL=Hypothyroid<LT>LF>Anxiety': 8,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>Hernia': 1,
#          '^c^^^^ctasMEHPL=Gout<LT>LF>Enlarged Prostate<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>CHF (Congestive Heart Failure)<LT>LF>GERD (Gastroesophageal Reflux Disease)': 1,
#          '^c^^^^ctasMEHPL=polycystic tumor - 2003': 1,
#          '^c^^^^ctasMEHPL=Smoker': 108,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Thyroid<LT>LF>High Cholesterol<LT>LF>uti': 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>High Cholesterol': 7,
#          '^c^^^^ctasMEHPL=ETOH Abuse': 137,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Chronic Back Pain': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Constipation<LT>LF>Depression<LT>LF>High Cholesterol<LT>LF>developmental disorder<LT>LF>Seizure': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>GERD (Gastroesophageal Reflux Disease)': 5,
#          '^c^^^^ctasMEHPL=ADHD (Attention Deficit Hyperactivity Disorder)<LT>LF>Depression<LT>LF>Depression<LT>LF>PSYCHOSIS': 1,
#          '^c^^^^ctasMEHPL=Immunizations up to Date': 300,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Substance Misuse': 19,
#          '^c^^^^ctasMEHPL=Gastritis': 5,
#          '^c^^^^ctasMEHPL=Myasthenia Gravis': 1,
#          '^c^^^^ctasMEHPL=Gout<LT>LF>Dementia<LT>LF>High BP<LT>LF>arrythmia': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>Immunizations up to Date': 306,
#          '^c^^^^ctasMEHPL=Kidney Stones<LT>LF>Hiatus Hernia<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Neuropathy': 2,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypothyroid': 25,
#          '^c^^^^ctasMEHPL=Weak lung. glaucoma surgery bilateral eyes 2016': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Thyroid<LT>LF>High BP<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>Rheumatoid Arthritis': 1,
#          '^c^^^^ctasMEHPL=MI (Myocardial Infarction)<LT>LF>High Cholesterol<LT>LF>High BP': 4,
#          '^c^^^^ctasMEHPL=Ovarian Cancer<LT>LF>chronic UTIs<LT>LF>Hysterectomy': 1,
#          '^c^^^^ctasMEHPL=Thyroid': 776,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>High BP<LT>LF>Thyroid': 3,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>High BP<LT>LF>Rheumatoid Arthritis': 1,
#          "^c^^^^ctasMEHPL=DVT's<LT>LF>Factor 5 Linden": 1,
#          '^c^^^^ctasMEHPL=left knee replacement, dementia, cataract surgery,  bladder reposition, TURN, hernia, see list <LT>LF>MI, pancreatitis': 1,
#          '^c^^^^ctasMEHPL=unable from pt, but as per PRP to EMS - HEP C \\T\\ HIV positive, substance abuse': 1,
#          '^c^^^^ctasMEHPL=GM2 Gangliosidosis<LT>LF>Seizure': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>Acid Reflux<LT>LF>Arthritis<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High BP': 54,
#          '^c^^^^ctasMEHPL=IV drug user': 2,
#          '^c^^^^ctasMEHPL=TIA (Transient Ischemic Attack)<LT>LF>High Cholesterol': 3,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>decreased kidney function': 1,
#          '^c^^^^ctasMEHPL=MS (Multiple Sclerosis)': 62,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>ARRYTHMIA': 1,
#          '^c^^^^ctasMEHPL=AFIB<LT>LF>High Cholesterol<LT>LF>Asthma<LT>LF>Hypertension (HTN)<LT>LF>Gerd<LT>LF>cardiac stents x 2': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>MI (Myocardial Infarction)<LT>LF>Thyroid': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 51,
#          '^c^^^^ctasMEHPL=concussion': 32,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>Thyroid<LT>LF>Acid Reflux': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>Hypertension (HTN)': 39,
#          "^c^^^^ctasMEHPL=Dementia<LT>LF>Alzheimer's<LT>LF>High Cholesterol<LT>LF>Hypothyroid<LT>LF>Depression<LT>LF>Asthma<LT>LF>Hypertension (HTN)<LT>LF>Acid Reflux": 1,
#          '^c^^^^ctasMEHPL=Acid Reflux<LT>LF>kidney problems<LT>LF>Thyroid<LT>LF>Stroke': 1,
#          '^c^^^^ctasMEHPL=Hepatitis C<LT>LF>Liver Chirosis<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)': 1,
#          "^c^^^^ctasMEHPL=Stroke<LT>LF>Gerd<LT>LF>Parkinson's<LT>LF>dementia<LT>LF>Cirrhosis": 1,
#          '^c^^^^ctasMEHPL=BLOOD CLOTS<LT>LF>UTERINE CYST WITH VAGINAL BLEEDING<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>Thyroid<LT>LF>BOWEL REDUCTION': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Asthma': 7,
#          "^c^^^^ctasMEHPL=CRF (Chronic Renal Failure)<LT>LF>Arthritis<LT>LF>Hypothyroid<LT>LF>Dementia<LT>LF>Alzheimer's<LT>LF>Hypertension (HTN)<LT>LF>CHF (Congestive Heart Failure)": 1,
#          '^c^^^^ctasMEHPL=Chronic Pain': 29,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Thyroid': 9,
#          '^c^^^^ctasMEHPL=Dementia<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Thyroid<LT>LF>Kidney failure': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>CRF (Chronic Renal Failure)<LT>LF>Enlarged Prostate<LT>LF>Pneumonia': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>gallbladder removal': 2,
#          '^c^^^^ctasMEHPL=Nephrotic syndrome': 2,
#          '^c^^^^ctasMEHPL=Dementia<LT>LF>Hypertension (HTN)<LT>LF>Glaucoma<LT>LF>NEOPLASM COLON<LT>LF>AFIB<LT>LF>HEARING LOSS<LT>LF>High Cholesterol<LT>LF>OSTEOARTHRITIS<LT>LF>B12 DEFICINECY': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Gout<LT>LF>Hypothyroid<LT>LF>osteoarthritis<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Acid Reflux<LT>LF>Asthma<LT>LF>Migraines': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>STENTS<LT>LF>KIDNEY FAILURE<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Bronchitis<LT>LF>Thyroid<LT>LF>Anxiety': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Anxiety<LT>LF>Depression<LT>LF>Substance Misuse': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>Leukemia': 1,
#          '^c^^^^ctasMEHPL=DVT (Deep Vein Thrombosis)': 32,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Osteoporosis<LT>LF>High BP<LT>LF>High Cholesterol<LT>LF>Thyroid<LT>LF>Anemia': 1,
#          '^c^^^^ctasMEHPL=ovarian cyst<LT>LF>cyst to back removed jan 31/2018': 1,
#          '^c^^^^ctasMEHPL=SEE DOCTORS NOTE': 1,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Gas': 1,
#          '^c^^^^ctasMEHPL=GAD (Generalized Anxiety Disorder)': 23,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>Depression<LT>LF>High Cholesterol': 3,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>High BP<LT>LF>Angina<LT>LF>Asthma': 1,
#          '^c^^^^ctasMEHPL=schizotypal<LT>LF>Anxiety': 1,
#          "^c^^^^ctasMEHPL=Crohn's Disease": 76,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Acid Reflux': 27,
#          '^c^^^^ctasMEHPL=Diverticulosis<LT>LF>Arthritis<LT>LF>HMF Forte, <LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=fistula<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>GERD (Gastroesophageal Reflux Disease)': 12,
#          '^c^^^^ctasMEHPL=Enlarged Prostate': 84,
#          '^c^^^^ctasMEHPL=mitral stenosis': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Anxiety<LT>LF>Asthma<LT>LF>High BP': 1,
#          '^c^^^^ctasMEHPL=Acid Reflux<LT>LF>High BP<LT>LF>Hypothyroid': 2,
#          '^c^^^^ctasMEHPL=Pneumonia': 89,
#          '^c^^^^ctasMEHPL=knee, shoulder surgery': 1,
#          '^c^^^^ctasMEHPL=Premature - born 25 weeks gestation': 1,
#          '^c^^^^ctasMEHPL=Acid Reflux<LT>LF>Hypertension (HTN)<LT>LF>Anxiety': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)': 10,
#          '^c^^^^ctasMEHPL=Pancreatitis<LT>LF>Depression<LT>LF>PTSD (Post Traumatic Stress Disorder)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Anxiety<LT>LF>HEMROHOIDS': 1,
#          '^c^^^^ctasMEHPL=Premature at 35 weeks': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>Depression<LT>LF>Anxiety': 7,
#          '^c^^^^ctasMEHPL=Anemia<LT>LF>sickle cell trait only *': 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>Hypothyroid<LT>LF>Depression<LT>LF>Enlarged Prostate<LT>LF>Atrial Fibrillation (A Fib)<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=Ovarian Cancer': 11,
#          '^c^^^^ctasMEHPL=Lupus<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)': 1,
#          "^c^^^^ctasMEHPL=Lupus<LT>LF>chrohn's disease<LT>LF>Hypertension (HTN)<LT>LF>Gout": 1,
#          '^c^^^^ctasMEHPL=Schizophrenia': 415,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>Hypertension (HTN)<LT>LF>Constipation<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Breast Cancer<LT>LF>Hypertension (HTN)': 7,
#          '^c^^^^ctasMEHPL=family history of cardiac issues.': 1,
#          '^c^^^^ctasMEHPL=Epilepsy': 118,
#          '^c^^^^ctasMEHPL=Pneumonia<LT>LF>fluffy airway': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>previous blood clot to gum': 1,
#          '^c^^^^ctasMEHPL=Heart Murmur<LT>LF>Smoker': 1,
#          '^c^^^^ctasMEHPL=KIDNEY DISEASE<LT>LF>HTN<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=Spinal Stenosis<LT>LF>Sleep Apnea<LT>LF>High Cholesterol<LT>LF>Kidney Stones<LT>LF>Arthritis<LT>LF>gastritis': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>Pacemaker/Cardioverter/Defib': 1,
#          '^c^^^^ctasMEHPL=STROKE': 1,
#          '^c^^^^ctasMEHPL=Kidney Stones': 321,
#          '^c^^^^ctasMEHPL=alopecia, anti body cells high': 1,
#          '^c^^^^ctasMEHPL=stents<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=Back Pain': 80,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>cardiac stenosis<LT>LF>rheumatic heart disease <LT>LF>acute pericarditis': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>TIA (Transient Ischemic Attack)<LT>LF>pressure comlex seizure<LT>LF>Hypothyroid<LT>LF>PTSD (Post Traumatic Stress Disorder)': 1,
#          '^c^^^^ctasMEHPL=Enlarged thyroid': 1,
#          '^c^^^^ctasMEHPL=Kidney Stones<LT>LF>GERD (Gastroesophageal Reflux Disease)': 1,
#          '^c^^^^ctasMEHPL=Migraines': 258,
#          '^c^^^^ctasMEHPL=febrile seizure<LT>LF>Asthma': 2,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Anemia<LT>LF>Osteoporosis': 1,
#          '^c^^^^ctasMEHPL=Substance Misuse<LT>LF>Schizophrenia': 3,
#          '^c^^^^ctasMEHPL=SPINAL BIFIDA<LT>LF>Asthma': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hypothyroid<LT>LF>MI (Myocardial Infarction)': 1,
#          '^c^^^^ctasMEHPL=behavioural': 1,
#          '^c^^^^ctasMEHPL=hypertension<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol': 340,
#          '^c^^^^ctasMEHPL=UTI': 120,
#          '^c^^^^ctasMEHPL=Knee Replacement': 8,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Depression<LT>LF>Smoker<LT>LF>Substance Misuse<LT>LF>Alcoholism': 1,
#          '^c^^^^ctasMEHPL=ETV surgery<LT>LF>Born with Right knee dislocation<LT>LF>Right side Hypertrophy': 1,
#          '^c^^^^ctasMEHPL=R HIP replacement<LT>LF>Gerd<LT>LF>BPH': 1,
#          '^c^^^^ctasMEHPL=MI (Myocardial Infarction)<LT>LF>Angina<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>low hemoglobin<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=Mitral valve replacement<LT>LF>Polycythemia<LT>LF>Fibromyalgia': 1,
#          '^c^^^^ctasMEHPL=low iron': 93,
#          '^c^^^^ctasMEHPL=Seizure': 262,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>ulcers': 1,
#          '^c^^^^ctasMEHPL=arthritis,  osteoporosis, hypertension': 1,
#          '^c^^^^ctasMEHPL=htn, high cholesterol, kidney disease, iddm, hypotensive,': 1,
#          '^c^^^^ctasMEHPL=pancreatic CA<LT>LF>Substance Misuse': 1,
#          '^c^^^^ctasMEHPL=learning disability, thyroid': 1,
#          '^c^^^^ctasMEHPL=mi, stent, cva, <LT>LF>htn, niddm': 1,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>ADHD (Attention Deficit Hyperactivity Disorder)': 19,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Hypothyroid<LT>LF>Breast Cancer': 1,
#          '^c^^^^ctasMEHPL=Right leg pain<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=recent angio, GERD, high cholesterol, CHF': 1,
#          '^c^^^^ctasMEHPL=?aggressive behaviour': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>MI (Myocardial Infarction)<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>GERD (Gastroesophageal Reflux Disease)': 1,
#          '^c^^^^ctasMEHPL=Rheumatoid Arthritis<LT>LF>Acid Reflux<LT>LF>Asthma': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)': 278,
#          '^c^^^^ctasMEHPL=GERD (Gastroesophageal Reflux Disease)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=asthma, eczema': 2,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>CAD (Coronary Artery Disease)<LT>LF>Hypertension (HTN)<LT>LF>angioplasty': 1,
#          '^c^^^^ctasMEHPL=gallbladder removed': 12,
#          '^c^^^^ctasMEHPL=htn, cholesterol, awaiting R knee replacement': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>CP (Cerebral Palsy)<LT>LF>Constipation': 1,
#          '^c^^^^ctasMEHPL=Osteoporosis<LT>LF>Asthma': 1,
#          '^c^^^^ctasMEHPL=Ulcerative Colitis<LT>LF>headaches constant': 1,
#          "^c^^^^ctasMEHPL=Hypothyroid<LT>LF>hallucinations<LT>LF>Parkinson's<LT>LF>gerd<LT>LF>cataracts<LT>LF>arthritis<LT>LF>dementia<LT>LF>functional quadraplegia": 1,
#          '^c^^^^ctasMEHPL=?MH': 1,
#          '^c^^^^ctasMEHPL=right neck disectected artery<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=sepsis, ASD, PDA, NEONATAL JAUNDICE': 1,
#          '^c^^^^ctasMEHPL=htn, high cholesterol, iddm, spinal stenosis': 1,
#          '^c^^^^ctasMEHPL=intubated on April 2, 2018': 1,
#          '^c^^^^ctasMEHPL=Chronic Back Pain<LT>LF>Chronic knee pain<LT>LF>digestion and vomiting<LT>LF>Arthritis': 1,
#          '^c^^^^ctasMEHPL=Smoker<LT>LF>Wheel chair bound<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Emphysema<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>High Cholesterol<LT>LF>Osteoporosis<LT>LF>CVA (Cerebral vascular Accident)': 1,
#          '^c^^^^ctasMEHPL=Glaucoma': 34,
#          '^c^^^^ctasMEHPL=Scoliosis': 34,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>Arthritis<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Pancreatitis<LT>LF>Hysterectomy': 1,
#          '^c^^^^ctasMEHPL=Dementia<LT>LF>High Cholesterol': 3,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>c section': 3,
#          '^c^^^^ctasMEHPL=aortic replacement <LT>LF>due for mitral and biscupid valve replacement <LT>LF>liver cirrhosis <LT>LF>kidney failure <LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Sleep Apnea<LT>LF>Atrial Fibrillation (A Fib)<LT>LF>Enlarged Prostate<LT>LF>Hip Replacement (Right)': 1,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Hypothyroid<LT>LF>Anxiety': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>Chronic Knee/ Back Pain <LT>LF>High Cholesterol<LT>LF>Bilateral Knee Replaecment': 1,
#          '^c^^^^ctasMEHPL=pacemaker<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>cabg<LT>LF>knee surgery': 1,
#          '^c^^^^ctasMEHPL=KIDNEY OBSTRUCTION.': 1,
#          '^c^^^^ctasMEHPL=Gabapentin, Wellbutrin, Abilify, Seroquel, Clonazepam, Flovent, Ventolin, Methadone': 1,
#          "^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>chron's disease<LT>LF>Gout<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Arthritis": 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>High BP<LT>LF>IBS (Irritable Bowel Syndrome)': 1,
#          '^c^^^^ctasMEHPL=Psych<LT>LF>Seizure': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>Arthritis': 4,
#          '^c^^^^ctasMEHPL=Panic Disorder': 15,
#          '^c^^^^ctasMEHPL=CABG, Cardiac STENT, CVA (left deficits), NIDDM, PTSD, Head injury with coma (from assault), sleep Apnea, Psoriasis, Hyptertension,': 1,
#          '^c^^^^ctasMEHPL=Dementia': 43,
#          '^c^^^^ctasMEHPL=hashimoto disease<LT>LF>high cholestrol<LT>LF>MI (Myocardial Infarction)': 1,
#          '^c^^^^ctasMEHPL=Select from list or enter<LT>LF>No Significant Medical History': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>PE': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Rectal cancer-treated   3 years ago <LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=MS (Multiple Sclerosis)<LT>LF>Osteoporosis': 2,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Prostate Cancer<LT>LF>CVA / Dementia?': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>abdominal hernia': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>gall bladder removed 1 month ago': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Osteoarthritis <LT>LF>Femur #<LT>LF>Obesity<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>?thyroid problem': 1,
#          '^c^^^^ctasMEHPL=MDS<LT>LF>High Cholesterol': 2,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Thyroid': 38,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Substance Misuse': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Acid Reflux': 59,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>depression': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Thyroid<LT>LF>Arthritis': 3,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>Depression': 238,
#          '^c^^^^ctasMEHPL=pericarditis': 6,
#          '^c^^^^ctasMEHPL=Chronic Back Pain<LT>LF>Arthritis<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Dementia<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>CVA (Cerebral vascular Accident)<LT>LF>Pancreatitis<LT>LF>CRF (Chronic Renal Failure)<LT>LF>Legally Blind': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>Depression': 24,
#          '^c^^^^ctasMEHPL=stroke<LT>LF>Hypertension (HTN)<LT>LF>Enlarged Prostate': 1,
#          '^c^^^^ctasMEHPL=chicken pox<LT>LF>Migraines': 1,
#          '^c^^^^ctasMEHPL=C-section 2x': 1,
#          '^c^^^^ctasMEHPL=kidney stone.': 1,
#          '^c^^^^ctasMEHPL=Substance Misuse<LT>LF>Diabetes<LT>LF>Schizophrenia': 2,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hyperthyroid<LT>LF>Hypertension (HTN)': 2,
#          '^c^^^^ctasMEHPL=PROSTRATE <LT>LF>Benign Prostatic Hypertension<LT>LF>Chronic Back Pain<LT>LF>Dementia': 1,
#          '^c^^^^ctasMEHPL=cellulitius of toe<LT>LF>cva<LT>LF>Hypertension (HTN)<LT>LF>Dementia': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>Enlarged Prostate': 4,
#          '^c^^^^ctasMEHPL=Seizure<LT>LF>Brain Cancer<LT>LF>supra ventricular tachycardia': 1,
#          '^c^^^^ctasMEHPL=Aneurism<LT>LF>ADHD (Attention Deficit Hyperactivity Disorder)': 1,
#          '^c^^^^ctasMEHPL=tonic-clonic seizures<LT>LF>partial seziures<LT>LF>Bi-Polar<LT>LF>Schizophrenia<LT>LF>HIV/AIDS': 1,
#          '^c^^^^ctasMEHPL=Epilepsy<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Atrial Fibrillation (A Fib)': 1,
#          '^c^^^^ctasMEHPL=TURP (Transurethral Resection of the Prostate)<LT>LF>Diverticulitis<LT>LF>BPH<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>hyperlipidemia<LT>LF>CVD risk<LT>LF>Asthma<LT>LF>Osteoporosis<LT>LF>osteoarthritis<LT>LF>heart murmur': 1,
#          '^c^^^^ctasMEHPL=SICKLE CELL TRAIT': 1,
#          '^c^^^^ctasMEHPL=Tonsillectomy<LT>LF>c-section<LT>LF>breast reduction <LT>LF>tubal ligation<LT>LF>ganglia cyst removal <LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>skin candidiasis<LT>LF>shoulder injury': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>High BP<LT>LF>stroke<LT>LF>thyroid': 1,
#          '^c^^^^ctasMEHPL=Pacemaker/Cardioverter/Defib<LT>LF>Hypothyroid<LT>LF>Vertigo<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Enlarged Prostate': 27,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Pacemaker/Cardioverter/Defib': 4,
#          '^c^^^^ctasMEHPL=inguinal hernia': 5,
#          '^c^^^^ctasMEHPL=Fibromyalgia<LT>LF>Pulmonary Hypertension<LT>LF>Hypertension (HTN)<LT>LF>Raynauds<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=CHF (Congestive Heart Failure)<LT>LF>artherosclerosis<LT>LF>Hypertension (HTN)<LT>LF>Tonsillectomy<LT>LF>CAD (Coronary Artery Disease)': 1,
#          '^c^^^^ctasMEHPL=Seizure<LT>LF>Substance Misuse': 4,
#          '^c^^^^ctasMEHPL=Atrial Ventricular malformation': 1,
#          '^c^^^^ctasMEHPL=stroke <LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)': 2,
#          '^c^^^^ctasMEHPL=Fibromyalgia<LT>LF>Osteoarthritis <LT>LF>Anxiety / PTSD<LT>LF>Chronic Fatigue Syndrome': 1,
#          '^c^^^^ctasMEHPL=premature': 6,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>KNEE PAIN<LT>LF>BACK ISSUE': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Acid Reflux<LT>LF>fatty liver': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>Anemia': 4,
#          '^c^^^^ctasMEHPL=abortion x 2<LT>LF>Anemia': 1,
#          '^c^^^^ctasMEHPL=etopic pregnancy': 2,
#          '^c^^^^ctasMEHPL=SVT, ablation  2017': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>Early stage dementia': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol<LT>LF>Diabetes': 49,
#          '^c^^^^ctasMEHPL=ADHD (Attention Deficit Hyperactivity Disorder)<LT>LF>Speech, Language deficit <LT>LF>Neurological disorders': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>Hernia - Repaired': 1,
#          '^c^^^^ctasMEHPL=Stomach Cancer<LT>LF>MI (Myocardial Infarction)<LT>LF>Atrial Fibrillation (A Fib)<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Perforated Stomache<LT>LF>Palliative': 1,
#          '^c^^^^ctasMEHPL=lung problem <LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>high chol': 1,
#          "^c^^^^ctasMEHPL=Parkinson's<LT>LF>Thyroid<LT>LF>PE, GERD, <LT>LF>High Cholesterol": 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Thyroid<LT>LF>Hypertension (HTN)<LT>LF>Asthma': 1,
#          '^c^^^^ctasMEHPL=possible MI<LT>LF>?interstitial pneumonitis': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>High Cholesterol<LT>LF>Diabetes': 1,
#          '^c^^^^ctasMEHPL=leaky heart valve': 1,
#          '^c^^^^ctasMEHPL=anxiety, depression, ADHD': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Gastrointestinal (GI) Bleed<LT>LF>Anemia<LT>LF>MI (Myocardial Infarction)<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Constipation<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Thyroid<LT>LF>Anemia': 6,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>head injury 4 years ago. hit head on ice.': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Depression<LT>LF>High Cholesterol<LT>LF>Thyroid': 1,
#          '^c^^^^ctasMEHPL=AFIB,PNUMONIA<LT>LF>Hypertension (HTN)<LT>LF>SVT': 1,
#          '^c^^^^ctasMEHPL=sleep aid': 1,
#          '^c^^^^ctasMEHPL=opoid addiction<LT>LF>Hiatus Hernia<LT>LF>stomach ulcer': 1,
#          '^c^^^^ctasMEHPL=Appendectomy': 70,
#          '^c^^^^ctasMEHPL=Schizophrenia<LT>LF>Bi-Polar<LT>LF>Depression': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>icd <LT>LF>Enlarged Prostate<LT>LF>MI (Myocardial Infarction)<LT>LF>CVA (Cerebral vascular Accident)': 1,
#          '^c^^^^ctasMEHPL=Vertigo<LT>LF>previous head injuries': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Anemia': 3,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>MI (Myocardial Infarction)<LT>LF>Prostate Cancer': 1,
#          '^c^^^^ctasMEHPL=Breast Cancer': 113,
#          '^c^^^^ctasMEHPL=GERD (Gastroesophageal Reflux Disease)<LT>LF>gastric ulcer<LT>LF>colon cancer<LT>LF>bowel surgery-1986': 1,
#          '^c^^^^ctasMEHPL=Pacemaker/Cardioverter/Defib<LT>LF>Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Bladder Cancer': 1,
#          '^c^^^^ctasMEHPL=seizure -febrile': 1,
#          '^c^^^^ctasMEHPL=Gerd<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Smoker<LT>LF>MI (Myocardial Infarction)<LT>LF>ptca<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=portal hypertension<LT>LF>Liver Cancer<LT>LF>Heart Attack<LT>LF>cardiac stents x 3 <LT>LF>Cholecystectomy<LT>LF>hepatic <LT>LF>Hypertension (HTN)<LT>LF>CHF (Congestive Heart Failure)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Pacemaker/Cardioverter/Defib<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)<LT>LF>Breast Cancer<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=Smoker<LT>LF>Bi-Polar<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=MI (Myocardial Infarction)<LT>LF>TIA (Transient Ischemic Attack)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          "^c^^^^ctasMEHPL=CVA (Cerebral vascular Accident)<LT>LF>bell's palsy<LT>LF>Hypertension (HTN)": 1,
#          '^c^^^^ctasMEHPL=Fibromyalgia<LT>LF>d<LT>LF>dechets disease<LT>LF>Endometriosis<LT>LF>Chronic Pain<LF>seizures': 1,
#          '^c^^^^ctasMEHPL=low magnesium<LT>LF>diverticulosis<LT>LF>ADHD, OCD, borderline<LT>LF>psychosis,<LT>LF>tremors': 1,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 11,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>ETOH Abuse<LT>LF>Thyroid<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Gallstones<LT>LF>High Cholesterol<LT>LF>30% blockage coronary artery': 1,
#          '^c^^^^ctasMEHPL=fibroids.<LT>LF>Diabetes<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>brain tumour removed-benign-3yrs ago<LT>LF>recent uti': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>High BP<LT>LF>Diabetes': 10,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Asthma<LT>LF>Depression<LT>LF>Sleep Apnea': 1,
#          '^c^^^^ctasMEHPL=pulmonary stenosis': 3,
#          '^c^^^^ctasMEHPL=Gout': 68,
#          '^c^^^^ctasMEHPL=born with one kidney': 2,
#          '^c^^^^ctasMEHPL=Acid Reflux<LT>LF>Thyroid<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Acid Reflux': 3,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Cirrhosis<LT>LF>one kidney<LT>LF>ETOH Abuse': 1,
#          '^c^^^^ctasMEHPL=Migraines<LT>LF>UTI': 1,
#          '^c^^^^ctasMEHPL=Schizophrenia<LT>LF>bipolar': 14,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>CHF (Congestive Heart Failure)<LT>LF>15 blocked cartory arteries. <LT>LF>High Cholesterol<LT>LF>Depression': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Bi-Polar<LT>LF>smoker<LT>LF>Liver Cancer<LT>LF>Chronic Back Pain': 1,
#          '^c^^^^ctasMEHPL=chronic headaches': 2,
#          '^c^^^^ctasMEHPL=inflamed gallbladder': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>gerd<LT>LF>MI (Myocardial Infarction)<LT>LF>ptca<LT>LF>smoking<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=chf<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Enlarged Prostate': 1,
#          '^c^^^^ctasMEHPL=Hearing Impaired<LT>LF>Hypertension (HTN)<LT>LF>Osteoporosis<LT>LF>Pneumonia': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Rheumatoid Arthritis<LT>LF>Acid Reflux<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=CHF (Congestive Heart Failure)<LT>LF>htn<LT>LF>High Cholesterol<LT>LF>Glaucoma<LT>LF>left mastectomy<LT>LF>lymph node disection<LT>LF>Depression': 1,
#          '^c^^^^ctasMEHPL=CHF (Congestive Heart Failure)<LT>LF>Pneumonia<LT>LF>Colitis<LT>LF>Hypertension (HTN)<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=foreign body esophagus.<LT>LF>bowel surgery polyposis<LT>LF>GERD (Gastroesophageal Reflux Disease)': 1,
#          '^c^^^^ctasMEHPL=dialysis<LT>LF>CVA (Cerebral vascular Accident)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=ovarian cyst<LT>LF>UTI': 2,
#          '^c^^^^ctasMEHPL=htn<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>gerd': 1,
# ...
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>MI x 4 years<LT>LF>BPH': 1,
#          '^c^^^^ctasMEHPL=acne': 12,
#          '^c^^^^ctasMEHPL=carotid stenosis 100% on left, htn, cholesterol, hypothyroid, copd<LT>LF>exsmoker': 1,
#          '^c^^^^ctasMEHPL=anxirty': 2,
#          '^c^^^^ctasMEHPL=stomach ulcer, lower GI bleed, prolapsed rectum, thyroid, afib, high cholesterol, HTN, GERD, lower back pain': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Stroke': 1,
#          '^c^^^^ctasMEHPL=PANCREATITIS-SURGERY, HIGH CHOL<LT>LF>Asthma': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Lung Cancer<LT>LF>Pneumonia<LT>LF>Angina<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=getting IVF treatment<LT>LF>frequent UTI': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>Anxiety': 13,
#          '^c^^^^ctasMEHPL=diabetes': 31,
#          '^c^^^^ctasMEHPL=Esophageal Cancer<LT>LF>g tube<LT>LF>npo x 1 year<LT>LF>pt has to airway stent<LT>LF>pt had esophageal stent': 1,
#          '^c^^^^ctasMEHPL=MS (Multiple Sclerosis)<LT>LF>WPW': 1,
#          '^c^^^^ctasMEHPL=healthy': 3,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>VACCINES UP TO DATE': 101,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>Prostate Cancer<LT>LF>Diabetes': 1,
#          '^c^^^^ctasMEHPL=thyroid': 94,
#          '^c^^^^ctasMEHPL=bipolar, back pain, htn, high blood pressure, NIDDM': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypothyroid<LT>LF>CHF (Congestive Heart Failure)<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Schizophrenia<LT>LF>pschosis': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)': 30,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>ADVIL-LAST TAKEN LAST NIGHT': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>colan ca<LT>LF>Arthritis': 1,
#          '^c^^^^ctasMEHPL=CRF, DM, HTN, HIGH CHOL': 1,
#          '^c^^^^ctasMEHPL=MI, lung Ca,': 1,
#          '^c^^^^ctasMEHPL=ALS (Amyotrophic Lateral Sclerosis)<LT>LF>BPH': 1,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>miX2 years ago-stentX1<LT>LF>htn, high chol': 1,
#          '^c^^^^ctasMEHPL=Diabetes<LT>LF>Hypothyroid<LT>LF>gall bladder surgery': 1,
#          '^c^^^^ctasMEHPL=MENTAL HEALTH<LT>LF>SCHIZO AFFECTIVE DISORDER': 1,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)<LT>LF>Hypothyroid<LT>LF>Prostate Cancer<LT>LF>UMBILICAL HERNIA REPAIR<LT>LF>STRESS INCONTINENCE<LT>LF>STENT X 5': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>Seizure<LT>LF>Glaucoma': 1,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>Depression<LT>LF>heart block<LT>LF>Arthritis<LT>LF>herniated disc<LT>LF>Angina': 1,
#          '^c^^^^ctasMEHPL=FULL TERM, NORMAL DELIVERY-NO COMPLICATIONS, MOM HAD GESTATION DIABETES': 1,
#          '^c^^^^ctasMEHPL=MI x 5 years': 1,
#          '^c^^^^ctasMEHPL=Cholecystitis': 5,
#          '^c^^^^ctasMEHPL=High Cholesterol<LT>LF>HEART MURMUR<LT>LF>HTN, NIDDM': 1,
#          '^c^^^^ctasMEHPL=G5,P2,M2<LT>LF>Thyroid<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=depression, POS': 1,
#          '^c^^^^ctasMEHPL=svt?': 1,
#          '^c^^^^ctasMEHPL=CHF (Congestive Heart Failure)<LT>LF>AAA<LT>LF>PTSD<LT>LF>CARDIOMYOPATHY<LT>LF>High Cholesterol<LT>LF>Prostate Cancer': 1,
#          '^c^^^^ctasMEHPL=constipation': 3,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Osteoporosis': 3,
#          '^c^^^^ctasMEHPL=PACEMAKER X 10 YRS<LT>LF>High Cholesterol<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Dementia': 1,
#          '^c^^^^ctasMEHPL=schizo affective bipolar, ptsd': 1,
#          '^c^^^^ctasMEHPL=some heart condition': 1,
#          '^c^^^^ctasMEHPL=Rheumatoid Arthritis': 76,
#          '^c^^^^ctasMEHPL=NIDDM': 57,
#          '^c^^^^ctasMEHPL=G2,p0<LT>LF>prenatal': 1,
#          '^c^^^^ctasMEHPL=Heart Attack<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Enlarged Prostate': 1,
#          '^c^^^^ctasMEHPL=depression,palpitations': 1,
#          '^c^^^^ctasMEHPL=Anemia<LT>LF>GASTRIC BYPASS': 1,
#          '^c^^^^ctasMEHPL=kidney failure <LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>MI (Myocardial Infarction)': 1,
#          '^c^^^^ctasMEHPL=Seizure<LT>LF>Chronic Back Pain<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=collar bone fracture (2017)': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>Asthma': 58,
#          '^c^^^^ctasMEHPL=Hypothyroid<LT>LF>Interstitial Cystitis': 1,
#          '^c^^^^ctasMEHPL=hemmoroids': 2,
#          '^c^^^^ctasMEHPL=Substance Misuse<LT>LF>Depression': 19,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Fibromyalgia<LT>LF>Arthritis<LT>LF>Ovarian Cancer<LT>LF>heart incident<LT>LF>angiogram x2': 1,
#          '^c^^^^ctasMEHPL=MI (Myocardial Infarction)<LT>LF>angioplastry with two stents<LT>LF>Pacemaker/Cardioverter/Defib': 1,
#          '^c^^^^ctasMEHPL=liver failure<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=heart disease<LT>LF>cardiac stent x 1': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>FIBROID<LT>LF>Sleep Apnea<LT>LF>Anemia': 1,
#          '^c^^^^ctasMEHPL=Pulmonary Fibrosis<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Irregular heart beat': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>CVA (Cerebral vascular Accident)<LT>LF>Hypothyroid<LT>LF>Atrial Fibrillation (A Fib)<LT>LF>Hearing Impaired': 1,
#          '^c^^^^ctasMEHPL=family hx of heart problems': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>Acid Reflux<LT>LF>lactose intolerance': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>GERD (Gastroesophageal Reflux Disease)': 35,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>Bi-Polar<LT>LF>Depression<LT>LF>Anxiety': 1,
#          '^c^^^^ctasMEHPL=kidney disease ( on dialysis, Tues, Thurs, Sat.)<LT>LF>Acid Reflux<LT>LF>low iron<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Herniated Disc': 6,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>prostate<LT>LF>enlarged heart': 1,
#          '^c^^^^ctasMEHPL=Pacemaker/Cardioverter/Defib<LT>LF>irregular heartbeat': 1,
#          '^c^^^^ctasMEHPL=mental health': 25,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Diabetes<LT>LF>TIA (Transient Ischemic Attack)': 1,
#          '^c^^^^ctasMEHPL=chrons disease': 3,
#          '^c^^^^ctasMEHPL=MI (Myocardial Infarction)<LT>LF>Angioplasty with stents<LT>LF>cardiac bypass x3<LT>LF>Thyroid<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=CABG<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Gerd': 1,
#          '^c^^^^ctasMEHPL=ADHD (Attention Deficit Hyperactivity Disorder)<LT>LF>Depression<LT>LF>Migraines<LT>LF>Benign Pituitary Tumor in the brain<LT>LF>Smoker': 1,
#          '^c^^^^ctasMEHPL=Thyroid removed 3-4 years ago': 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>Depression<LT>LF>benign essential tremor': 1,
#          '^c^^^^ctasMEHPL=Appendectomy<LT>LF>laparoscopic': 1,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Anxiety<LT>LF>Substance Misuse': 5,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypothyroid': 7,
#          '^c^^^^ctasMEHPL=Lupus<LT>LF>Vitaligo - skin pigmentation': 1,
#          '^c^^^^ctasMEHPL=Schizophrenia<LT>LF>PTSD (Post Traumatic Stress Disorder)<LT>LF>Thyroid<LT>LF>Anxiety': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>High Cholesterol<LT>LF>Acid Reflux<LT>LF>Angina<LT>LF>angiogram': 1,
#          '^c^^^^ctasMEHPL=austium': 1,
#          '^c^^^^ctasMEHPL=syncope<LT>LF>Hypothyroid<LT>LF>Depression<LT>LF>Anxiety<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Vertigo': 3,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Anxiety<LT>LF>PTSD (Post Traumatic Stress Disorder)<LT>LF>Substance Misuse<LT>LF>cocaine misuse': 1,
#          '^c^^^^ctasMEHPL=spinititis<LT>LF>pinched nerves<LT>LF>Fibromyalgia<LT>LF>chronic vertigo<LT>LF>Cholecystectomy<LT>LF>insomnia<LT>LF>Scoliosis': 1,
#          '^c^^^^ctasMEHPL=Gerd<LT>LF>Pinched Nerve - Left arm numbness <LT>LF>Anxiety': 1,
#          '^c^^^^ctasMEHPL=Polio<LT>LF>Hypertension (HTN)<LT>LF>Rh- Group B': 1,
#          '^c^^^^ctasMEHPL=Bi-Polar<LT>LF>Depression<LT>LF>Anxiety': 3,
#          '^c^^^^ctasMEHPL=CVA (Cerebral vascular Accident)<LT>LF>Dementia <LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>GERD<LT>LF>Aneurysm ?': 1,
#          '^c^^^^ctasMEHPL=SVT': 24,
#          '^c^^^^ctasMEHPL=Unable to obtain': 4,
#          '^c^^^^ctasMEHPL=mvc 2010': 1,
#          '^c^^^^ctasMEHPL=Fibromyalgia<LT>LF>Gout': 1,
#          '^c^^^^ctasMEHPL=Migraines<LT>LF>Anemia<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Hip Replacement<LT>LF>Glaucoma Cataract/Cataract Repair<LT>LF>carcinoma stage 2 with surgery<LT>LF>nephrectomy of kidney': 1,
#          '^c^^^^ctasMEHPL=Kidney Stones<LT>LF>Gout<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>High BP<LT>LF>Depression<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=CBAG<LT>LF>liver <LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>liver transplant 2011<LT>LF>Pleural effusion <LT>LF>Gerd': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Gerd<LT>LF>High Cholesterol<LT>LF>Constipation': 1,
#          '^c^^^^ctasMEHPL=High BP<LT>LF>Arthritis': 11,
#          '^c^^^^ctasMEHPL=Psoriasis': 3,
#          '^c^^^^ctasMEHPL=Depression<LT>LF>Sciatica': 1,
#          '^c^^^^ctasMEHPL=htn<LT>LF>Hyperthyroid<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>CAD (Coronary Artery Disease)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Diabetes<LT>LF>Asthma': 2,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Atrial Fibrillation (A Fib)': 20,
#          '^c^^^^ctasMEHPL=Uterine Fibroids<LT>LF>Sciatica': 1,
#          '^c^^^^ctasMEHPL=disk herniation<LT>LF>Anxiety<LT>LF>Smoker': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>UTI<LT>LF>border line diabetes<LT>LF>low iron': 1,
#          "^c^^^^ctasMEHPL=IBS (Irritable Bowel Syndrome)<LT>LF>Asthma<LT>LF>Meniere's": 1,
#          '^c^^^^ctasMEHPL=Hyperthyroid': 56,
#          '^c^^^^ctasMEHPL=palpitations': 10,
#          '^c^^^^ctasMEHPL=asthma<LT>LF>Hypertension (HTN)': 2,
#          '^c^^^^ctasMEHPL=NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>ht': 1,
#          '^c^^^^ctasMEHPL=Atrial Fibrillation (A Fib)': 33,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Hypothyroid': 50,
#          '^c^^^^ctasMEHPL=syncopal<LT>LF>Hyperthyroid': 1,
#          '^c^^^^ctasMEHPL=Anemia<LT>LF>Diverticulitis<LT>LF>Gerd<LT>LF>Hypertension (HTN)<LT>LF>Rheumatoid Arthritis<LT>LF>High Cholesterol<LT>LF>Hypothyroid<LT>LF>Asthma<LT>LF>macular degenertation': 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>heroine addiction': 1,
#          '^c^^^^ctasMEHPL=hernia SX': 2,
#          '^c^^^^ctasMEHPL=Bypass Surgery<LT>LF>STROKE<LT>LF>Hypertension (HTN)<LT>LF>Gerd': 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>Depression<LT>LF>Alcoholism': 1,
#          '^c^^^^ctasMEHPL=Hyperthyroid<LT>LF>Hernia': 1,
#          '^c^^^^ctasMEHPL=Pacemaker/Cardioverter/Defib<LT>LF>Gerd<LT>LF>Hypothyroid<LT>LF>Hypertension (HTN)<LT>LF>BACK INJURY': 1,
#          '^c^^^^ctasMEHPL=CVA (Cerebral vascular Accident)<LT>LF>PROSTRATE,PELVIC FRACTURE,BLINDNESS,DEAF,HTN,GERD,OSTEOARTHRITIS,COLON CA -2014.HERNIA': 1,
#          '^c^^^^ctasMEHPL=MI<LT>LF>STENTS<LT>LF>CHF<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>IMPLANTED DEFIB': 1,
#          '^c^^^^ctasMEHPL=lung issues problem<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=Hysterectomy': 42,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>etidronate': 1,
#          '^c^^^^ctasMEHPL=CRF (Chronic Renal Failure)<LT>LF>Cirrhosis<LT>LF>cardiac sx<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Hypothyroid': 1,
#          '^c^^^^ctasMEHPL=drug induce psychosis': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>ASTHMA': 2,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>Hypertension (HTN)': 25,
#          '^c^^^^ctasMEHPL=stents<LT>LF>High Cholesterol': 3,
#          "^c^^^^ctasMEHPL=vertigo<LT>LF>Parkinson's<LT>LF>arrythmia<LT>LF>Hypertension (HTN)<LT>LF>aterial fib<LT>LF>Arthritis<LT>LF>High Cholesterol<LT>LF>Hypothyroid": 1,
#          '^c^^^^ctasMEHPL=Thyroid<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 8,
#          '^c^^^^ctasMEHPL=Acid Reflux<LT>LF>CAD (Coronary Artery Disease)<LT>LF>Fluid retention': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>GERD (Gastroesophageal Reflux Disease)<LT>LF>ANEMIA<LT>LF>Asthma<LT>LF>BROKEN LEFT ARM<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Depression': 7,
#          '^c^^^^ctasMEHPL=flutter<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Sleep Apnea<LT>LF>Thyroid': 1,
#          '^c^^^^ctasMEHPL=HEMOPHILIA , BYPASS (LEGS) SURGERY': 1,
#          '^c^^^^ctasMEHPL=6 bypass X 3 yrs ago<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)<LT>LF>Chronic neck pain<LT>LF>Glaucoma Cataract/Cataract Repair': 1,
#          '^c^^^^ctasMEHPL=BREAST CANCER  METS TO LIVER AND LUNGS': 1,
#          '^c^^^^ctasMEHPL=MISCARRIAGE  3X': 1,
#          '^c^^^^ctasMEHPL=hypthyrodism': 1,
#          '^c^^^^ctasMEHPL=COPD (Chronic Obstructive Pulmonary Disease)<LT>LF>Bronchitis, Emphazema': 1,
#          '^c^^^^ctasMEHPL=MI,HTN,CHOLESTROL,COPD': 1,
#          '^c^^^^ctasMEHPL=No Significant Medical History<LT>LF>Bells Palsy': 1,
#          '^c^^^^ctasMEHPL=Colitis<LT>LF>Bi-Polar<LT>LF>Asthma<LT>LF>Epilepsy': 1,
#          '^c^^^^ctasMEHPL=Asthma<LT>LF>ANXIETY<LT>LF>Depression': 1,
#          '^c^^^^ctasMEHPL=Bi-Polar<LT>LF>Fibromyalgia<LT>LF>Polysistic syndrome': 1,
#          "^c^^^^ctasMEHPL=CHRONIC LEG PAIN <LT>LF>Parkinson's<LT>LF>Hernia": 1,
#          '^c^^^^ctasMEHPL=vertigo<LT>LF>Thyroid': 1,
#          '^c^^^^ctasMEHPL=Smoker<LT>LF>ETOH Abuse<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=Bipolar<LT>LF>ADHD (Attention Deficit Hyperactivity Disorder)': 1,
#          '^c^^^^ctasMEHPL=CVA (Cerebral vascular Accident)<LT>LF>Hypertension (HTN)<LT>LF>PROSTRATE<LT>LF>HIGH CHOLESTROL<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          "^c^^^^ctasMEHPL=Alzheimer's<LT>LF>Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>1 stent with no MI": 1,
#          '^c^^^^ctasMEHPL=Anxiety<LT>LF>Depression<LT>LF>Asthma<LT>LF>irregular heart beat': 1,
#          '^c^^^^ctasMEHPL=Breast Cancer<LT>LF>Diabetes': 2,
#          '^c^^^^ctasMEHPL=Left shoulder dislocation 2016': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>Diabetes': 79,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>High Cholesterol<LT>LF>Thyroid<LT>LF>IDDM (Insulin-Dependent Diabetes Mellitus)': 2,
#          '^c^^^^ctasMEHPL=Dementia<LT>LF>Hypothyroid<LT>LF>High Cholesterol': 1,
#          '^c^^^^ctasMEHPL=svt with ablasion<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>High Cholesterol<LT>LF>Hypertension (HTN)': 1,
#          '^c^^^^ctasMEHPL=OVARIAN CYST': 4,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)<LT>LF>CABG<LT>LF>transfusions, prbc,and iron<LT>LF>Cirrhosis<LT>LF>crf': 1,
#          '^c^^^^ctasMEHPL=Hypertension (HTN)<LT>LF>CELIAC DISEASE<LT>LF>NIDDM (Non-Insulin-Dependent Diabetes Mellitus)': 1,
#          '^c^^^^ctasMEHPL=Arthritis<LT>LF>Spinal Sx.<LT>LF>Diabetes': 1,
#          ...})

# %%
history = list(subj_df['MedicalHistory'].str[16:].astype('str'))

# %%
type(history)
# Out:
# list

# %%
split_hist = [item.split('<LT>LF>') for item in history if item != 'nan']

# %%
len(split_hist)
# Out:
# 122211

# %%
split_hist[:25]
# Out:
# [['No Significant Medical History'],
#  ['Substance Misuse'],
#  ['ACS (Acute Coronary Syndrome)',
#   'MI (Myocardial Infarction)',
#   'triple a repair',
#   'NIDDM (Non-Insulin-Dependent Diabetes Mellitus)',
#   'Hypertension (HTN)',
#   'bronchiectasis'],
#  ['Hypertension (HTN)'],
#  ['Seizure', 'Asthma', 'palpitations', 'leaky hrt valve'],
#  ['No Significant Medical History'],
#  ['No Significant Medical History'],
#  ['No Significant Medical History'],
#  ['Hypertension (HTN)', 'High Cholesterol', 'Gerd', 'Chronic Back Pain'],
#  ['No Significant Medical History'],
#  ['Dialysis Haemo/PD',
#   'IDDM (Insulin-Dependent Diabetes Mellitus)',
#   'CRF (Chronic Renal Failure)',
#   'heart problem',
#   'High Cholesterol'],
#  ['Fibromyalgia'],
#  ['enlarged liver'],
#  ['Anxiety',
#   'Autistic',
#   'ADHD (Attention Deficit Hyperactivity Disorder)',
#   'Depression',
#   'Asthma',
#   'Celiac'],
#  ['No Significant Medical History'],
#  ['IDDM (Insulin-Dependent Diabetes Mellitus)'],
#  ['No Significant Medical History'],
#  ['Hypertension (HTN)',
#   'TIA (Transient Ischemic Attack)',
#   'Arthritis',
#   'Glaucoma',
#   'Dementia',
#   'CVA (Cerebral vascular Accident)'],
#  ['Bladder Cancer',
#   'Hypertension (HTN)',
#   'MI (Myocardial Infarction)',
#   'stents,borderline dm'],
#  ['ca colon with bowel resection', 'Received Chemotherapy within 4 weeks'],
#  ['No Significant Medical History'],
#  ['Hypothyroid'],
#  ['tb carrier, hep c', 'Substance Misuse'],
#  ['Anxiety'],
#  ['No Significant Medical History']]

# %%
diagnoses = Counter()
for hx in split_hist:
    for item in hx:
        diagnoses[item] += 1

# %%
len(diagnoses)
# Out:
# 29803

# %%
diagnoses.most_common()
# Out:
# [('No Significant Medical History', 48412),
#  ('Hypertension (HTN)', 18790),
#  ('High Cholesterol', 15828),
#  ('NIDDM (Non-Insulin-Dependent Diabetes Mellitus)', 7976),
#  ('High BP', 5142),
#  ('Depression', 5061),
#  ('Asthma', 4498),
#  ('Anxiety', 3785),
#  ('Hypothyroid', 3116),
#  ('Thyroid', 3059),
#  ('IDDM (Insulin-Dependent Diabetes Mellitus)', 2920),
#  ('Diabetes', 2775),
#  ('Arthritis', 1709),
#  ('Acid Reflux', 1600),
#  ('Gerd', 1498),
#  ('COPD (Chronic Obstructive Pulmonary Disease)', 1479),
#  ('MI (Myocardial Infarction)', 1446),
#  ('GERD (Gastroesophageal Reflux Disease)', 1344),
#  ('Anemia', 1143),
#  ('Seizure', 1056),
#  ('CHF (Congestive Heart Failure)', 1044),
#  ('Atrial Fibrillation (A Fib)', 1041),
#  ('Schizophrenia', 1027),
#  ('Substance Misuse', 948),
#  ('CVA (Cerebral vascular Accident)', 946),
#  ('Dementia', 924),
#  ('Enlarged Prostate', 809),
#  ('Kidney Stones', 746),
#  ('Immunizations up to Date', 725),
#  ('Gout', 666),
#  ('Migraines', 626),
#  ('Osteoporosis', 621),
#  ('Pacemaker/Cardioverter/Defib', 620),
#  ('ADHD (Attention Deficit Hyperactivity Disorder)', 589),
#  ('Chronic Back Pain', 555),
#  ('Smoker', 488),
#  ('Fibromyalgia', 477),
#  ('CAD (Coronary Artery Disease)', 474),
#  ('Breast Cancer', 469),
#  ('ETOH Abuse', 458),
#  ('UTI', 440),
#  ('Bi-Polar', 435),
#  ('Bypass Surgery', 421),
#  ('Rheumatoid Arthritis', 417),
#  ('Alcoholism', 410),
#  ('Dialysis Haemo/PD', 398),
#  ('Pneumonia', 397),
#  ('bipolar', 392),
#  ('CABG', 390),
#  ('Lung Cancer', 366),
#  ('Epilepsy', 365),
#  ('Sleep Apnea', 351),
#  ('htn', 344),
#  ('Stroke', 325),
#  ('Eczema', 320),
#  ('Prostate Cancer', 313),
#  ('Diverticulitis', 309),
#  ('CRF (Chronic Renal Failure)', 307),
#  ("Parkinson's", 305),
#  ('afib', 304),
#  ('TIA (Transient Ischemic Attack)', 292),
#  ('asthma', 272),
#  ('Gallstones', 272),
#  ('Hysterectomy', 266),
#  ('Vertigo', 266),
#  ("Alzheimer's", 266),
#  ('IBS (Irritable Bowel Syndrome)', 256),
#  ('PTSD (Post Traumatic Stress Disorder)', 255),
#  ('Cholecystectomy', 249),
#  ('MI', 247),
#  ('HTN', 246),
#  ('Constipation', 241),
#  ('stents', 239),
#  ('Glaucoma', 233),
#  ('Hyperthyroid', 231),
#  ('DVT (Deep Vein Thrombosis)', 230),
#  ('Uterine Fibroids', 230),
#  ('Sickle Cell', 224),
#  ('low iron', 217),
#  ('Hernia', 215),
#  ('Pancreatitis', 215),
#  ('Appendectomy', 214),
#  ('Angina', 213),
#  ('Autistic', 207),
#  ('Lupus', 205),
#  ('Ulcerative Colitis', 203),
#  ('thyroid', 201),
#  ("Crohn's Disease", 193),
#  ('Chronic Pain', 189),
#  ('Heart Murmur', 188),
#  ('depression', 188),
#  ('Back Pain', 185),
#  ('anxiety', 176),
#  ('angioplasty', 167),
#  ('Benign Prostatic Hypertension', 167),
#  ('MS (Multiple Sclerosis)', 167),
#  ('Endometriosis', 165),
#  ('Knee Replacement', 157),
#  ('Glaucoma Cataract/Cataract Repair', 156),
#  ('cardiac', 156),
#  ('BPH', 148),
#  ('VACCINES UP TO DATE', 148),
#  ('stent', 146),
#  ('Cirrhosis', 146),
#  ('OCD (Obsessive Compulsive Disorder)', 142),
#  ('Sciatica', 142),
#  ('gerd', 139),
#  ('Borderline Personality Disorder', 138),
#  ('Hepatitis C', 137),
#  ('Bronchitis', 137),
#  ('PE (Pulmonary Embolism)', 136),
#  ('Colitis', 132),
#  ('osteoarthritis', 132),
#  ('Lymphoma', 128),
#  ('kidney failure', 128),
#  ('NIDDM', 128),
#  ('GAD (Generalized Anxiety Disorder)', 125),
#  ('unknown', 124),
#  ('Heart Attack', 122),
#  ('GERD', 117),
#  ('Renal Colic', 106),
#  ('diabetes', 106),
#  ('Hip Replacement', 106),
#  ('PE', 103),
#  ('psychosis', 102),
#  ('Bladder Cancer', 98),
#  ('AFIB', 97),
#  ('pacemaker', 95),
#  ('Hiatus Hernia', 93),
#  ('Leukemia', 91),
#  ('Scoliosis', 91),
#  ('gout', 91),
#  ('Received Chemotherapy within 4 weeks', 90),
#  ('Neuropathy', 90),
#  ('acid reflux', 90),
#  ('prostate', 88),
#  ('PCOS', 88),
#  ('bph', 86),
#  ('ASTHMA', 84),
#  ('Liver Cancer', 84),
#  ('ovarian cyst', 83),
#  ('anemia', 82),
#  ('Panic Disorder', 81),
#  ('Tonsillectomy', 81),
#  ('fatty liver', 80),
#  ('CP (Cerebral Palsy)', 80),
#  ('BIPOLAR', 78),
#  ('Hearing Impaired', 77),
#  ('Spinal Stenosis', 76),
#  ('insomnia', 75),
#  ('ANXIETY', 73),
#  ('high cholesterol', 73),
#  ('Emphysema', 72),
#  ('Pulmonary Fibrosis', 72),
#  ('kidney stones', 72),
#  ('kidney disease', 71),
#  ('TURP (Transurethral Resection of the Prostate)', 68),
#  ('SVT', 68),
#  ('Celiac', 67),
#  ('HIV/AIDS', 65),
#  ('unable to obtain', 65),
#  ('DEPRESSION', 64),
#  ('mental health', 63),
#  ('seizures', 61),
#  ('Stomach Cancer', 59),
#  ('liver cirrhosis', 59),
#  ('Ovarian Cancer', 58),
#  ('colon ca', 58),
#  ('PVD (Peripheral Vascular Disease)', 58),
#  ('SBO/LBO (Small/Large Bowel Obstruction)', 57),
#  ('psoriasis', 57),
#  ('ANGIOPLASTY', 55),
#  ('mi', 55),
#  ('Peptic Ulcer', 54),
#  ('dementia', 54),
#  ('niddm', 54),
#  ('concussion', 52),
#  ('Bells Palsy', 52),
#  ('Esophageal Cancer', 52),
#  ('kidney issues', 52),
#  ('COPD', 52),
#  ('Ectopic Pregnancy', 52),
#  ('copd', 50),
#  ('seizure', 49),
#  ('arthritis', 48),
#  ('herniated disc', 47),
#  ('Mitral Valve Regurgitation', 47),
#  ('smoker', 46),
#  ('STEMI (ST-Elevation Myocardial Infarction)', 46),
#  ('Aneurism', 45),
#  ('Aortic Stenosis', 44),
#  ('CHF', 44),
#  ('cardiomyopathy', 44),
#  ('see list', 44),
#  ('high BP', 44),
#  ('Brain Cancer', 43),
#  ('dialysis', 43),
#  ('Bone Cancer', 43),
#  ('ADHD', 43),
#  ('colon cancer', 42),
#  ('hemorrhoids', 42),
#  ('arrythmia', 41),
#  ('IDDM', 41),
#  ('stroke', 40),
#  ('stomach ulcer', 39),
#  ('THYROID', 39),
#  ('palpitations', 38),
#  ('hypertension', 38),
#  ('Hepatitis', 38),
#  ('LOW IRON', 37),
#  ('Bipolar', 37),
#  ('Uterine Cancer', 37),
#  ('ulcer', 37),
#  ('Sarcoidosis', 36),
#  ('angiogram', 36),
#  ('vertigo', 36),
#  ('heart burn', 36),
#  ('htn,', 36),
#  ('shingles', 36),
#  ('ACID REFLUX', 36),
#  ('renal failure', 36),
#  ('a-fib', 35),
#  ('cellulitis', 35),
#  ('kidney problem', 34),
#  ('gall bladder removed', 34),
#  ('gastric bypass', 34),
#  ('HTN, high cholesterol', 34),
#  ('irregular heart beat', 33),
#  ('ACS (Acute Coronary Syndrome)', 32),
#  ('STENTS', 32),
#  ('Pulmonary Hypertension', 32),
#  ('CAD', 32),
#  ('migraines', 32),
#  ('thyroidectomy', 32),
#  ('croup', 32),
#  ('Stents', 32),
#  ('svt', 32),
#  ('iron deficiency', 32),
#  ('back pain', 32),
#  ('multiple myeloma', 32),
#  ('gastritis', 31),
#  ('febrile seizure', 31),
#  ('HYPERTENSION', 31),
#  ('back injury', 31),
#  ('drug abuse', 31),
#  ('depression, anxiety', 31),
#  ('hypotension', 31),
#  ('autism', 31),
#  ('gallbladder removed', 30),
#  ('ptca', 30),
#  ('ear infection', 30),
#  ('cholesterol', 30),
#  ('osteoporosis', 30),
#  ('Angioplasty', 29),
#  ('Skin Cancer', 29),
#  ('gestational diabetes', 29),
#  ('pcos', 29),
#  ('htn, cholesterol', 29),
#  ('Throat Cancer', 29),
#  ('gall bladder removal', 29),
#  ('2 stents', 29),
#  ('Paraplegia', 28),
#  ('ANEMIA', 28),
#  ('anxiety, depression', 28),
#  ('chrons', 28),
#  ('CVA', 28),
#  ('triple bypass', 28),
#  ('dyslipidemia', 28),
#  ('nerve pain', 28),
#  ('Osteoarthritis', 27),
#  ('Cardiac', 27),
#  ('cataract', 27),
#  ('SCI (Spinal Cord Injury)', 27),
#  ('Blind', 27),
#  ('OSTEOARTHRITIS', 26),
#  ('hyperlipidemia', 26),
#  ('STENT', 26),
#  ('HIGH BP', 26),
#  ('OA', 26),
#  ('Cancer', 26),
#  ('umbilical hernia', 26),
#  ('kidney transplant', 26),
#  ('3 stents', 26),
#  ('pericarditis', 25),
#  ('htn, high chol', 25),
#  ('heart disease', 25),
#  ('valve replacement', 25),
#  ('bipolar disorder', 25),
#  ('ITP (Immune Thrombocytopenic Purpura)', 25),
#  ('chronic back pain', 25),
#  ('cardiac stent', 25),
#  ('blood clot', 25),
#  ('hernia repair', 25),
#  ('smoking', 24),
#  ('chf', 24),
#  ('peritoneal dialysis', 24),
#  ('back surgery', 24),
#  ('AAA', 24),
#  ('developmental delay', 24),
#  ('INSOMNIA', 24),
#  ('eczema', 24),
#  ('headache', 24),
#  ('arrhythmia', 24),
#  ('hypothyroid', 24),
#  ('blood clots', 23),
#  ('kidney problems', 23),
#  ('knee surgery', 23),
#  ('bilateral knee replacement', 23),
#  ('ADD', 23),
#  ('UNKNOWN', 23),
#  ('Unknown', 23),
#  ('high blood pressure', 23),
#  ('parkinsons', 23),
#  ('pneumonia', 22),
#  ('brain injury', 22),
#  ('Cholecystitis', 22),
#  ('colostomy', 22),
#  ('SEIZURES', 22),
#  ('IBS', 22),
#  ('RA', 22),
#  ('scizophrenia', 22),
#  ('kidney infection', 21),
#  ('Anticoagulants', 21),
#  ('migraine', 21),
#  ('diabetic', 21),
#  ('ca breast', 21),
#  ('ovarian cysts', 21),
#  ('panic attacks', 21),
#  ('Psychosis', 21),
#  ('heart problem', 20),
#  ('cva', 20),
#  ('varicose veins', 20),
#  ('NONSMOKER', 20),
#  ('Afib', 20),
#  ('anaemia', 20),
#  ('headaches', 20),
#  ('ascites', 20),
#  ('prostate issues', 19),
#  ('ulcers', 19),
#  ('cyclic vomiting', 19),
#  ('suicidal', 19),
#  ('KIDNEY STONES', 19),
#  ('cardiac stents', 19),
#  ('ICD', 19),
#  ('restless leg syndrome', 19),
#  ('GOUT', 19),
#  ('hernia', 19),
#  ('CKD', 19),
#  ('htn, high cholesterol', 19),
#  ('developmentally delayed', 19),
#  ('fibroids', 19),
#  ('overactive bladder', 19),
#  ('brain tumor', 19),
#  ('ezcema', 19),
#  ('drug use', 19),
#  ('chest infection', 18),
#  ('cataracts', 18),
#  ('inguinal hernia', 18),
#  ('one kidney', 18),
#  ('thyroid cancer', 18),
#  ('sickle cell trait', 18),
#  ('HTN,', 18),
#  ('glucoma', 18),
#  ('fibromyalgia', 18),
#  ('ODD', 18),
#  ('diet controlled diabetes', 18),
#  ('Pneumothorax', 18),
#  ('KIDNEY ISSUES', 18),
#  ('sciatica', 18),
#  ('down syndrome', 18),
#  ('hypothyroidism', 18),
#  ('hard of hearing', 18),
#  ('gall stones', 18),
#  ('chronic kidney disease', 18),
#  ('heart failure', 18),
#  ('hemodialysis', 18),
#  ('PSYCHOSIS', 17),
#  ('gallbladder removal', 17),
#  ('c-section', 17),
#  ('mitral valve prolapse', 17),
#  ('constipation', 17),
#  ('VACCINES UP TODATE', 17),
#  ('Low iron', 17),
#  ('falls', 17),
#  ('iddm', 17),
#  ('Acid reflux', 17),
#  ('ARTHRITIS', 17),
#  ('legally blind', 17),
#  ('HIGH CHOLESTEROL', 17),
#  ('mood disorder', 17),
#  ('liver disease', 17),
#  ('high BP, high cholesterol', 17),
#  ('DRUG ABUSE', 17),
#  ('macular degeneration', 17),
#  ('sleep apnea', 17),
#  ('liver issues', 17),
#  ('KIDNEY FAILURE', 16),
#  ('abdominal hernia', 16),
#  ('high chol', 16),
#  ('degenerative disc disease', 16),
#  ('left knee replacement', 16),
#  ('ALS (Amyotrophic Lateral Sclerosis)', 16),
#  ('incomplete list', 16),
#  ('PTSD', 16),
#  ('bradycardia', 16),
#  ('Tinnitus', 16),
#  ('IUD', 16),
#  ('urinary retention', 16),
#  ('DDD', 16),
#  ('COLON CANCER', 16),
#  ('Visually Impaired', 16),
#  ('Upper GI Bleed', 16),
#  ('MVC', 16),
#  ('head injury', 16),
#  ('Pacemaker', 16),
#  ('bladder infection', 16),
#  ('COLON CA', 15),
#  ('syncope', 15),
#  ('CBAG', 15),
#  ('Duodenal Ulcer', 15),
#  ('hearing loss', 15),
#  ('palpitation', 15),
#  ('stents x 2', 15),
#  ('fetal alcohol syndrome', 15),
#  ('kidney cancer', 15),
#  ('bipass', 15),
#  ('obesity', 15),
#  ('Splenectomy', 15),
#  ('chronic cough', 15),
#  ('A.Fib', 15),
#  ('chol', 15),
#  ('UNABLE TO OBTAIN', 15),
#  ('crestor', 15),
#  ('UTD', 15),
#  ('NIDDM, HTN', 15),
#  ('CLL', 15),
#  ('Hi cholesterol', 15),
#  ('substance abuse', 14),
#  ('uti', 14),
#  ('htn, niddm', 14),
#  ('heart murmur', 14),
#  ('gastric ulcer', 14),
#  ('peripheral neuropathy', 14),
#  ('GERDS', 14),
#  ('acne', 14),
#  ('WPW', 14),
#  ('HTN, NIDDM', 14),
#  ('liver failure', 14),
#  ('Irregular heart beat', 14),
#  ('kidney issue', 14),
#  ('PACEMAKER', 14),
#  ('right hip replacement', 14),
#  ('chronic bronchitis', 14),
#  ('Meningitis', 14),
#  ('herpes', 14),
#  ('hemorrhoid', 14),
#  ('4 stents', 14),
#  ('brain tumour', 14),
#  ('polyps', 14),
#  ('cervical cancer', 14),
#  ('asa', 14),
#  ('PSORIASIS', 14),
#  ('sinusitis', 14),
#  ('Cardiac stents', 14),
#  ('Liver cirrhosis', 14),
#  ('appendicitis', 14),
#  ('AUTISM', 14),
#  ('ESRD', 14),
#  ('MDS', 13),
#  ('tubal ligation', 13),
#  ('premature', 13),
#  ('tremors', 13),
#  ('enlarged heart', 13),
#  ('Psoriasis', 13),
#  ('FATTY LIVER', 13),
#  ('Insomnia', 13),
#  ('high', 13),
#  ('Kidney disease', 13),
#  ('cholestrol', 13),
#  ('hysterectomy', 13),
#  ('stents x2', 13),
#  ('adhd', 13),
#  ('LBBB', 13),
#  ('febrile seizures', 13),
#  ('TB', 13),
#  ('heartburn', 13),
#  ('enlarge prostate', 13),
#  ('Bulimia', 13),
#  ('crohns', 13),
#  ('melanoma', 13),
#  ('paranoia', 13),
#  ('chronic knee pain', 13),
#  ('low hgb', 13),
#  ('colon CA', 13),
#  ('mastectomy', 13),
#  ('kidney stone', 13),
#  ('bipolar  disorder', 13),
#  ('hallucinations', 12),
#  ('cabg', 12),
#  ('diverticulosis', 12),
#  ('knee pain', 12),
#  ('metformin', 12),
#  ('Testicular Cancer', 12),
#  ('gurd', 12),
#  ('stress', 12),
#  ('stent x 2', 12),
#  ('borderline diabetes', 12),
#  ('ca colon', 12),
#  ('prediabetic', 12),
#  ('miscarriage', 12),
#  ('breast ca', 12),
#  ('hip surgery', 12),
#  ('sleep disorder', 12),
#  ('hep c', 12),
#  ('bowel resection', 12),
#  ('Low Iron', 12),
#  ('cardioversion', 12),
#  ('Anorexia', 12),
#  ('aortic valve replacement', 12),
#  ('low bp', 12),
#  ('excema', 12),
#  ('jaundice', 12),
#  ('liver problem', 12),
#  ('insomia', 12),
#  ('slipped disc', 12),
#  ('schizophrenia', 12),
#  ('stomach issues', 12),
#  ('kidney', 12),
#  ('epilepsy', 12),
#  ('low BP', 12),
#  ('alzheimers', 12),
#  ('dysphagia', 12),
#  ('DEMENTIA', 12),
#  ('open heart surgery', 12),
#  ('Mental Health', 12),
#  ('High cholesterol', 12),
#  ('sepsis', 11),
#  ('strep throat', 11),
#  ('STROKE', 11),
#  ('low hemoglobin', 11),
#  ('Gastrointestinal (GI) Bleed', 11),
#  ('h pylori', 11),
#  ('polio', 11),
#  ('throat infection', 11),
#  ('nephrotic syndrome', 11),
#  ('blood pressure', 11),
#  ('BACK PAIN', 11),
#  ('delusional disorder', 11),
#  ('hyponatremia', 11),
#  ('heart surgery', 11),
#  ('suicidal attempts', 11),
#  ('lower back pain', 11),
#  ('mental health issues', 11),
#  ('exzema', 11),
#  ('pancreatitis', 11),
#  ('TRIPLE BYPASS', 11),
#  ('pancreatic ca', 11),
#  ('Gall bladder removed', 11),
#  ('h-pylori', 11),
#  ('A. Fib', 11),
#  ('Hypertension', 11),
#  ('CELLULITIS', 11),
#  ('Gestational diabetes', 11),
#  ('hip fracture', 11),
#  ('vasculitis', 11),
#  ('bowel obstruction', 11),
#  ('liver transplant', 11),
#  ('NIDDM,', 11),
#  ('Gallbladder removed', 11),
#  ('Hemodialysis', 11),
#  ('Iron deficiency', 11),
#  ('MI ', 11),
#  ('ca lung', 11),
#  ('aortic aneurysm', 11),
#  ('deaf', 10),
#  ('Gastritis', 10),
#  ('DEPRESSION, ANXIETY', 10),
#  ('URINARY RETENTION', 10),
#  ('MENTAL HEALTH', 10),
#  ('BACK INJURY', 10),
#  ('OVARIAN CYST', 10),
#  ('LIVER CIRRHOSIS', 10),
#  ('pe', 10),
#  ('ulcerative colitis', 10),
#  ('SOMATIC PAIN DISORDER', 10),
#  ('lymphoma', 10),
#  ('cancer', 10),
#  ('Dialysis', 10),
#  ('Prostate', 10),
#  ('MRSA', 10),
#  ('concussions', 10),
#  ('chronic constipation', 10),
#  ('SEE LIST', 10),
#  ('Muscular Dystrophy', 10),
#  ('CONCUSSION', 10),
#  ('joint pain', 10),
#  ('gallbladder', 10),
#  ('ASD', 10),
#  ('G6PD', 10),
#  ('Congenital heart ', 10),
#  ('osteomylitis', 10),
#  ('acute renal failure', 10),
#  ('chronic neck pain', 10),
#  ('C-section', 10),
#  ('thyroid ca', 10),
#  ('hypoglycemia', 10),
#  ('pancreatic cancer', 10),
#  ('Mental health', 10),
#  ('myocarditis', 10),
#  ('fibroid', 10),
#  ('PTCA', 10),
#  ('bronchitis', 10),
#  ('delirium', 10),
#  ('osteopenia', 10),
#  ('angina', 10),
#  ('RENAL FAILURE', 10),
#  ('lupus', 10),
#  ('right knee replacement', 10),
#  ('niddm, htn', 10),
#  ('brain aneurysm', 10),
#  ('heart issues', 10),
#  ('eating disorder', 10),
#  ('KIDNEY DYSFUNCTION', 10),
#  ('Croup', 10),
#  ('asthma,', 10),
#  ('tendonitis', 10),
#  ('poor historian', 10),
#  ('athritis', 10),
#  ('ECZEMA', 10),
#  ('Autism', 10),
#  ('high cholesterol, high BP', 10),
#  ('gallstones', 10),
#  ('G2P1', 10),
#  ('MS', 10),
#  ('nka', 10),
#  ('HTN, HIGH CHOL', 9),
#  ('SEIZURE', 9),
#  ('left breast ca', 9),
#  ('Liver Cirrhosis', 9),
#  ('heart block', 9),
#  ('chrons disease', 9),
#  ("Meniere's", 9),
#  ('ANGINA', 9),
#  ('heart murmer', 9),
#  ('mental issue', 9),
#  ('bypass', 9),
#  ('DVT', 9),
#  ('left hip replacement', 9),
#  ('spina bifida', 9),
#  ('H. Pylori', 9),
#  ('Stent', 9),
#  ('panic attack', 9),
#  ('SMOKER', 9),
#  ('cpap', 9),
#  ('PROSTATE ISSUES', 9),
#  ('TIA', 9),
#  ('thalassemia', 9),
#  ('Quadriplegia', 9),
#  ('stents x3', 9),
#  ('epistaxis', 9),
#  ('add', 9),
#  ('irregular heart rate', 9),
#  ('chronic leg pain', 9),
#  ('A-fib', 9),
#  ('ETOH abuse', 9),
#  ('sinus infection', 9),
#  ('Fatty liver', 9),
#  ('scoliosis', 9),
#  ('lung ca', 9),
#  ('ventolin', 9),
#  ('Pyelonephritis', 9),
#  ('tachycardia', 9),
#  ('HEMORRHOIDS', 9),
#  ('ablation', 9),
#  ('cardiac issues', 9),
#  ('Kidney stones', 9),
#  ('INGUINAL HERNIA', 9),
#  ('pleural effusion', 9),
#  ('Premature', 9),
#  ('HYPOTHYROID', 9),
#  ('high cholesterol, HTN', 9),
#  ('DNR', 9),
#  ('Mi', 9),
#  ('METHADONE PROGRAM', 9),
#  ('niddm,', 9),
#  ('osteoprosis', 9),
#  ('ANXIETY, DEPRESSION', 9),
#  ('ca prostate', 9),
#  ('HTN, high cholesterol, NIDDM', 9),
#  ('multiple myloma', 9),
#  ('low thyroid', 9),
#  ('spinal surgery', 9),
#  ('HIGH BP, HIGH CHOL', 9),
#  ('suicide attempts', 8),
#  ('STENT X 1', 8),
#  ('LOW BP', 8),
#  ('KIDNEY DISEASE', 8),
#  ('c section', 8),
#  ('recent uti', 8),
#  ('mitral valve repair', 8),
#  ('DEVELOPMENTAL DELAY', 8),
#  ('colan ca', 8),
#  ('CARDIOMYOPATHY', 8),
#  ('GASTRIC BYPASS', 8),
#  ('Herniated Disc', 8),
#  ('irregular heartbeat', 8),
#  ('CML', 8),
#  ('PCOD', 8),
#  ('Concussion', 8),
#  ('HIV', 8),
#  ('carpal tunnel', 8),
#  ('fluid retention', 8),
#  ('iron', 8),
#  ('partial hysterectomy', 8),
#  ('mvc', 8),
#  ('HTN, NIDDM, high cholesterol', 8),
#  ('withdrawal seizures', 8),
#  ('chronic shoulder pain', 8),
#  ('VSD', 8),
#  ('PID (Pelvic Inflammatory Disease)', 8),
#  ('stent x 1', 8),
#  ('hypertension, high cholesterol', 8),
#  ('Thyroidectomy', 8),
#  ('anemic', 8),
#  ('HTN, ', 8),
#  ('EPILEPSY', 8),
#  ('enlarged prostate', 8),
#  ('See list', 8),
#  ('MARIJUANA USE', 8),
#  ('synthroid', 8),
#  ('MULTIPLE MYELOMA', 8),
#  ('MITRAL VALVE PROLAPSE', 8),
#  ('atrial flutter', 8),
#  ('suicidal ideation', 8),
#  ('Bilateral knee replacement', 8),
#  ('depression,', 8),
#  ('bipolar, depression', 8),
#  ('SLEEPING ISSUES', 8),
#  ('DEGENERATIVE DISC DISEASE', 8),
#  ('Kidney issues', 8),
#  ('elevated liver enzymes', 8),
#  ('quad bypass', 8),
#  ('THROAT INFECTION', 8),
#  ('hemiplegia', 8),
#  ('colitis', 8),
#  ('prostate problem', 8),
#  ('thrombocytopenia', 8),
#  ('Gastroparesis', 8),
#  ('withdrawal seizure', 8),
#  ('left knee surgery', 8),
#  ('tbi', 8),
#  ('a.fib', 8),
#  ('diverticulitis', 8),
#  ('GI bleed', 8),
#  ('bladder issues', 8),
#  ('degenerative disc', 8),
#  ('STENT X1', 8),
#  ('Colon Ca', 8),
#  ('UMBILICAL HERNIA', 8),
#  ('pituitary tumor', 8),
#  ('heart problems', 8),
#  ('CROUP', 8),
#  ('cdiff', 8),
#  ('hematuria', 8),
#  ('pulmonary edema', 8),
#  ('carpal tunnel syndrome', 8),
#  ('pacemaker ', 8),
#  ('Ear infection', 8),
#  ('Hypercholesterolemia', 8),
#  ('low platelets', 7),
#  ('Kidney failure', 7),
#  ('high cholestrol', 7),
#  ('drug addiction', 7),
#  ('hole in heart', 7),
#  ('FULL TERM', 7),
#  ('pre diabetes', 7),
#  ('THYROID CA', 7),
#  ('schizoaffective disorder', 7),
#  ('Cellulitis', 7),
#  ('hernia surgery', 7),
#  ('Kidney Disease', 7),
#  ('social anxiety', 7),
#  ('stent x2', 7),
#  ('graves disease', 7),
#  ("chron's", 7),
#  ('STREP THROAT', 7),
#  ('CARDIAC', 7),
#  ('cad', 7),
#  ('glaucoma', 7),
#  ('heart', 7),
#  ('hepatitis B', 7),
#  ('anal fissure', 7),
#  ('diabetes, high cholesterol', 7),
#  ('leaky valve', 7),
#  ('PTCA WITH STENTS', 7),
#  ('MI 2017', 7),
#  ('htn, gerd', 7),
#  ('Developmental delay', 7),
#  ('polycystic ovaries', 7),
#  ('Kidney problem', 7),
#  ('Deaf', 7),
#  ('stent 2008', 7),
#  ('icd', 7),
#  ('uric acid', 7),
#  ('scleroderma', 7),
#  ('tripple bypass', 7),
#  ('HYPERTENSION, HIGH CHOLESTEROL', 7),
#  ('heart condition', 7),
#  ('ASA', 7),
#  ('hyperkalemia', 7),
#  ('non verbal', 7),
#  ('quadruple bypass', 7),
#  ('HIGH CHOL', 7),
#  ('Kidney Failure', 7),
#  ('low potassium', 7),
#  ('colonoscopy', 7),
#  ('pace maker', 7),
#  ('MI x2', 7),
#  ('cardiac arrest', 7),
#  ('odd', 7),
#  ('thy', 7),
#  ('endocarditis', 7),
#  ('prostate ca', 7),
#  ('dizziness', 7),
#  ('Hep C', 7),
#  ('TMJ', 7),
#  ('pre diabetic', 7),
#  ('Palpitations', 7),
#  ('appendectomy', 7),
#  ('hystrectomy', 7),
#  ('lung infection', 7),
#  ('SUICIDAL IDEATION', 7),
#  ('H pylori', 7),
#  ('right knee surgery', 7),
#  ('cholesterol, htn', 7),
#  ('left shoulder injury', 7),
#  ('brain surgery', 7),
#  ('G1P0', 7),
#  ('PNEUMONIA', 7),
#  ('renal stone', 7),
#  ('FIBROIDS', 7),
#  ('ckd', 7),
#  ('osteo arthritis', 7),
#  ('anxiety,', 7),
#  ('downs syndrome', 7),
#  ('COLOSTOMY', 7),
#  ('stents x 3', 7),
#  ('pud', 7),
#  ('hemophilia', 7),
#  ('kidney ca', 7),
#  ('dry eyes', 7),
#  ('UTIs', 7),
#  ('pre eclampsia', 7),
#  ('menorrhagia', 7),
#  ('prostatitis', 7),
#  ('hemorroids', 7),
#  ('NIDDM, HIGH CHOL', 7),
#  ('type 2 dm', 7),
#  ('marijuana use', 7),
#  ('iddm,', 7),
#  ('tia', 7),
#  ('angio', 7),
#  ('high chol, htn', 7),
#  ('up to date to immunization', 7),
#  ('neck pain', 7),
#  ('Hypothyroidism', 7),
#  ('DIABETES', 7),
#  ('htn, high chol, niddm', 7),
#  ('Quadruple bypass', 7),
#  ('colostomy bag', 7),
#  ('high BP, diabetes', 7),
#  ('pre-diabetic', 7),
#  ('decreased kidney function', 6),
#  ('mitral stenosis', 6),
#  ('liver cirrhosis ', 6),
#  ("chron's disease", 6),
#  ('Osteoarthritis ', 6),
#  ('ptsd', 6),
#  ('Shingles', 6),
#  ('ETOH ABUSE', 6),
#  ('triple bipass', 6),
#  ('Multiple Myeloma', 6),
#  ('Polio', 6),
#  ('PROSTRATE', 6),
#  ('pinched nerve', 6),
#  ('frequent UTIs', 6),
#  ('NO FAMILY HX MI', 6),
#  ('angioplasty with 2 stents', 6),
#  ('leukemia', 6),
#  ('hemmerhoids', 6),
#  ('vascular dementia', 6),
#  ('gull bladder removed', 6),
#  ('trigeminal neuralgia', 6),
#  ('Miscarriage', 6),
#  ('ca liver', 6),
#  ('gall bladder removal ', 6),
#  ('PIH (Pregnancy Induced Hypertension)', 6),
#  ('enlarged aorta', 6),
#  ('SMOKING', 6),
#  ('ANGIOGRAM', 6),
#  ('ataxia', 6),
#  ('SLEEP APNEA', 6),
#  ('ciliac disease', 6),
#  ('lobectomy', 6),
#  ('thryoid', 6),
#  ('hypokalemia', 6),
#  ('?asthma', 6),
#  ('diabetic neuropathy', 6),
#  ('OVERACTIVE BLADDER', 6),
#  ('stent x1', 6),
#  ('Ovarian Cyst', 6),
#  ('htn, thyroid', 6),
#  ('On Prednisone/Steroids', 6),
#  ("Marfan's Syndrome", 6),
#  ('polymyalgia rheumatica', 6),
#  ('depression/anxiety', 6),
#  ('VERTIGO', 6),
#  ('blood in stool', 6),
#  ('DIABETIC NEUROPATHY', 6),
#  ('CHRONS', 6),
#  ('MI 2013', 6),
#  ('DRUG USE', 6),
#  ('neonatal jaundice', 6),
#  ('MIGRANES', 6),
#  ('SHINGLES', 6),
#  ('G6PD deficiency', 6),
#  ('chronic uti', 6),
#  ('gall bladder removed ', 6),
#  ('confusion', 6),
#  ('Macular degeneration', 6),
#  ('neurogenic bladder', 6),
#  ('hydronephrosis', 6),
#  ('autoimmune pancreatitis', 6),
#  ('chronic abdominal pain', 6),
#  ('2 cardiac stents', 6),
#  ('SCHIZOAFFECTIVE DISORDER', 6),
#  ('benign hypertension', 6),
#  ('ear infections', 6),
#  ('low sodium', 6),
#  ('lung issues', 6),
#  ('traumatic brain injury', 6),
#  ('?afib', 6),
#  ('cholesterol, niddm', 6),
#  ('sleeping problem', 6),
#  ('iud', 6),
#  ('liver cirosis', 6),
#  ('Blood clots', 6),
#  ('prediabetes', 6),
#  ('Colon Cancer', 6),
#  ('5 stents', 6),
#  ('gastroparesis', 6),
#  ('kidney transplant ', 6),
#  ('Kidney problems', 6),
#  ('sinus', 6),
#  ('HEAD INJURY', 6),
#  ('Brain Injury', 6),
#  ('Fatty Liver', 6),
#  ('fatty liver disease', 6),
#  ('Colostomy', 6),
#  ('aplastic anemia', 6),
#  ('yeast infection', 6),
#  ('prostrate', 6),
#  ('major depressive disorder', 6),
#  ('stomach ulcers', 6),
#  ('syncopal episodes', 6),
#  ('cataract surgery', 6),
#  ('HEMODIALYSIS', 6),
#  ('Smoking', 6),
#  ('NIDDM, high cholesterol', 6),
#  ('rheumatoid arthritis', 6),
#  ('C Dif (Clostridium difficile)', 6),
#  ('HYPERTENSION, HIGH CHOLESTEROL, NIDDM', 6),
#  ('neuropathy', 6),
#  ('HYPEREMESIS', 6),
#  ('herniated discs', 6),
#  ('PARKINSONS', 6),
#  ('bulging disc', 6),
#  ('Htn,', 6),
#  ('shoulder pain', 6),
#  ('candesartan', 6),
#  ('nerve damage', 6),
#  ('mitral valve replacement', 6),
#  ('learning disability', 6),
#  ('liver', 6),
#  ('addiction', 6),
#  ('renal insufficiency', 6),
#  ('fever', 6),
#  ('cognitive impairment', 6),
#  ('fibromylagia', 6),
#  ('RSV', 6),
#  ('polycythemia', 6),
#  ('HEP C', 6),
#  ('breast  cancer', 6),
#  ('Thyroid cancer', 6),
#  ('? asthma', 6),
#  ('abdominal pain', 6),
#  ('defib', 6),
#  ('vaccinations are up to date', 6),
#  ('leg pain', 6),
#  ('Stents x 2', 6),
#  ...]

# %%
dx_rank_dict = {item[0]:i+1 for i,item in enumerate(diagnoses.most_common())}

# %%
len(dx_rank_dict)
# Out:
# 29803

# %%
dx_freq_dict = {item[0]:item[1]/len(diagnoses) for item in diagnoses.most_common()}

# %%
dx_rank_dict.items()
# Out:
# dict_items([('No Significant Medical History', 1), ('Hypertension (HTN)', 2), ('High Cholesterol', 3), ('NIDDM (Non-Insulin-Dependent Diabetes Mellitus)', 4), ('High BP', 5), ('Depression', 6), ('Asthma', 7), ('Anxiety', 8), ('Hypothyroid', 9), ('Thyroid', 10), ('IDDM (Insulin-Dependent Diabetes Mellitus)', 11), ('Diabetes', 12), ('Arthritis', 13), ('Acid Reflux', 14), ('Gerd', 15), ('COPD (Chronic Obstructive Pulmonary Disease)', 16), ('MI (Myocardial Infarction)', 17), ('GERD (Gastroesophageal Reflux Disease)', 18), ('Anemia', 19), ('Seizure', 20), ('CHF (Congestive Heart Failure)', 21), ('Atrial Fibrillation (A Fib)', 22), ('Schizophrenia', 23), ('Substance Misuse', 24), ('CVA (Cerebral vascular Accident)', 25), ('Dementia', 26), ('Enlarged Prostate', 27), ('Kidney Stones', 28), ('Immunizations up to Date', 29), ('Gout', 30), ('Migraines', 31), ('Osteoporosis', 32), ('Pacemaker/Cardioverter/Defib', 33), ('ADHD (Attention Deficit Hyperactivity Disorder)', 34), ('Chronic Back Pain', 35), ('Smoker', 36), ('Fibromyalgia', 37), ('CAD (Coronary Artery Disease)', 38), ('Breast Cancer', 39), ('ETOH Abuse', 40), ('UTI', 41), ('Bi-Polar', 42), ('Bypass Surgery', 43), ('Rheumatoid Arthritis', 44), ('Alcoholism', 45), ('Dialysis Haemo/PD', 46), ('Pneumonia', 47), ('bipolar', 48), ('CABG', 49), ('Lung Cancer', 50), ('Epilepsy', 51), ('Sleep Apnea', 52), ('htn', 53), ('Stroke', 54), ('Eczema', 55), ('Prostate Cancer', 56), ('Diverticulitis', 57), ('CRF (Chronic Renal Failure)', 58), ("Parkinson's", 59), ('afib', 60), ('TIA (Transient Ischemic Attack)', 61), ('asthma', 62), ('Gallstones', 63), ('Hysterectomy', 64), ('Vertigo', 65), ("Alzheimer's", 66), ('IBS (Irritable Bowel Syndrome)', 67), ('PTSD (Post Traumatic Stress Disorder)', 68), ('Cholecystectomy', 69), ('MI', 70), ('HTN', 71), ('Constipation', 72), ('stents', 73), ('Glaucoma', 74), ('Hyperthyroid', 75), ('DVT (Deep Vein Thrombosis)', 76), ('Uterine Fibroids', 77), ('Sickle Cell', 78), ('low iron', 79), ('Hernia', 80), ('Pancreatitis', 81), ('Appendectomy', 82), ('Angina', 83), ('Autistic', 84), ('Lupus', 85), ('Ulcerative Colitis', 86), ('thyroid', 87), ("Crohn's Disease", 88), ('Chronic Pain', 89), ('Heart Murmur', 90), ('depression', 91), ('Back Pain', 92), ('anxiety', 93), ('angioplasty', 94), ('Benign Prostatic Hypertension', 95), ('MS (Multiple Sclerosis)', 96), ('Endometriosis', 97), ('Knee Replacement', 98), ('Glaucoma Cataract/Cataract Repair', 99), ('cardiac', 100), ('BPH', 101), ('VACCINES UP TO DATE', 102), ('stent', 103), ('Cirrhosis', 104), ('OCD (Obsessive Compulsive Disorder)', 105), ('Sciatica', 106), ('gerd', 107), ('Borderline Personality Disorder', 108), ('Hepatitis C', 109), ('Bronchitis', 110), ('PE (Pulmonary Embolism)', 111), ('Colitis', 112), ('osteoarthritis', 113), ('Lymphoma', 114), ('kidney failure', 115), ('NIDDM', 116), ('GAD (Generalized Anxiety Disorder)', 117), ('unknown', 118), ('Heart Attack', 119), ('GERD', 120), ('Renal Colic', 121), ('diabetes', 122), ('Hip Replacement', 123), ('PE', 124), ('psychosis', 125), ('Bladder Cancer', 126), ('AFIB', 127), ('pacemaker', 128), ('Hiatus Hernia', 129), ('Leukemia', 130), ('Scoliosis', 131), ('gout', 132), ('Received Chemotherapy within 4 weeks', 133), ('Neuropathy', 134), ('acid reflux', 135), ('prostate', 136), ('PCOS', 137), ('bph', 138), ('ASTHMA', 139), ('Liver Cancer', 140), ('ovarian cyst', 141), ('anemia', 142), ('Panic Disorder', 143), ('Tonsillectomy', 144), ('fatty liver', 145), ('CP (Cerebral Palsy)', 146), ('BIPOLAR', 147), ('Hearing Impaired', 148), ('Spinal Stenosis', 149), ('insomnia', 150), ('ANXIETY', 151), ('high cholesterol', 152), ('Emphysema', 153), ('Pulmonary Fibrosis', 154), ('kidney stones', 155), ('kidney disease', 156), ('TURP (Transurethral Resection of the Prostate)', 157), ('SVT', 158), ('Celiac', 159), ('HIV/AIDS', 160), ('unable to obtain', 161), ('DEPRESSION', 162), ('mental health', 163), ('seizures', 164), ('Stomach Cancer', 165), ('liver cirrhosis', 166), ('Ovarian C ...

# %%
dx_freq_dict.items()
# Out:
# dict_items([('No Significant Medical History', 1.6244002281649499), ('Hypertension (HTN)', 0.6304734422709123), ('High Cholesterol', 0.5310874744153273), ('NIDDM (Non-Insulin-Dependent Diabetes Mellitus)', 0.26762406469147404), ('High BP', 0.1725329664798846), ('Depression', 0.16981511928329363), ('Asthma', 0.15092440358353185), ('Anxiety', 0.12700063751971277), ('Hypothyroid', 0.10455323289601717), ('Thyroid', 0.1026406737576754), ('IDDM (Insulin-Dependent Diabetes Mellitus)', 0.09797671375364896), ('Diabetes', 0.09311143173506023), ('Arthritis', 0.05734322048115961), ('Acid Reflux', 0.053685870549944635), ('Gerd', 0.05026339630238567), ('COPD (Chronic Obstructive Pulmonary Disease)', 0.04962587658960507), ('MI (Myocardial Infarction)', 0.048518605509512466), ('GERD (Gastroesophageal Reflux Disease)', 0.04509613126195349), ('Anemia', 0.0383518437741167), ('Seizure', 0.03543267456296346), ('CHF (Congestive Heart Failure)', 0.03503003053383887), ('Atrial Fibrillation (A Fib)', 0.03492936952655773), ('Schizophrenia', 0.03445961815924571), ('Substance Misuse', 0.0318088783008422), ('CVA (Cerebral vascular Accident)', 0.031741770962654764), ('Dementia', 0.031003590242593027), ('Enlarged Prostate', 0.027144918296815757), ('Kidney Stones', 0.025031037143911687), ('Immunizations up to Date', 0.024326410092943663), ('Gout', 0.022346743616414456), ('Migraines', 0.021004596852665838), ('Osteoporosis', 0.02083682850719726), ('Pacemaker/Cardioverter/Defib', 0.020803274838103545), ('ADHD (Attention Deficit Hyperactivity Disorder)', 0.01976311109619837), ('Chronic Back Pain', 0.018622286347012046), ('Smoker', 0.016374190517733114), ('Fibromyalgia', 0.016005100157702245), ('CAD (Coronary Artery Disease)', 0.0159044391504211), ('Breast Cancer', 0.015736670804952523), ('ETOH Abuse', 0.015367580444921652), ('UTI', 0.014763614401234776), ('Bi-Polar', 0.014595846055766198), ('Bypass Surgery', 0.014126094688454183), ('Rheumatoid Arthritis', 0.01399188001207932), ('Alcoholism', 0.013757004328423313), ('Dialysis Haemo/PD', 0.013354360299298729), ('Pneumonia', 0.013320806630205012), ('bipolar', 0.013153038284736436), ('CABG', 0.013085930946549005), ('Lung Cancer', 0.012280642888299836), ('Epilepsy', 0.01224708921920612), ('Sleep Apnea', 0.011777337851894104), ('htn', 0.011542462168238097), ('Stroke', 0.010904942455457504), ('Eczema', 0.010737174109988928), ('Prostate Cancer', 0.010502298426332919), ('Diverticulitis', 0.010368083749958058), ('CRF (Chronic Renal Failure)', 0.010300976411770628), ("Parkinson's", 0.010233869073583196), ('afib', 0.010200315404489482), ('TIA (Transient Ischemic Attack)', 0.009797671375364896), ('asthma', 0.009126597993490589), ('Gallstones', 0.009126597993490589), ('Hysterectomy', 0.008925275978928296), ('Vertigo', 0.008925275978928296), ("Alzheimer's", 0.008925275978928296), ('IBS (Irritable Bowel Syndrome)', 0.008589739287991142), ('PTSD (Post Traumatic Stress Disorder)', 0.008556185618897427), ('Cholecystectomy', 0.008354863604335135), ('MI', 0.008287756266147703), ('HTN', 0.008254202597053988), ('Constipation', 0.00808643425158541), ('stents', 0.00801932691339798), ('Glaucoma', 0.007818004898835688), ('Hyperthyroid', 0.007750897560648257), ('DVT (Deep Vein Thrombosis)', 0.007717343891554542), ('Uterine Fibroids', 0.007717343891554542), ('Sickle Cell', 0.007516021876992249), ('low iron', 0.007281146193336242), ('Hernia', 0.00721403885514881), ('Pancreatitis', 0.00721403885514881), ('Appendectomy', 0.007180485186055095), ('Angina', 0.0071469315169613796), ('Autistic', 0.006945609502399088), ('Lupus', 0.006878502164211656), ('Ulcerative Colitis', 0.006811394826024226), ('thyroid', 0.006744287487836795), ("Crohn's Disease", 0.006475858135087072), ('Chronic Pain', 0.00634164345871221), ('Heart Murmur', 0.006308089789618495), ('depression', 0.006308089789618495), ('Back Pain', 0.006207428782337349), ('anxiety', 0.00590544576049391), ('angioplasty', 0.0056034627386504715), ('Benign Prostatic Hypertension', 0.00560346273865047 ...

# %%
split_hist_len = [len(item) for item in split_hist]

# %%
hxdf = pd.DataFrame(split_hist_len)

# %%
hxdf.describe()
# Out:
#                    0
# count  122211.000000
# mean        1.759964
# std         1.409361
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        27.000000

# %%
lengths = Counter(split_hist_len); lengths
# Out:
# Counter({1: 80806,
#          6: 1769,
#          4: 6278,
#          5: 3437,
#          2: 17785,
#          3: 10313,
#          8: 481,
#          9: 227,
#          7: 855,
#          13: 20,
#          11: 57,
#          10: 116,
#          12: 30,
#          15: 15,
#          14: 9,
#          17: 4,
#          18: 2,
#          16: 6,
#          27: 1})

# %%
for k,v in sorted(lengths.items()):
    print (k, '{0:2f}%'.format(v*100/len(split_hist_len)))
# Out:
# 1 66.120071%
# 2 14.552700%
# 3 8.438684%
# 4 5.137017%
# 5 2.812349%
# 6 1.447497%
# 7 0.699610%
# 8 0.393582%
# 9 0.185744%
# 10 0.094918%
# 11 0.046641%
# 12 0.024548%
# 13 0.016365%
# 14 0.007364%
# 15 0.012274%
# 16 0.004910%
# 17 0.003273%
# 18 0.001637%
# 27 0.000818%

# %% [markdown]
# So here's what I want to do now:
# - I want to loop through each item in the split_hist list.
# - For each of these items (lists), I want to make a list/tuple of possible history items
# - To make this list, I will iterate through each entry in the item, check it's rank in the most common list
# - then I will rank them according to their place in the most-common list and take up to 6
# - will pad with zero for cases with less than 6 histories

# %%
#v2
ordered_hist = []
for item in split_hist:
    top_6 = []
    for hx in item:
        top_6.append((dx_rank_dict[hx], hx))
    sort = sorted(top_6)
    sort2 = [ii for i,ii in sort]
    if len(sort2) > 6:
        sort2 = sort2[:5]
    if len(sort2) < 6:
        pad_req = 6-len(sort2)
        i = 0
        while i < pad_req:
            sort2.append(np.nan) #('n/a')
            i = i+1
        
    #print (top_6)
    #print (sorted(top_6))
    ordered_hist.append(sort2)

# %%
for item in ordered_hist[:20]:
    print (item)
# Out:
# ['No Significant Medical History', nan, nan, nan, nan, nan]
# ['Substance Misuse', nan, nan, nan, nan, nan]
# ['Hypertension (HTN)', 'NIDDM (Non-Insulin-Dependent Diabetes Mellitus)', 'MI (Myocardial Infarction)', 'ACS (Acute Coronary Syndrome)', 'bronchiectasis', 'triple a repair']
# ['Hypertension (HTN)', nan, nan, nan, nan, nan]
# ['Asthma', 'Seizure', 'palpitations', 'leaky hrt valve', nan, nan]
# ['No Significant Medical History', nan, nan, nan, nan, nan]
# ['No Significant Medical History', nan, nan, nan, nan, nan]
# ['No Significant Medical History', nan, nan, nan, nan, nan]
# ['Hypertension (HTN)', 'High Cholesterol', 'Gerd', 'Chronic Back Pain', nan, nan]
# ['No Significant Medical History', nan, nan, nan, nan, nan]
# ['High Cholesterol', 'IDDM (Insulin-Dependent Diabetes Mellitus)', 'Dialysis Haemo/PD', 'CRF (Chronic Renal Failure)', 'heart problem', nan]
# ['Fibromyalgia', nan, nan, nan, nan, nan]
# ['enlarged liver', nan, nan, nan, nan, nan]
# ['Depression', 'Asthma', 'Anxiety', 'ADHD (Attention Deficit Hyperactivity Disorder)', 'Autistic', 'Celiac']
# ['No Significant Medical History', nan, nan, nan, nan, nan]
# ['IDDM (Insulin-Dependent Diabetes Mellitus)', nan, nan, nan, nan, nan]
# ['No Significant Medical History', nan, nan, nan, nan, nan]
# ['Hypertension (HTN)', 'Arthritis', 'CVA (Cerebral vascular Accident)', 'Dementia', 'TIA (Transient Ischemic Attack)', 'Glaucoma']
# ['Hypertension (HTN)', 'MI (Myocardial Infarction)', 'Bladder Cancer', 'stents,borderline dm', nan, nan]
# ['Received Chemotherapy within 4 weeks', 'ca colon with bowel resection', nan, nan, nan, nan]

# %%
medhx_df = pd.DataFrame(ordered_hist, columns = ['medhx' + str(i+1) for i in range(6)])

# %%
len(medhx_df)
# Out:
# 122211

# %%
medhx_df.head()
# Out:
#                            medhx1  \
# 0  No Significant Medical History
# 1                Substance Misuse
# 2              Hypertension (HTN)
# 3              Hypertension (HTN)
# 4                          Asthma
#
#                                             medhx2  \
# 0                                              NaN
# 1                                              NaN
# 2  NIDDM (Non-Insulin-Dependent Diabetes Mellitus)
# 3                                              NaN
# 4                                          Seizure
#
#                        medhx3                         medhx4          medhx5  \
# 0                         NaN                            NaN             NaN
# 1                         NaN                            NaN             NaN
# 2  MI (Myocardial Infarction)  ACS (Acute Coronary Syndrome)  bronchiectasis
# 3                         NaN                            NaN             NaN
# 4                palpitations                leaky hrt valve             NaN
#
#             medhx6
# 0              NaN
# 1              NaN
# 2  triple a repair
# 3              NaN
# 4              NaN

# %%
freq_hist = []
for item in split_hist:
    top_6 = []
    for hx in item:
        top_6.append((dx_freq_dict[hx], hx))
    sort = sorted(top_6)
    sort2 = [i for i,ii in sort]
    if len(sort2) > 6:
        sort2 = sort2[:5]
    if len(sort2) < 6:
        pad_req = 6-len(sort2)
        i = 0
        while i < pad_req:
            sort2.append(np.nan) #('n/a')
            i = i+1
        
    #print (top_6)
    #print (sorted(top_6))
    freq_hist.append(sort2)

# %%
freq_hist[:20]
# Out:
# [[1.6244002281649499, nan, nan, nan, nan, nan],
#  [0.0318088783008422, nan, nan, nan, nan, nan],
#  [3.35536690937154e-05,
#   0.0001342146763748616,
#   0.0010737174109988928,
#   0.048518605509512466,
#   0.26762406469147404,
#   0.6304734422709123],
#  [0.6304734422709123, nan, nan, nan, nan, nan],
#  [3.35536690937154e-05,
#   0.0012750394255611852,
#   0.03543267456296346,
#   0.15092440358353185,
#   nan,
#   nan],
#  [1.6244002281649499, nan, nan, nan, nan, nan],
#  [1.6244002281649499, nan, nan, nan, nan, nan],
#  [1.6244002281649499, nan, nan, nan, nan, nan],
#  [0.018622286347012046,
#   0.05026339630238567,
#   0.5310874744153273,
#   0.6304734422709123,
#   nan,
#   nan],
#  [1.6244002281649499, nan, nan, nan, nan, nan],
#  [0.000671073381874308,
#   0.010300976411770628,
#   0.013354360299298729,
#   0.09797671375364896,
#   0.5310874744153273,
#   nan],
#  [0.016005100157702245, nan, nan, nan, nan, nan],
#  [0.0001342146763748616, nan, nan, nan, nan, nan],
#  [0.002248095829278932,
#   0.006945609502399088,
#   0.01976311109619837,
#   0.12700063751971277,
#   0.15092440358353185,
#   0.16981511928329363],
#  [1.6244002281649499, nan, nan, nan, nan, nan],
#  [0.09797671375364896, nan, nan, nan, nan, nan],
#  [1.6244002281649499, nan, nan, nan, nan, nan],
#  [0.007818004898835688,
#   0.009797671375364896,
#   0.031003590242593027,
#   0.031741770962654764,
#   0.05734322048115961,
#   0.6304734422709123],
#  [3.35536690937154e-05,
#   0.003288259571184109,
#   0.048518605509512466,
#   0.6304734422709123,
#   nan,
#   nan],
#  [3.35536690937154e-05, 0.003019830218434386, nan, nan, nan, nan]]

# %%
medfreq_df = pd.DataFrame(freq_hist, columns = ['freqhx' + str(i+1) for i in range(6)])

# %%
medfreq_df.head()
# Out:
#     freqhx1   freqhx2   freqhx3   freqhx4   freqhx5   freqhx6
# 0  1.624400       NaN       NaN       NaN       NaN       NaN
# 1  0.031809       NaN       NaN       NaN       NaN       NaN
# 2  0.000034  0.000134  0.001074  0.048519  0.267624  0.630473
# 3  0.630473       NaN       NaN       NaN       NaN       NaN
# 4  0.000034  0.001275  0.035433  0.150924       NaN       NaN

# %%
date_df = clin[['Triage Date & Time', 'Reg Date & Time',
       'PIA Date & Time', 'Disposition Date & Time', 'Left ED Date & Time']]

# %%
data_path
# Out:
# '/Users/jjaskolkambp/Desktop/machine learning/my_projects/data/ED triage project'

# %%
date_df.to_csv(data_path + '/date_data.csv')

# %%
medhx_df.to_csv(data_path + '/med_hx.csv')

# %%
medfreq_df.to_csv(data_path + '/med_freq.csv')

# %%
features3 = pd.concat([clin[['systolic', 'diastolic', 'pulse', 'o2sat',
                            'temp', 'AgeInYrs', 'Gender', 'PresentingComplaint',
                            'TriageLevel']], medfreq_df], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(features3, target2) #, random_state=1)
xgc = xgb.XGBClassifier()
xgc.fit(X_train, y_train)
preds = xgc.predict(X_test)
conf = confusion_matrix(y_test, preds); conf
# Out:
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([[29789,   332,     0,     0],
#        [ 2564,   815,     0,     0],
#        [  552,    69,     0,     0],
#        [   82,    46,     0,     0]])

# %%
f1_w = sklearn.metrics.f1_score(y_test, preds, average='weighted')
f1 = sklearn.metrics.f1_score(y_test, preds, average=None)
acc = sklearn.metrics.accuracy_score(y_test, preds)
prec = sklearn.metrics.precision_score(y_test,preds, average = None)
rec = sklearn.metrics.recall_score(y_test,preds, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.8649280186331326
# f1:           [0.94406414 0.35121741 0.         0.        ]
# accuracy:     0.8935735349937225
# precision:    [0.90305272 0.64580032 0.         0.        ]
# recall:       [0.98897779 0.24119562 0.         0.        ]
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
LABELS = target_dict.keys()  #['admit', 'discharge'] #lab_count.keys()

plt.figure(figsize=(5, 5))
sns.heatmap(conf, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(features3, target1) #, random_state=1)
xgc = xgb.XGBClassifier()
xgc.fit(X_train, y_train)
preds = xgc.predict(X_test)
conf = confusion_matrix(y_test, preds); conf
# Out:
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([[29685,   309,     0,     1],
#        [ 2615,   702,     0,     4],
#        [  506,    62,     0,     0],
#        [  246,   115,     0,     4]])

# %%
f1_w = sklearn.metrics.f1_score(y_test, preds, average='weighted')
f1 = sklearn.metrics.f1_score(y_test, preds, average=None)
acc = sklearn.metrics.accuracy_score(y_test, preds)
prec = sklearn.metrics.precision_score(y_test,preds, average = None)
rec = sklearn.metrics.recall_score(y_test,preds, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.855135502879926
# f1:           [0.94167843 0.31137725 0.         0.02139037]
# accuracy:     0.887354375310228
# precision:    [0.89813022 0.59090909 0.         0.44444444]
# recall:       [0.98966494 0.21138211 0.         0.0109589 ]
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
plt.figure(figsize=(5, 5))
sns.heatmap(conf, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %%
#need to make a dictionary of numbers instead of words for med history
med_labels = []
for item in split_hist:
    top_6 = []
    for hx in item:
        top_6.append((dx_rank_dict[hx], hx))
    sort = sorted(top_6)
    sort2 = [i for i,ii in sort]
    if len(sort2) > 6:
        sort2 = sort2[:5]
    if len(sort2) < 6:
        pad_req = 6-len(sort2)
        i = 0
        while i < pad_req:
            sort2.append(np.nan) #('n/a')
            i = i+1
        
    #print (top_6)
    #print (sorted(top_6))
    med_labels.append(sort2)

# %%
medlab_df = pd.DataFrame(med_labels, columns = ['medlab' + str(i+1) for i in range(6)])

# %%
medlab_df.head()
# Out:
#    medlab1  medlab2  medlab3  medlab4  medlab5  medlab6
# 0        1      NaN      NaN      NaN      NaN      NaN
# 1       24      NaN      NaN      NaN      NaN      NaN
# 2        2      4.0     17.0    229.0   1217.0   3859.0
# 3        2      NaN      NaN      NaN      NaN      NaN
# 4        7     20.0    207.0   3860.0      NaN      NaN

# %%
features4 = pd.concat([clin[['systolic', 'diastolic', 'pulse', 'o2sat',
                            'temp', 'AgeInYrs', 'Gender', 'PresentingComplaint',
                            'TriageLevel']], medlab_df], axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(features4, target2) #, random_state=1)
xgc = xgb.XGBClassifier()
xgc.fit(X_train, y_train)
preds = xgc.predict(X_test)
conf = confusion_matrix(y_test, preds); conf
# Out:
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([[29536,   325,     0,     0],
#        [ 2745,   835,     0,     0],
#        [  621,    69,     0,     0],
#        [   79,    39,     0,     0]])

# %%
f1_w = sklearn.metrics.f1_score(y_test, preds, average='weighted')
f1 = sklearn.metrics.f1_score(y_test, preds, average=None)
acc = sklearn.metrics.accuracy_score(y_test, preds)
prec = sklearn.metrics.precision_score(y_test,preds, average = None)
rec = sklearn.metrics.recall_score(y_test,preds, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.8555810874008807
# f1:           [0.94000827 0.34447195 0.         0.        ]
# accuracy:     0.8867704166545008
# precision:    [0.89554592 0.65851735 0.         0.        ]
# recall:       [0.98911624 0.23324022 0.         0.        ]
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/jjaskolkambp/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
plt.figure(figsize=(5, 5))
sns.heatmap(conf, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()
