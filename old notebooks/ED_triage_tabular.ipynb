# %% [markdown]
# # Tabular models

# %%
from fastai import *
from fastai.tabular import *

# %%
import os
import re
from collections import Counter
import random

# %%
from sklearn.metrics import confusion_matrix
import sklearn.metrics
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
path = '/floyd/home/notebooks'
data_path = '/floyd/home/data'
model_path = '/floyd/home/models'

# %%
os.listdir(data_path)
# Out:
# ['date_data.csv',
#  'ed_databunch',
#  'tabular_data.csv',
#  'targets.csv',
#  'subj_data.csv',
#  'inf_control_data.csv',
#  'med_hx.csv',
#  'med_lab.csv',
#  '.ipynb_checkpoints',
#  'jj_modified_bch_data.xlsx',
#  'med_freq.csv']

# %%
df1 = pd.read_csv(data_path +'/tabular_data.csv')
df2 = pd.read_csv(data_path +'/targets.csv')
df3 = pd.read_csv(data_path + '/subj_data.csv')
df4 = pd.read_csv(data_path +'/date_data.csv')
df5 = pd.read_csv(data_path +'/med_hx.csv')

# %%
len(df1), len(df2), len(df3), len(df4), len(df5)
# Out:
# (136993, 136993, 136993, 136993, 136993)

# %%
df4.head()
# Out:
#    Unnamed: 0      Triage Date & Time         Reg Date & Time  \
# 0           0  31/03/2018  11:55:00PM  01/04/2018  12:03:00AM
# 1           1  31/03/2018  11:22:00PM  01/04/2018  12:08:00AM
# 2           2  01/04/2018  12:01:00AM  01/04/2018  12:10:00AM
# 3           3  01/04/2018  12:04:00AM  01/04/2018  12:13:00AM
# 4           4  01/04/2018  12:11:00AM  01/04/2018  12:14:00AM
#
#           PIA Date & Time Disposition Date & Time     Left ED Date & Time
# 0  01/04/2018   1:36:00AM  01/04/2018   7:00:00AM  01/04/2018   7:00:00AM
# 1  01/04/2018   1:10:00AM  01/04/2018   8:49:00AM  01/04/2018   8:49:00AM
# 2  01/04/2018   1:49:00AM  01/04/2018   4:40:00AM  01/04/2018   4:40:00AM
# 3                     NaN  01/04/2018   1:25:00AM  01/04/2018   1:25:00AM
# 4  01/04/2018   1:40:00AM  01/04/2018   6:59:00AM  01/04/2018   6:59:00AM

# %%
add_datepart(df4, 'Triage Date & Time');
# Out:
#         Unnamed: 0         Reg Date & Time         PIA Date & Time  \
# 0                0  01/04/2018  12:03:00AM  01/04/2018   1:36:00AM
# 1                1  01/04/2018  12:08:00AM  01/04/2018   1:10:00AM
# 2                2  01/04/2018  12:10:00AM  01/04/2018   1:49:00AM
# 3                3  01/04/2018  12:13:00AM                     NaN
# 4                4  01/04/2018  12:14:00AM  01/04/2018   1:40:00AM
# 5                5  01/04/2018  12:17:00AM  01/04/2018   2:03:00AM
# 6                6  01/04/2018  12:20:00AM  01/04/2018  12:30:00AM
# 7                7  01/04/2018  12:23:00AM  01/04/2018   2:03:00AM
# 8                8  01/04/2018  12:26:00AM  01/04/2018   2:19:00AM
# 9                9  01/04/2018  12:27:00AM  01/04/2018   2:14:00AM
# 10              10  01/04/2018  12:32:00AM  01/04/2018   1:40:00AM
# 11              11  01/04/2018  12:35:00AM  01/04/2018   1:30:00AM
# 12              12  01/04/2018  12:38:00AM  01/04/2018   2:32:00AM
# 13              13  01/04/2018  12:42:00AM  01/04/2018   2:26:00AM
# 27                              3.0                          4.0
# 28                              3.0                          4.0
# 29                              3.0                          4.0
# ...                             ...                          ...
# 136963                          6.0                         90.0
# 136964                          6.0                         90.0
# 136965                          6.0                         90.0
# 136966                          6.0                         90.0
# 136967                          6.0                         90.0
# 136968                          6.0                         90.0
# 136969                          6.0                         90.0
# 136970                          6.0                         90.0
# 136971                          6.0                         90.0
# 136972                          6.0                         90.0
# 136973                          6.0                         90.0
# 136974                          6.0                         90.0
# 136975                          6.0                         90.0
# 136976                          6.0                         90.0
# 136977                          6.0                         90.0
# 136978                          6.0                         90.0
# 136979                          6.0                         90.0
# 136980                          6.0                         90.0
# 136981                          6.0                         90.0
# 136982                          6.0                         90.0
# 136983                          6.0                         90.0
# 136984                          6.0                         90.0
# 136985                          6.0                         90.0
# 136986                          6.0                         90.0
# 136987                          6.0                         90.0
# 136988                          6.0                         90.0
# 136989                          6.0                         90.0
# 136990                          6.0                         90.0
# 136991                          6.0                         90.0
# 136992                          6.0                         90.0
#
#         Triage Date & TimeIs_month_end  Triage Date & TimeIs_month_start  \
# 0                                 True                             False
# 1                                 True                             False
# 2                                False                             False
# 3                                False                             False
# 4                                False                             False
# 5                                False                             False
# 6                                False                             False
# 7                                False                             False
# 8                                False                             False
# 9                                False                             False
# 10                               False                             False
# 11                               False                             False
# 12                               False                             False
# 13                               False                             False
# 14                               False                             False
# 15                               False                             False
# 16                               False                             False
# 17                               False                             False
# 18                               False                             False
# 19                               False                             False
# 20                               False                             False
# 21                               False                             False
# 22                               False                             False
# 23                               False                             False
# 24                               False                             False
# 25                               False                             False
# 26                               False                             False
# 27                               False                             False
# 28                               False                             False
# 29                               False                             False
# ...                                ...                               ...
# 136963                            True                             False
# 136964                            True                             False
# 136965                            True                             False
# 136966                            True                             False
# 136967                            True                             False
# 136968                            True                             False
# 136969                            True                             False
# 136970                            True                             False
# 136971                            True                             False
# 136972                            True                             False
# 136973                            True                             False
# 136974                            True                             False
# 136975                            True                             False
# 136976                            True                             False
# 136977                            True                             False
# 136978                            True                             False
# 136979                            True                             False
# 136980                            True                             False
# 136981                            True                             False
# 136982                            True                             False
# 136983                            True                             False
# 136984                            True                             False
# 136985                            True                             False
# 136986                            True                             False
# 136987                            True                             False
# 136988                            True                             False
# 136989                            True                             False
# 136990                            True                             False
# 136991                            True                             False
# 136992                            True                             False
#
#         Triage Date & TimeIs_quarter_end  Triage Date & TimeIs_quarter_start  \
# 0                                   True                               False
# 1                                   True                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# 5                                  False                               False
# 6                                  False                               False
# 7                                  False                               False
# 8                                  False                               False
# 9                                  False                               False
# 10                                 False                               False
# 11                                 False                               False
# 12                                 False                               False
# 13                                 False                               False
# 14                                 False                               False
# 15                                 False                               False
# 16                                 False                               False
# 17                                 False                               False
# 18                                 False                               False
# 19                                 False                               False
# 20                                 False                               False
# 21                                 False                               False
# 22                                 False                               False
# 23                                 False                               False
# 24                                 False                               False
# 25                                 False                               False
# 26                                 False                               False
# 27                                 False                               False
# 28                                 False                               False
# 29                                 False                               False
# ...                                  ...                                 ...
# 136963                              True                               False
# 136964                              True                               False
# 136965                              True                               False
# 136966                              True                               False
# 136967                              True                               False
# 136968                              True                               False
# 136969                              True                               False
# 136970                              True                               False
# 136971                              True                               False
# 136972                              True                               False
# 136973                              True                               False
# 136974                              True                               False
# 136975                              True                               False
# 136976                              True                               False
# 136977                              True                               False
# 136978                              True                               False
# 136979                              True                               False
# 136980                              True                               False
# 136981                              True                               False
# 136982                              True                               False
# 136983                              True                               False
# 136984                              True                               False
# 136985                              True                               False
# 136986                              True                               False
# 136987                              True                               False
# 136988                              True                               False
# 136989                              True                               False
# 136990                              True                               False
# 136991                              True                               False
# 136992                              True                               False
#
#         Triage Date & TimeIs_year_end  Triage Date & TimeIs_year_start  \
# 0                               False                            False
# 1                               False                            False
# 2                               False                            False
# 3                               False                            False
# 4                               False                            False
# 5                               False                            False
# 6                               False                            False
# 7                               False                            False
# 8                               False                            False
# 9                               False                            False
# 10                              False                            False
# 11                              False                            False
# 12                              False                            False
# 13                              False                            False
# 14                              False                            False
# 15                              False                            False
# 16                              False                            False
# 17                              False                            False
# 18                              False                            False
# 19                              False                            False
# 20                              False                            False
# 21                              False                            False
# 22                              False                            False
# 23                              False                            False
# 24                              False                            False
# 25                              False                            False
# 26                              False                            False
# 27                              False                            False
# 28                              False                            False
# 29                              False                            False
# ...                               ...                              ...
# 136963                          False                            False
# 136964                          False                            False
# 136965                          False                            False
# 136966                          False                            False
# 136967                          False                            False
# 136968                          False                            False
# 136969                          False                            False
# 136970                          False                            False
# 136971                          False                            False
# 136972                          False                            False
# 136973                          False                            False
# 136974                          False                            False
# 136975                          False                            False
# 136976                          False                            False
# 136977                          False                            False
# 136978                          False                            False
# 136979                          False                            False
# 136980                          False                            False
# 136981                          False                            False
# 136982                          False                            False
# 136983                          False                            False
# 136984                          False                            False
# 136985                          False                            False
# 136986                          False                            False
# 136987                          False                            False
# 136988                          False                            False
# 136989                          False                            False
# 136990                          False                            False
# 136991                          False                            False
# 136992                          False                            False
#
#         Triage Date & TimeElapsed
# 0                      1522540500
# 1                      1522538520
# 2                      1515024060
# 3                      1515024240
# 4                      1515024660
# 5                      1515024360
# 6                      1515024600
# 7                      1515025020
# 8                      1515025080
# 9                      1515024840
# 10                     1515025740
# 11                     1515025920
# 12                     1515025800
# 13                     1515026220
# 14                     1515026580
# 15                     1515026640
# 16                     1515025500
# 17                     1515027180
# 18                     1515027360
# 19                     1515027360
# 20                     1515027780
# 21                     1515028140
# 22                     1515028500
# 23                     1515028740
# 24                     1515028800
# 25                     1515029160
# 26                     1515029040
# 27                     1515029880
# 28                     1515030300
# 29                     1515029340
# ...                           ...
# 136963                 1554067500
# 136964                 1554068700
# 136965                 1554068880
# 136966                 1554069120
# 136967                 1554069360
# 136968                 1554069480
# 136969                 1554069840
# 136970                 1554069960
# 136971                 1554070440
# 136972                 1554070620
# 136973                 1554071100
# 136974                 1554071100
# 136975                 1554071460
# 136976                 1554071280
# 136977                 1554070860
# 136978                 1554071640
# 136979                 1554071820
# 136980                 1554072000
# 136981                 1554072180
# 136982                 1554072060
# 136983                 1554073320
# 136984                 1554072480
# 136985                 1554072540
# 136986                 1554072660
# 136987                 1554073680
# 136988                 1554074580
# 136989                 1554075480
# 136990                 1554075120
# 136991                 1554074880
# 136992                 1554075780
#
# [136993 rows x 18 columns]

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Reg Date & Time', 'PIA Date & Time',
#        'Disposition Date & Time', 'Left ED Date & Time',
#        'Triage Date & TimeYear', 'Triage Date & TimeMonth',
#        'Triage Date & TimeWeek', 'Triage Date & TimeDay',
#        'Triage Date & TimeDayofweek', 'Triage Date & TimeDayofyear',
#        'Triage Date & TimeIs_month_end', 'Triage Date & TimeIs_month_start',
#        'Triage Date & TimeIs_quarter_end',
#        'Triage Date & TimeIs_quarter_start', 'Triage Date & TimeIs_year_end',
#        'Triage Date & TimeIs_year_start', 'Triage Date & TimeElapsed'],
#       dtype='object')

# %%
date_df = df4[['Triage Date & TimeMonth',
       'Triage Date & TimeWeek', 'Triage Date & TimeDay',
       'Triage Date & TimeDayofweek', 'Triage Date & TimeDayofyear',
       'Triage Date & TimeIs_month_end', 'Triage Date & TimeIs_month_start',
       'Triage Date & TimeIs_quarter_end',
       'Triage Date & TimeIs_quarter_start', 'Triage Date & TimeIs_year_end',
       'Triage Date & TimeIs_year_start', 'Triage Date & TimeElapsed']]

# %%
date_df.head()
# Out:
#    Triage Date & TimeMonth  Triage Date & TimeWeek  Triage Date & TimeDay  \
# 0                      3.0                    13.0                   31.0
# 1                      3.0                    13.0                   31.0
# 2                      1.0                     1.0                    4.0
# 3                      1.0                     1.0                    4.0
# 4                      1.0                     1.0                    4.0
#
#    Triage Date & TimeDayofweek  Triage Date & TimeDayofyear  \
# 0                          5.0                         90.0
# 1                          5.0                         90.0
# 2                          3.0                          4.0
# 3                          3.0                          4.0
# 4                          3.0                          4.0
#
#    Triage Date & TimeIs_month_end  Triage Date & TimeIs_month_start  \
# 0                            True                             False
# 1                            True                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
#
#    Triage Date & TimeIs_quarter_end  Triage Date & TimeIs_quarter_start  \
# 0                              True                               False
# 1                              True                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
#
#    Triage Date & TimeIs_year_end  Triage Date & TimeIs_year_start  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                          False                            False
# 4                          False                            False
#
#    Triage Date & TimeElapsed
# 0                 1522540500
# 1                 1522538520
# 2                 1515024060
# 3                 1515024240
# 4                 1515024660

# %%
df5 = pd.read_csv(data_path +'/med_hx.csv')

# %%
df5.drop(['Unnamed: 0'], axis = 1, inplace = True)
df5.columns = ['medhx' + str(i+1) for i in range(6)]
df5.head()
# Out:
#                            medhx1  \
# 0  No Significant Medical History
# 1                Substance Misuse
# 2              Hypertension (HTN)
# 3              Hypertension (HTN)
# 4                          Asthma
#
#                                             medhx2  \
# 0                                              NaN
# 1                                              NaN
# 2  NIDDM (Non-Insulin-Dependent Diabetes Mellitus)
# 3                                              NaN
# 4                                          Seizure
#
#                        medhx3                         medhx4          medhx5  \
# 0                         NaN                            NaN             NaN
# 1                         NaN                            NaN             NaN
# 2  MI (Myocardial Infarction)  ACS (Acute Coronary Syndrome)  bronchiectasis
# 3                         NaN                            NaN             NaN
# 4                palpitations                leaky hrt valve             NaN
#
#             medhx6
# 0              NaN
# 1              NaN
# 2  triple a repair
# 3              NaN
# 4              NaN

# %%
df = pd.concat([df1,df2,df3, date_df, df5], axis = 1)

# %%
len(df)
# Out:
# 136993

# %%
df.head()
# Out:
#    Unnamed: 0  ID  TriageLevel  AgeInYrs GenderDesc  DischargeDisposition  \
# 0           0   1          3.0      12.0       Male                    17
# 1           1   2          2.0      80.0     Female                    17
# 2           2   3          3.0       3.0       Male                    17
# 3           3   4          3.0      56.0     Female                    62
# 4           4   5          2.0      69.0     Female                    17
#
#    PresentingComplaint             PresentingComplaintDesc AdmitLocation  \
# 0                  852                               Fever           NaN
# 1                  401      Altered level of consciousness           NaN
# 2                  253                        Constipation           NaN
# 3                  409  Extremity weakness/symptoms of CVA           NaN
# 4                    3       Chest pain - cardiac features           NaN
#
#   PatientService       ...        Triage Date & TimeIs_quarter_start  \
# 0            NaN       ...                                     False
# 1            NaN       ...                                     False
# 2            NaN       ...                                     False
# 3            NaN       ...                                     False
# 4            NaN       ...                                     False
#
#    Triage Date & TimeIs_year_end  Triage Date & TimeIs_year_start  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                          False                            False
# 4                          False                            False
#
#    Triage Date & TimeElapsed                          medhx1  \
# 0                 1522540500  No Significant Medical History
# 1                 1522538520                Substance Misuse
# 2                 1515024060              Hypertension (HTN)
# 3                 1515024240              Hypertension (HTN)
# 4                 1515024660                          Asthma
#
#                                             medhx2  \
# 0                                              NaN
# 1                                              NaN
# 2  NIDDM (Non-Insulin-Dependent Diabetes Mellitus)
# 3                                              NaN
# 4                                          Seizure
#
#                        medhx3                         medhx4          medhx5  \
# 0                         NaN                            NaN             NaN
# 1                         NaN                            NaN             NaN
# 2  MI (Myocardial Infarction)  ACS (Acute Coronary Syndrome)  bronchiectasis
# 3                         NaN                            NaN             NaN
# 4                palpitations                leaky hrt valve             NaN
#
#             medhx6
# 0              NaN
# 1              NaN
# 2  triple a repair
# 3              NaN
# 4              NaN
#
# [5 rows x 44 columns]

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'ID',
#  'TriageLevel',
#  'AgeInYrs',
#  'GenderDesc',
#  'DischargeDisposition',
#  'PresentingComplaint',
#  'PresentingComplaintDesc',
#  'AdmitLocation',
#  'PatientService',
#  'BloodPressure_LastEDReading',
#  'systolic',
#  'diastolic',
#  'temp',
#  'pulse',
#  'o2sat',
#  'Unnamed: 0',
#  'service',
#  'target2',
#  'target',
#  'outcome',
#  'discharge',
#  'dispo',
#  'Unnamed: 0',
#  'MedicalHistory',
#  'SubjectiveNotes',
#  'Triage Date & TimeMonth',
#  'Triage Date & TimeWeek',
#  'Triage Date & TimeDay',
#  'Triage Date & TimeDayofweek',
#  'Triage Date & TimeDayofyear',
#  'Triage Date & TimeIs_month_end',
#  'Triage Date & TimeIs_month_start',
#  'Triage Date & TimeIs_quarter_end',
#  'Triage Date & TimeIs_quarter_start',
#  'Triage Date & TimeIs_year_end',
#  'Triage Date & TimeIs_year_start',
#  'Triage Date & TimeElapsed',
#  'medhx1',
#  'medhx2',
#  'medhx3',
#  'medhx4',
#  'medhx5',
#  'medhx6']

# %%
#check that I got what I wanted out of the prior setp
count = Counter(df['outcome']); count
# Out:
# Counter({'discharge': 120106, 'sadmit': 2272, 'madmit': 13270, 'ICU': 1345})

# %%
dep_var = 'outcome'
cat_names = ['TriageLevel',
 'GenderDesc',
 'PresentingComplaint']
cont_names = ['AgeInYrs', 'o2sat', 'pulse','temp','systolic','diastolic']
procs = [FillMissing, Categorify, Normalize]

# %%
test = TabularList.from_df(df.copy(),cat_names=cat_names, cont_names=cont_names)

# %%
valid_idxs = random.sample(range(len(df)), len(df)//5); len(valid_idxs)
# Out:
# 27398

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                           .split_by_idx(valid_idxs)
                           .label_from_df(cols=dep_var)
                           .add_test(test)
                           .databunch())

# %%
len(data.train_ds), len(data.valid_ds)
# Out:
# (109595, 27398)

# %%
len(data.train_ds) +  len(data.valid_ds) == len(data.test_ds)
# Out:
# True

# %%
data.save(data_path + '/ed_databunch')

# %%
data.show_batch(rows=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>TriageLevel</th>
#       <th>GenderDesc</th>
#       <th>PresentingComplaint</th>
#       <th>o2sat_na</th>
#       <th>pulse_na</th>
#       <th>temp_na</th>
#       <th>systolic_na</th>
#       <th>diastolic_na</th>
#       <th>AgeInYrs</th>
#       <th>o2sat</th>
#       <th>pulse</th>
#       <th>temp</th>
#       <th>systolic</th>
#       <th>diastolic</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2.0</td>
#       <td>Female</td>
#       <td>301</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>0.5689</td>
#       <td>-0.2583</td>
#       <td>0.1498</td>
#       <td>-0.2276</td>
#       <td>1.2221</td>
#       <td>0.5450</td>
#       <td>discharge</td>
#     </tr>
#     <tr>
#       <td>3.0</td>
#       <td>Male</td>
#       <td>852</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>-1.6620</td>
#       <td>0.3022</td>
#       <td>1.9023</td>
#       <td>2.7299</td>
#       <td>-0.1164</td>
#       <td>-0.0549</td>
#       <td>discharge</td>
#     </tr>
#     <tr>
#       <td>3.0</td>
#       <td>Male</td>
#       <td>551</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>1.1092</td>
#       <td>0.0219</td>
#       <td>-1.0320</td>
#       <td>-0.4125</td>
#       <td>0.1067</td>
#       <td>-0.0549</td>
#       <td>discharge</td>
#     </tr>
#     <tr>
#       <td>2.0</td>
#       <td>Male</td>
#       <td>504</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>1.7327</td>
#       <td>-0.5386</td>
#       <td>0.3536</td>
#       <td>-0.0428</td>
#       <td>1.7128</td>
#       <td>-0.0549</td>
#       <td>discharge</td>
#     </tr>
#     <tr>
#       <td>3.0</td>
#       <td>Female</td>
#       <td>257</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td
td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
preds, targets = learn.get_preds(DatasetType.Valid) 
predictions = np.argmax(preds, axis = 1)

# %%
preds[0], targets[0], predictions[0]
# Out:
# (tensor([0.0014, 0.9312, 0.0562, 0.0112]), tensor(1), tensor(1))

# %%
LABELS = data.classes

confusion_matrix = sklearn.metrics.confusion_matrix(targets, predictions)

plt.figure(figsize=(5, 5))
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %%
f1_w = sklearn.metrics.f1_score(targets, predictions, average='weighted')
f1 = sklearn.metrics.f1_score(targets, predictions, average=None)
acc = sklearn.metrics.accuracy_score(targets, predictions)
prec = sklearn.metrics.precision_score(targets,predictions, average = None)
rec = sklearn.metrics.recall_score(targets,predictions, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.8587475758612368
# f1:           [0.041237 0.942167 0.331975 0.04661 ]
# accuracy:     0.8886780056938463
# precision:    [0.333333 0.899848 0.613454 0.458333]
# recall:       [0.021978 0.988663 0.227561 0.024554]

# %% [markdown]
# <br>
# <br>
# <br>
# Now gonna try to do better by adding some columns that are from the triage notes
# <br>
# <br>
# <br>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'TriageLevel', 'AgeInYrs', 'GenderDesc',
#        'DischargeDisposition', 'PresentingComplaint',
#        'PresentingComplaintDesc', 'AdmitLocation', 'PatientService',
#        'BloodPressure_LastEDReading', 'systolic', 'diastolic', 'temp', 'pulse',
#        'o2sat', 'Unnamed: 0', 'service', 'target2', 'target', 'outcome',
#        'discharge', 'dispo', 'Unnamed: 0', 'MedicalHistory', 'SubjectiveNotes',
#        'Triage Date & TimeMonth', 'Triage Date & TimeWeek',
#        'Triage Date & TimeDay', 'Triage Date & TimeDayofweek',
#        'Triage Date & TimeDayofyear', 'Triage Date & TimeIs_month_end',
#        'Triage Date & TimeIs_month_start', 'Triage Date & TimeIs_quarter_end',
#        'Triage Date & TimeIs_quarter_start', 'Triage Date & TimeIs_year_end',
#        'Triage Date & TimeIs_year_start', 'Triage Date & TimeElapsed',
#        'medhx1', 'medhx2', 'medhx3', 'medhx4', 'medhx5', 'medhx6'],
#       dtype='object')

# %%
dep_var = 'outcome'
cat_names = ['TriageLevel',
 'GenderDesc',
 'PresentingComplaint',
        'Triage Date & TimeMonth', 'Triage Date & TimeWeek',
       'Triage Date & TimeDay', 'Triage Date & TimeDayofweek',
       'Triage Date & TimeDayofyear', 'Triage Date & TimeIs_month_end',
       'Triage Date & TimeIs_month_start', 'Triage Date & TimeIs_quarter_end',
       'Triage Date & TimeIs_quarter_start', 'Triage Date & TimeIs_year_end',
       'Triage Date & TimeIs_year_start', 'Triage Date & TimeElapsed',
       'medhx1', 'medhx2', 'medhx3']
cont_names = ['AgeInYrs', 'o2sat', 'pulse','temp','systolic','diastolic']
procs = [FillMissing, Categorify, Normalize]

# %%
test = TabularList.from_df(df.copy(),cat_names=cat_names, cont_names=cont_names)

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
                           .split_by_rand_pct(0.1)
                           .label_from_df(cols=dep_var)
                           .add_test(test)
                           .databunch())

# %%
f1 = FBeta(beta=1, average = 'weighted')

# %%
learn = tabular_learner(data, layers=[200,100], metrics=[accuracy,f1])
learn.fit_one_cycle(5, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.351834</td>
#       <td>0.351382</td>
#       <td>0.886707</td>
#       <td>0.860668</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.219645</td>
#       <td>0.381363</td>
#       <td>0.880721</td>
#       <td>0.853465</td>
#       <td>01:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.116852</td>
#       <td>0.485410</td>
#       <td>0.876268</td>
#       <td>0.852601</td>
#       <td>01:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.045589</td>
#       <td>0.564753</td>
#       <td>0.878239</td>
#       <td>0.858996</td>
#       <td>01:51</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.014728</td>
#       <td>0.654210</td>
#       <td>0.876122</td>
#       <td>0.859734</td>
#       <td>01:50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# so significant overfitting here

# %%
data.classes
# Out:
# ['ICU', 'discharge', 'madmit', 'sadmit']

# %%
preds, targets = learn.get_preds(DatasetType.Valid) 
predictions = np.argmax(preds, axis = 1)

# %%
f1_w = sklearn.metrics.f1_score(targets, predictions, average='weighted')
f1 = sklearn.metrics.f1_score(targets, predictions, average=None)
acc = sklearn.metrics.accuracy_score(targets, predictions)
prec = sklearn.metrics.precision_score(targets,predictions, average = None)
rec = sklearn.metrics.recall_score(targets,predictions, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.8597344261403467
# f1:           [0.051282 0.935882 0.382042 0.078292]
# accuracy:     0.8761223446966931
# precision:    [0.125    0.911839 0.455882 0.244444]
# recall:       [0.032258 0.961228 0.328788 0.04661 ]

# %%
LABELS = data.classes

confusion_matrix = sklearn.metrics.confusion_matrix(targets, predictions)

plt.figure(figsize=(5, 5))
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %%
preds, targets = learn.get_preds(DatasetType.Train) 
predictions = np.argmax(preds, axis = 1)

# %%
LABELS = data.classes

confusion_matrix = sklearn.metrics.confusion_matrix(targets, predictions)

plt.figure(figsize=(5, 5))
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %%
learn = tabular_learner(data, layers=[200,100], metrics=[accuracy,f1], emb_drop = 0.5)
learn.fit_one_cycle(20, 1e-5, wd = 0.3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.375249</td>
#       <td>1.322305</td>
#       <td>0.454048</td>
#       <td>0.575723</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.330623</td>
#       <td>1.292534</td>
#       <td>0.602818</td>
#       <td>0.692448</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.276737</td>
#       <td>1.202295</td>
#       <td>0.735090</td>
#       <td>0.778157</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.188118</td>
#       <td>1.117098</td>
#       <td>0.785167</td>
#       <td>0.807972</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.047458</td>
#       <td>1.005684</td>
#       <td>0.819768</td>
#       <td>0.829671</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.860077</td>
#       <td>0.804649</td>
#       <td>0.859917</td>
#       <td>0.853979</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.691471</td>
#       <td>0.640544</td>
#       <td>0.878239</td>
#       <td>0.861766</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.531612</td>
#       <td>0.535471</td>
#       <td>0.881670</td>
#       <td>0.861016</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.437552</td>
#       <td>0.441604</td>
#       <td>0.884809</td>
#       <td>0.859236</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.385715</td>
#       <td>0.401565</td>
#       <td>0.884955</td>
#       <td>0.857140</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.339291</td>
#       <td>0.383592</td>
#       <td>0.885831</td>
#       <td>0.857057</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.332565</td>
#       <td>0.378383</td>
#       <td>0.886050</td>
#       <td>0.857496</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.320867</td>
#       <td>0.373727</td>
#       <td>0.886561</td>
#       <td>0.856451</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.321629</td>
#       <td>0.373895</td>
#       <td>0.885977</td>
#       <td>0.856280</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.288652</td>
#       <td>0.372458</td>
#       <td>0.884882</td>
#       <td>0.855323</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.314219</td>
#       <td>0.372471</td>
#       <td>0.884444</td>
#       <td>0.856518</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.291609</td>
#       <td>0.370693</td>
#       <td>0.884444</td>
#       <td>0.855108</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.278950</td>
#       <td>0.373347</td>
#       <td>0.884298</td>
#       <td>0.851269</td>
#       <td>01:54</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.293919</td>
#       <td>0.372561</td>
#       <td>0.885466</td>
#       <td>0.855869</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.306215</td>
#       <td>0.371926</td>
#       <td>0.883933</td>
#       <td>0.853742</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('edtriage_tab.pth')

# %%
preds, targets = learn.get_preds(DatasetType.Valid) 
predictions = np.argmax(preds, axis = 1)

# %%
f1_w = sklearn.metrics.f1_score(targets, predictions, average='weighted')
f1 = sklearn.metrics.f1_score(targets, predictions, average=None)
acc = sklearn.metrics.accuracy_score(targets, predictions)
prec = sklearn.metrics.precision_score(targets,predictions, average = None)
rec = sklearn.metrics.recall_score(targets,predictions, average = None)
print ('weighted f1: ', f1_w)
print ('f1:          ', f1)
print ('accuracy:    ', acc)
print ('precision:   ', prec)
print ('recall:      ', rec)
# Out:
# weighted f1:  0.8537425009837355
# f1:           [0.       0.939527 0.329009 0.      ]
# accuracy:     0.8839331338053873
# precision:    [0.       0.898164 0.55614  0.      ]
# recall:       [0.       0.984883 0.233604 0.      ]
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
LABELS = data.classes

confusion_matrix = sklearn.metrics.confusion_matrix(targets, predictions)

plt.figure(figsize=(5, 5))
sns.heatmap(confusion_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d", annot_kws={"size": 20});
plt.title("Confusion matrix", fontsize=20)
plt.ylabel('True label', fontsize=20)
plt.xlabel('Predicted label', fontsize=20)
plt.show()

# %% [markdown]
# even with more columns and slower training, I can't do better than 88% accuracy and f-score 0.85
